# %% [markdown]
#                 # My first automatic Jupyter Notebook
#                   This is an auto-generated notebook.

# %%
                # %pylab inline
                hist(normal(size=2000), bins=50);
