# %% [markdown]
# # Job satisfaction

# %%
import seaborn as sns
import operator
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from IPython.display import display
import IPython.core.display as di
from include.config import CleaningConfig, PlottingConfig, NotebookConfig
from include.counting import get_count, get_percentage
from include.plotting import get_plot, display_side_by_side
from include.likertScalePlot import likert_scale
from include.textCleaning import wordcloud

# %%
df =  pd.read_csv('./2017/uk/data/cleaned_data.csv')

# %%
recode_time = {'Never': 0, 'Sometimes': 1, 'Often': 2, 'Very Often': 3, 'Always': 4}
recode_agree = {'Strongly disagree': -2 ,
                'Disagree': -1, 
                'Neither agree or disagree': 0,
                'Agree': 1,
                'Strongly Agree': 2}

# %%
turnover_intention = df[['likertime2[turnOver1]. Please rate the following propositions. There are no right or wrong answers [How often do you feel frustrated when not given the opportunity to achieve your personal work-related goals?]', 'likertime2[turnOver2]. Please rate the following propositions. There are no right or wrong answers [How often do you look forward to another day at work?]', 'likerttime1[turnOver3]. Please rate the following propositions. There are no right or wrong answers [How often do you consider leaving your job?]', 'likerttime1[turnOver4]. Please rate the following propositions. There are no right or wrong answers [How often do you dream about getting another job that will better suit your needs?]']]

# %%
#turnover = turnover_intention.replace(recode_values)
turnover = turnover_intention.replace(recode_time).astype(dtype='float').sum(axis=1)

df_turnover = pd.DataFrame(turnover)
df_turnover['variable'] = 'turnover'

# %%
perceived_employability = df[['likertagree1[percEmp1]. Please rate the following propositions. There are no right or wrong answers [It would not be very difficult for me to get an equivalent job in a different organisation]', 'likertagree2[percEmp2]. Please rate the following propositions. There are no right or wrong answers [I can think of a number of organisations that would probably offer me a job]', 'likertagree1[percEmp3]. Please rate the following propositions. There are no right or wrong answers [My experience is in demand on the labour market]', 'likertagree3[percEmp4]. Please rate the following propositions. There are no right or wrong answers [Given my qualifications and experience, getting a new job would not be very hard at all]']]
 
perceived = perceived_employability.replace(recode_agree).astype(dtype='float').sum(axis=1)
df_perceived = pd.DataFrame(perceived)
df_perceived['variable'] = 'perceived employability'

# %%
df_jobs = df_turnover.append(df_perceived)
df_jobs.dropna(axis=0)
# Out:
#        0                 variable
# 0    8.0                 turnover
# 1    5.0                 turnover
# 2    0.0                 turnover
# 3    3.0                 turnover
# 4    6.0                 turnover
# 5    2.0                 turnover
# 6    9.0                 turnover
# 7    0.0                 turnover
# 8    4.0                 turnover
# 9    8.0                 turnover
# 10   4.0                 turnover
# 11   3.0                 turnover
# 12   9.0                 turnover
# 13   2.0                 turnover
# 14   6.0                 turnover
# 15   6.0                 turnover
# 16   6.0                 turnover
# 17   4.0                 turnover
# 18   7.0                 turnover
# 19   3.0                 turnover
# 20   4.0                 turnover
# 21   0.0                 turnover
# 22   3.0                 turnover
# 23   9.0                 turnover
# 24   7.0                 turnover
# 25   3.0                 turnover
# 26   2.0                 turnover
# 27   0.0                 turnover
# 28   9.0                 turnover
# 29   4.0                 turnover
# ..   ...                      ...
# 223  1.0  perceived employability
# 224 -3.0  perceived employability
# 225  0.0  perceived employability
# 226  2.0  perceived employability
# 227  5.0  perceived employability
# 228  8.0  perceived employability
# 229  4.0  perceived employability
# 230  1.0  perceived employability
# 231  3.0  perceived employability
# 232  4.0  perceived employability
# 233  0.0  perceived employability
# 234  5.0  perceived employability
# 235  5.0  perceived employability
# 236  3.0  perceived employability
# 237  1.0  perceived employability
# 238  0.0  perceived employability
# 239  8.0  perceived employability
# 240  3.0  perceived employability
# 241  0.0  perceived employability
# 242  1.0  perceived employability
# 243 -2.0  perceived employability
# 244  4.0  perceived employability
# 245  2.0  perceived employability
# 246  3.0  perceived employability
# 247  6.0  perceived employability
# 248 -2.0  perceived employability
# 249  1.0  perceived employability
# 250  0.0  perceived employability
# 251  1.0  perceived employability
# 252  3.0  perceived employability
#
# [506 rows x 2 columns]

# %%
# Creating the figure
#plt.figure(figsize=(20, 10))  
#plt.figure() 
#ax = plt.subplot(111)  
sns.boxplot(df_jobs)
#ax = sns.swarmplot(turnover_intention, color='#3F5D7D')
#sns.swarmplot(df_jobs, color="w", alpha=.5)
#plt.xticks(range(0, 53, 10), fontsize=12)
#plt.xlabel("Number of disciplines", fontsize=16)  
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-144-e3eecb20d06b> in <module>()
#       3 #plt.figure()
#       4 #ax = plt.subplot(111)
# ----> 5 sns.boxplot(df_jobs)
#       6 #ax = sns.swarmplot(turnover_intention, color='#3F5D7D')
#       7 #sns.swarmplot(df_jobs, color="w", alpha=.5)
#
# ~/git/ssi/jobs-analysis/venv/lib/python3.6/site-packages/seaborn/categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2215     kwargs.update(dict(whis=whis, notch=notch))
#    2216
# -> 2217     plotter.plot(ax, kwargs)
#    2218     return ax
#    2219
#
# ~/git/ssi/jobs-analysis/venv/lib/python3.6/site-packages/seaborn/categorical.py in plot(self, ax, boxplot_kws)
#     542     def plot(self, ax, boxplot_kws):
#     543         """Make the plot."""
# --> 544         self.draw_boxplot(ax, boxplot_kws)
#     545         self.annotate_axes(ax)
#     546         if self.orient == "h":
#
# ~/git/ssi/jobs-analysis/venv/lib/python3.6/site-packages/seaborn/categorical.py in draw_boxplot(self, ax, kws)
#     479                                          positions=[i],
#     480                                          widths=self.width,
# --> 481                                          **kws)
#     482                 color = self.colors[i]
#     483                 self.restyle_boxplot(artist_dict, color, props)
#
# ~/git/ssi/jobs-analysis/venv/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/git/ssi/jobs-analysis/venv/lib/python3.6/site-packages/matplotlib/axes/_axes.py in boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_xticks, autorange, zorder)
#    3555
#    3556         bxpstats = cbook.boxplot_stats(x, whis=whis, bootstrap=bootstrap,
# -> 3557                                        labels=labels, autorange=autorange)
#    3558         if notch is None:
#    3559             notch = rcParams['boxplot.notch']
#
# ~/git/ssi/jobs-analysis/venv/lib/python3.6/site-packages/matplotlib/cbook/__init__.py in boxplot_stats(X, whis, bootstrap, labels, autorange)
#    1839
#    1840         # arithmetic mean
# -> 1841         stats['mean'] = np.mean(x)
#    1842
#    1843         # medians and quartiles
#
# ~/git/ssi/jobs-analysis/venv/lib/python3.6/site-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    2955
#    2956     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 2957                           out=out, **kwargs)
#    2958
#    2959
#
# ~/git/ssi/jobs-analysis/venv/lib/python3.6/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#      68             is_float16_result = True
#      69
# ---> 70     ret = umr_sum(arr, axis, dtype, out, keepdims)
#      71     if isinstance(ret, mu.ndarray):
#      72         ret = um.true_divide(
#
# TypeError: cannot perform reduce with flexible type

# %%
perceived_employability =

# %%
satisfaction
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-da252213ec43> in <module>()
# ----> 1 satisfaction
#
# NameError: name 'satisfaction' is not defined

# %%
recognition =
# Out:
#   File "<ipython-input-8-fd0803500071>", line 1
#     recognition =
#                  ^
# SyntaxError: invalid syntax

# %%
feedback =
