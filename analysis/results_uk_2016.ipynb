# %% [markdown]
# # Section: Importing modules

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from IPython.display import display
import IPython.core.display as di
from IPython.core.interactiveshell import InteractiveShell
from include.config import CleaningConfig, PlottingConfig, NotebookConfig
from include.counting import get_count, get_percentage
from include.plotting import get_plot, display_side_by_side
from include.likertScalePlot import likert_scale
from include.textCleaning import wordcloud

# %%
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000) 
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# This text is used to hide the code cell when exported in html

# %%
di.display_html('<script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>', raw=True)
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>

# %%
get_ipython().magic('matplotlib inline')  # Activate that line to use in Jupyter 
matplotlib.rcParams['figure.figsize'] = (15.0, 8.0)

# %% [markdown]
# # Loading dataset

# %%
df =  pd.read_csv('./2016/uk/data/cleaned_data.csv')

# %% [markdown]
# The total of participant after cleaning the dataset. Remove all participants that have not completed the survey passed the first pages and all participants who are not from the country

# %%
len(df)
# Out:
# 273

# %% [markdown]
# # Section: 1

# %% [markdown]
# ## Group of question: socio

# %% [markdown]
# ### In which country do you live?

# %%
v_to_count, filename = get_count(df, ['socio1. In which country do you live?'], "one choice", "./../survey_creation/2016/uk/listAnswers/countries.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                Count  Percentage
# In which country do you live?
# United Kingdom                   273       100.0

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ## Group of question: edu

# %% [markdown]
# ### What is the highest qualification you have obtained?

# %%
v_to_count, filename = get_count(df, ['edu1. What is the highest qualification you have obtained?'], "one choice", "./../survey_creation/2016/uk/listAnswers/education.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Count  Percentage
# What is the highest qualification you have obta...
# Doctorate                                             183        67.0
# Masters degree                                         53        19.0
# Undergraduate degree                                   33        12.0
# Further Education (NVQ  A-Level ...)                    3         1.0
# None                                                    1         0.0

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ### What was your academic subject?

# %%
v_to_count, filename = get_count(df, ['edu2. What was your academic subject?'], "one choice", "./../survey_creation/2016/uk/listAnswers/academic_field.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                             Count  Percentage
# What was your academic subject?
# Physical Sciences                             110        41.0
# Computer Sciences                              61        23.0
# Mathematical and Computer Sciences             28        10.0
# Engineering                                    23         9.0
# Biological Sciences                            19         7.0
# Other                                           7         3.0
# Social studies                                  7         3.0
# Combined studies                                7         3.0
# Subjects allied to Medicine                     3         1.0
# Linguistics  Classics and related subjects      2         1.0
# Historical and Philosophical studies            2         1.0
# NaN                                             4         NaN

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ### Enter your academic subject

# %%
 wc = wordcloud(df, ['edu3. Enter your academic subject'])
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f55341a3d68>

# %%
 plt.imshow(wc, interpolation='bilinear')
 plt.axis("off")
# Out:
# (-0.5, 1499.5, 799.5, -0.5)

# %% [markdown]
# ## Group of question: rse

# %% [markdown]
# ### Are you employed primarily to develop software for research?; Do you spend more time developing software than conducting research?; Are you employed as a postdoctoral researcher?; Are you the person who "does computers" in your research group?

# %%
v_to_count, filename = get_count(df, ['rse16a. Are you employed primarily to develop software for research?', 'rse16b. Do you spend more time developing software than conducting research?', 'rse16c. Are you employed as a postdoctoral researcher?', 'rse16d. Are you the person who "does computers" in your research group?'], "y/n/na", "./../survey_creation/2016/uk/listAnswers/.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Yes [Count]  No [Count]  \
# Are you the person who "does computers" in your...
#  Are you employed primarily to develop software...          166         104
#  Do you spend more time developing software tha...          225          40
#  Are you employed as a postdoctoral researcher?              82         181
#  Are you the person who "does computers" in you...          132          85
#
#                                                     NaN value  \
# Are you the person who "does computers" in your...
#  Are you employed primarily to develop software...          3
#  Do you spend more time developing software tha...          8
#  Are you employed as a postdoctoral researcher?            10
#  Are you the person who "does computers" in you...         56
#
#                                                     Yes [Percentage]  \
# Are you the person who "does computers" in your...
#  Are you employed primarily to develop software...              61.0
#  Do you spend more time developing software tha...              85.0
#  Are you employed as a postdoctoral researcher?                 31.0
#  Are you the person who "does computers" in you...              61.0
#
#                                                     No [Percentage]
# Are you the person who "does computers" in your...
#  Are you employed primarily to develop software...             39.0
#  Do you spend more time developing software tha...             15.0
#  Are you employed as a postdoctoral researcher?                69.0
#  Are you the person who "does computers" in you...             39.0

# %%
_ = get_plot(perc_to_count, "y/n/na")

# %% [markdown]
# # Section: 2

# %% [markdown]
# ## Group of question: currentEmp

# %% [markdown]
# ### Do you work for a university?

# %%
v_to_count, filename = get_count(df, ['currentEmp1. Do you work for a university?'], "y/n/na", "./../survey_creation/2016/uk/listAnswers/.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                 Yes [Count]  No [Count]  NaN value  \
# Do you work for a university?
#  Do you work for a university?          203          68          2
#
#                                 Yes [Percentage]  No [Percentage]
# Do you work for a university?
#  Do you work for a university?              75.0             25.0

# %%
_ = get_plot(perc_to_count, "y/n/na")

# %% [markdown]
# ### Which university?

# %%
v_to_count, filename = get_count(df, ['currentEmp2. Which university?'], "one choice", "./../survey_creation/2016/uk/listAnswers/universities.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                     Count  Percentage
# Which university?
# University of Oxford                   50        25.0
# Other/Not listed                       16         8.0
# University of Manchester               13         7.0
# University of Leeds                    13         7.0
# University of Edinburgh                11         6.0
# University of Southampton              10         5.0
# University of Reading                  10         5.0
# University of London                   10         5.0
# University of St Andrews                9         5.0
# University of Sheffield                 8         4.0
# University of Cambridge                 7         4.0
# Lancaster University                    4         2.0
# Durham University                       4         2.0
# Imperial College London                 4         2.0
# University of Nottingham                3         2.0
# University of Glasgow                   3         2.0
# University of Bristol                   3         2.0
# University of Hull                      2         1.0
# University of York                      2         1.0
# Brunel University                       2         1.0
# University of Sussex                    1         1.0
# Aberystwyth University                  1         1.0
# University of Strathclyde               1         1.0
# University of Liverpool                 1         1.0
# Queen&#039;s University Belfast         1         1.0
# Northumbria University                  1         1.0
# University of Dundee                    1         1.0
# Newcastle University                    1         1.0
# Heriot-Watt University                  1         1.0
# University of Bath                      1         1.0
# University of Kent                      1         1.0
# Manchester Metropolitan University      1         1.0
# Cranfield University                    1         1.0
# NaN                                    76         NaN

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ### Which organisation do you work for?

# %%
v_to_count, filename = get_count(df, ['currentEmp4. Which organisation do you work for?'], "one choice", "./../survey_creation/2016/uk/listAnswers/type_organisation.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Count  Percentage
# Which organisation do you work for?
# University College London                               3        19.0
# King's College London                                   3        19.0
# UCL                                                     2        12.0
# Kings College London + Biomedical Research Centre       1         6.0
# University of Reading                                   1         6.0
# Contract for Collegio Carlo Alberto, Itlay but ...      1         6.0
# Univestiry College London                               1         6.0
# Queen Mary University London                            1         6.0
# Bogor Agricultural University (IPB), Indonesia          1         6.0
# Birkbeck, University of London                          1         6.0
# Not saying                                              1         6.0
# NaN                                                   257         NaN

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ### In what year did you start your current position?

# %%
v_to_count, filename = get_count(df, ['currentEmp16a. In what year did you start your current position?'], "freenumeric", "./../survey_creation/2016/uk/listAnswers/.csv", "False", "./2016/uk/output/")

# %%
_ = get_plot(v_to_count, "freenumeric")
# Out:
#        currentEmp16a. In what year did you start your current position?
# count                                         272.000000
# mean                                         2010.852941
# std                                             5.376633
# min                                          1987.000000
# 25%                                          2009.000000
# 50%                                          2013.000000
# 75%                                          2014.000000
# max                                          2016.000000

# %% [markdown]
# ### What is the duration of your current contract?

# %%
v_to_count, filename = get_count(df, ['currentEmp11. What is the duration of your current contract?'], "freenumeric", "./../survey_creation/2016/uk/listAnswers/.csv", "False", "./2016/uk/output/")

# %%
_ = get_plot(v_to_count, "freenumeric")
# Out:
#        currentEmp11. What is the duration of your current contract?
# count                                         123.000000
# mean                                           28.178862
# std                                            15.718858
# min                                             2.000000
# 25%                                            13.000000
# 50%                                            24.000000
# 75%                                            36.000000
# max                                            96.000000

# %% [markdown]
# ### Do you work full time or part time?

# %%
v_to_count, filename = get_count(df, ['currentEmp12. Do you work full time or part time?'], "one choice", "./../survey_creation/2016/uk/listAnswers/type_hours.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                      Count  Percentage
# Do you work full time or part time?
# Full time                              258        95.0
# Part time                               14         5.0
# NaN                                      1         NaN

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ### Is this your first job?

# %%
v_to_count, filename = get_count(df, ['currentEmp16b. Is this your first job?'], "y/n/na", "./../survey_creation/2016/uk/listAnswers/.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                           Yes [Count]  No [Count]  NaN value  \
# Is this your first job?
#  Is this your first job?           47         225          1
#
#                           Yes [Percentage]  No [Percentage]
# Is this your first job?
#  Is this your first job?              17.0             83.0

# %%
_ = get_plot(perc_to_count, "y/n/na")

# %% [markdown]
# ## Group of question: prevEmp

# %% [markdown]
# ### Why did you leave the private sector?

# %%
v_to_count, filename = get_count(df, ['prevEmp16b. Why did you leave the private sector?'], "one choice", "./../survey_creation/2016/uk/listAnswers/reasons_leave_job.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Count  Percentage
# Why did you leave the private sector?
# Others                                                 76        68.0
# Mismatch between description and promise during...     12        11.0
# Lack of opportunity to advance                          9         8.0
# Loss of faith and confidence in corporate leaders       8         7.0
# Excessive overtime hours                                5         5.0
# A work environment that does not encourage team...      1         1.0
# NaN                                                   162         NaN

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ### What was the official job title of your previous job (i.e. the job title stated on your contact of employment)?

# %%
 wc = wordcloud(df, ['prevEmp16c. What was the official job title of your previous job (i.e. the job title stated on your contact of employment)?'])
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f552af4ef60>

# %%
 plt.imshow(wc, interpolation='bilinear')
 plt.axis("off")
# Out:
# (-0.5, 1499.5, 799.5, -0.5)

# %% [markdown]
# ### What was the type of your contract?

# %%
v_to_count, filename = get_count(df, ['prevEmp16d. What was the type of your contract?'], "one choice", "./../survey_creation/2016/uk/listAnswers/type_contract.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                      Count  Percentage
# What was the type of your contract?
# Permanent                              116        52.0
# Fixed-term                              92        41.0
# Freelancer  consultant  contractors     13         6.0
# Zero hour contract                       2         1.0
# NaN                                     50         NaN

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# # Section: 3

# %% [markdown]
# ## Group of question: currentEmp

# %% [markdown]
# ### What is this job title?

# %%
 wc = wordcloud(df, ['currentEmp5. What is your official job title (i.e. the job title on your contract of employment)?', 'currentEmp5. What is this job title?'])
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f553434e978>

# %%
 plt.imshow(wc, interpolation='bilinear')
 plt.axis("off")
# Out:
# (-0.5, 1499.5, 799.5, -0.5)

# %% [markdown]
# ### Are you known in your group by a different job title (e.g. the job title on your group website or business cards)?

# %%
v_to_count, filename = get_count(df, ['currentEmp6. Are you known in your group by a different job title (e.g. the job title on your group website or business cards)?'], "y/n/na", "./../survey_creation/2016/uk/listAnswers/.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Yes [Count]  No [Count]  \
# Are you known in your group by a different job ...
#  Are you known in your group by a different job...           37         235
#
#                                                     NaN value  \
# Are you known in your group by a different job ...
#  Are you known in your group by a different job...          1
#
#                                                     Yes [Percentage]  \
# Are you known in your group by a different job ...
#  Are you known in your group by a different job...              14.0
#
#                                                     No [Percentage]
# Are you known in your group by a different job ...
#  Are you known in your group by a different job...             86.0

# %%
_ = get_plot(perc_to_count, "y/n/na")

# %% [markdown]
# ## Group of question: currentWork

# %% [markdown]
# ### What percentage of your time do you spend developing software each week?

# %%
 wc = wordcloud(df, ['currentWork16a. What percentage of your time do you spend developing software each week?'])
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f552af1ccf8>

# %%
 plt.imshow(wc, interpolation='bilinear')
 plt.axis("off")
# Out:
# (-0.5, 1499.5, 799.5, -0.5)

# %% [markdown]
# ## Group of question: paper

# %% [markdown]
# ### Were you acknowledged in the paper?; Were you named as a co-author of the paper?; Were you named as the lead author of the paper?

# %%
v_to_count, filename = get_count(df, ['paper2. Were you acknowledged in the paper?', 'paper4. Were you named as a co-author of the paper?', 'paper5. Were you named as the lead author of the paper?'], "y/n/na", "./../survey_creation/2016/uk/listAnswers/.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                   Yes [Count]  No [Count]  \
# Publications
#  Were you acknowledged in the paper?                      182          55
#  Were you named as a co-author of the paper?              170          69
#  Were you named as the lead author of the paper?          103         135
#
#                                                   NaN value  Yes [Percentage]  \
# Publications
#  Were you acknowledged in the paper?                     36              77.0
#  Were you named as a co-author of the paper?             34              71.0
#  Were you named as the lead author of the paper?         35              43.0
#
#                                                   No [Percentage]
# Publications
#  Were you acknowledged in the paper?                         23.0
#  Were you named as a co-author of the paper?                 29.0
#  Were you named as the lead author of the paper?             57.0

# %%
_ = get_plot(perc_to_count, "y/n/na")

# %% [markdown]
# ## Group of question: stability

# %% [markdown]
# ### What is the bus factor of your most important software project?

# %%
v_to_count, filename = get_count(df, ['stability1. What is the bus factor of your most important software project?'], "likert", "./../survey_creation/2016/uk/listAnswers/bus_factor.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Count  Percentage
# What is the bus factor of your most important s...
# 1                                                   124.0        50.0
# 2                                                    82.0        33.0
# 3                                                    32.0        13.0
# 4                                                    12.0         5.0
# 5+                                                    NaN         0.0

# %%
_ = get_plot(v_to_count, "likert")

# %% [markdown]
# # Section: 4

# %% [markdown]
# ## Group of question: perfCheck

# %% [markdown]
# ### Do you receive sufficient information on the results of your work?; Does your work give you the opportunity to check on how well you are doing your work?

# %%
v_to_count, filename = get_count(df, ['perfCheck1. Do you receive sufficient information on the results of your work?', 'perfCheck2. Does your work give you the opportunity to check on how well you are doing your work?'], "likert", "./../survey_creation/2016/uk/listAnswers/likert_time_5.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)
# Out:
# /home/olivier/git/ssi/international-survey/analysis/include/likertScalePlot.py:143: RuntimeWarning: invalid value encountered in double_scalars
#   return [((x /total) *100) for x in row]

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                      Do you receive sufficient information on the results of your work? [Count]  \
# Do you receive sufficient information on the re...
# Never                                                                                             NaN
# Sometimes                                                                                        99.0
# Often                                                                                            82.0
# Very Often                                                                                       54.0
# Always                                                                                           29.0
#
#                                                      Does your work give you the opportunity to check on how well you are doing your work? [Count]  \
# Do you receive sufficient information on the re...
# Never                                                                                             NaN
# Sometimes                                                                                       107.0
# Often                                                                                            67.0
# Very Often                                                                                       60.0
# Always                                                                                           23.0
#
#                                                      Do you receive sufficient information on the results of your work? [Percentage]  \
# Do you receive sufficient information on the re...
# Never                                                                                             NaN
# Sometimes                                                                                        48.0
# Often                                                                                            55.0
# Very Often                                                                                       47.0
# Always                                                                                           56.0
#
#                                                      Does your work give you the opportunity to check on how well you are doing your work? [Percentage]
# Do you receive sufficient information on the re...
# Never                                                                                             NaN
# Sometimes                                                                                        52.0
# Often                                                                                            45.0
# Very Often                                                                                       53.0
# Always                                                                                           44.0

# %%
_ = get_plot(v_to_count, "likert")

# %% [markdown]
# ## Group of question: turnOver

# %% [markdown]
# ### How often do you feel frustrated when not given the opportunity to achieve your personal work-related goals?; How often do you look forward to another day at work?

# %%
v_to_count, filename = get_count(df, ['turnOver1. How often do you feel frustrated when not given the opportunity to achieve your personal work-related goals?', 'turnOver2. How often do you look forward to another day at work?'], "likert", "./../survey_creation/2016/uk/listAnswers/likert_time_5.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                      How often do you feel frustrated when not given the opportunity to achieve your personal work-related goals? [Count]  \
# How often do you look forward to another day at...
# Never                                                                                             NaN
# Sometimes                                                                                       129.0
# Often                                                                                            54.0
# Very Often                                                                                       50.0
# Always                                                                                           23.0
#
#                                                      How often do you look forward to another day at work? [Count]  \
# How often do you look forward to another day at...
# Never                                                                                            27.0
# Sometimes                                                                                       145.0
# Often                                                                                            83.0
# Very Often                                                                                        NaN
# Always                                                                                            NaN
#
#                                                      How often do you feel frustrated when not given the opportunity to achieve your personal work-related goals? [Percentage]  \
# How often do you look forward to another day at...
# Never                                                                                             0.0
# Sometimes                                                                                        47.0
# Often                                                                                            39.0
# Very Often                                                                                      100.0
# Always                                                                                          100.0
#
#                                                      How often do you look forward to another day at work? [Percentage]
# How often do you look forward to another day at...
# Never                                                                                           100.0
# Sometimes                                                                                        53.0
# Often                                                                                            61.0
# Very Often                                                                                        0.0
# Always                                                                                            0.0

# %%
_ = get_plot(v_to_count, "likert")

# %% [markdown]
# ## Group of question: affRec

# %% [markdown]
# ### I am satisfied with my supervisor/line manager's confidence in me; I am satisfied with a word of thanks from my supervisor/line manager

# %%
v_to_count, filename = get_count(df, ["affRec1. I am satisfied with my supervisor/line manager's confidence in me", 'affRec2. I am satisfied with a word of thanks from my supervisor/line manager'], "likert", "./../survey_creation/2016/uk/listAnswers/likert_agree.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                             I am satisfied with my supervisor/line manager's confidence in me [Count]  \
# Affective recognition
# Strongly disagree                                                         15
# Disagree                                                                  30
# Neither agree or disagree                                                 37
# Agree                                                                     86
# Strongly Agree                                                           103
#
#                             I am satisfied with a word of thanks from my supervisor/line manager [Count]  \
# Affective recognition
# Strongly disagree                                                         19
# Disagree                                                                  35
# Neither agree or disagree                                                 72
# Agree                                                                     95
# Strongly Agree                                                            50
#
#                             I am satisfied with my supervisor/line manager's confidence in me [Percentage]  \
# Affective recognition
# Strongly disagree                                                       44.0
# Disagree                                                                46.0
# Neither agree or disagree                                               34.0
# Agree                                                                   48.0
# Strongly Agree                                                          67.0
#
#                             I am satisfied with a word of thanks from my supervisor/line manager [Percentage]
# Affective recognition
# Strongly disagree                                                       56.0
# Disagree                                                                54.0
# Neither agree or disagree                                               66.0
# Agree                                                                   52.0
# Strongly Agree                                                          33.0

# %%
_ = get_plot(v_to_count, "likert")

# %% [markdown]
# ## Group of question: percEmp

# %% [markdown]
# ### It would not be very difficult for me to get an equivalent job in a different organisation; I can think of a number of organisations that would probably offer me a job; My experience is in demand on the labour market

# %%
v_to_count, filename = get_count(df, ['percEmp1. It would not be very difficult for me to get an equivalent job in a different organisation', 'percEmp2. I can think of a number of organisations that would probably offer me a job', 'percEmp3. My experience is in demand on the labour market'], "likert", "./../survey_creation/2016/uk/listAnswers/likert_agree.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                      It would not be very difficult for me to get an equivalent job in a different organisation [Count]  \
# I can think of a number of organisations that w...
# Strongly disagree                                                                                  22
# Disagree                                                                                           48
# Neither agree or disagree                                                                          70
# Agree                                                                                              75
# Strongly Agree                                                                                     56
#
#                                                      I can think of a number of organisations that would probably offer me a job [Count]  \
# I can think of a number of organisations that w...
# Strongly disagree                                                                                  15
# Disagree                                                                                           32
# Neither agree or disagree                                                                          67
# Agree                                                                                             102
# Strongly Agree                                                                                     55
#
#                                                      My experience is in demand on the labour market [Count]  \
# I can think of a number of organisations that w...
# Strongly disagree                                                                                  13
# Disagree                                                                                           13
# Neither agree or disagree                                                                          76
# Agree                                                                                             108
# Strongly Agree                                                                                     61
#
#                                                      It would not be very difficult for me to get an equivalent job in a different organisation [Percentage]  \
# I can think of a number of organisations that w...
# Strongly disagree                                                                                44.0
# Disagree                                                                                         52.0
# Neither agree or disagree                                                                        33.0
# Agree                                                                                            26.0
# Strongly Agree                                                                                   33.0
#
#                                                      I can think of a number of organisations that would probably offer me a job [Percentage]  \
# I can think of a number of organisations that w...
# Strongly disagree                                                                                30.0
# Disagree                                                                                         34.0
# Neither agree or disagree                                                                        31.0
# Agree                                                                                            36.0
# Strongly Agree                                                                                   32.0
#
#                                                      My experience is in demand on the labour market [Percentage]
# I can think of a number of organisations that w...
# Strongly disagree                                                                                26.0
# Disagree                                                                                         14.0
# Neither agree or disagree                                                                        36.0
# Agree                                                                                            38.0
# Strongly Agree                                                                                   35.0

# %%
_ = get_plot(v_to_count, "likert")

# %% [markdown]
# ## Group of question: affSat

# %% [markdown]
# ### I find real enjoyment in my job; Most days I am enthusiastic about my job; I feel fairly well satisfied with my job

# %%
v_to_count, filename = get_count(df, ['affSat1. I find real enjoyment in my job', 'affSat2. Most days I am enthusiastic about my job', 'affSat3. I feel fairly well satisfied with my job'], "likert", "./../survey_creation/2016/uk/listAnswers/likert_agree.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                   I find real enjoyment in my job [Count]  \
# I find real enjoyment in my job
# Strongly disagree                                                       8
# Disagree                                                               30
# Neither agree or disagree                                              58
# Agree                                                                 103
# Strongly Agree                                                         72
#
#                                   Most days I am enthusiastic about my job [Count]  \
# I find real enjoyment in my job
# Strongly disagree                                                               17
# Disagree                                                                        30
# Neither agree or disagree                                                       54
# Agree                                                                          115
# Strongly Agree                                                                  55
#
#                                   I feel fairly well satisfied with my job [Count]  \
# I find real enjoyment in my job
# Strongly disagree                                                               10
# Disagree                                                                        40
# Neither agree or disagree                                                       61
# Agree                                                                          104
# Strongly Agree                                                                  56
#
#                                   I find real enjoyment in my job [Percentage]  \
# I find real enjoyment in my job
# Strongly disagree                                                         23.0
# Disagree                                                                  30.0
# Neither agree or disagree                                                 34.0
# Agree                                                                     32.0
# Strongly Agree                                                            39.0
#
#                                   Most days I am enthusiastic about my job [Percentage]  \
# I find real enjoyment in my job
# Strongly disagree                                                             49.0
# Disagree                                                                      30.0
# Neither agree or disagree                                                     31.0
# Agree                                                                         36.0
# Strongly Agree                                                                30.0
#
#                                   I feel fairly well satisfied with my job [Percentage]
# I find real enjoyment in my job
# Strongly disagree                                                             29.0
# Disagree                                                                      40.0
# Neither agree or disagree                                                     35.0
# Agree                                                                         32.0
# Strongly Agree                                                                31.0

# %%
_ = get_plot(v_to_count, "likert")

# %% [markdown]
# ## Group of question: progRSE

# %% [markdown]
# ### My current position is an integral part of my career plan; It is likely that my next position will be an RSE role

# %%
v_to_count, filename = get_count(df, ['progRSE4. My current position is an integral part of my career plan', 'progRSE5. It is likely that my next position will be an RSE role'], "likert", "./../survey_creation/2016/uk/listAnswers/likert_agree.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                      My current position is an integral part of my career plan [Count]  \
# It is likely that my next position will be an R...
# Strongly disagree                                                                                  21
# Disagree                                                                                           35
# Neither agree or disagree                                                                          74
# Agree                                                                                              80
# Strongly Agree                                                                                     61
#
#                                                      It is likely that my next position will be an RSE role [Count]  \
# It is likely that my next position will be an R...
# Strongly disagree                                                                                  21
# Disagree                                                                                           44
# Neither agree or disagree                                                                          85
# Agree                                                                                              80
# Strongly Agree                                                                                     41
#
#                                                      My current position is an integral part of my career plan [Percentage]  \
# It is likely that my next position will be an R...
# Strongly disagree                                                                                50.0
# Disagree                                                                                         44.0
# Neither agree or disagree                                                                        47.0
# Agree                                                                                            50.0
# Strongly Agree                                                                                   60.0
#
#                                                      It is likely that my next position will be an RSE role [Percentage]
# It is likely that my next position will be an R...
# Strongly disagree                                                                                50.0
# Disagree                                                                                         56.0
# Neither agree or disagree                                                                        53.0
# Agree                                                                                            50.0
# Strongly Agree                                                                                   40.0

# %%
_ = get_plot(v_to_count, "likert")

# %% [markdown]
# # Section: 5

# %% [markdown]
# ## Group of question: perfCheck

# %% [markdown]
# ### Do you receive sufficient information on the purpose of your work?; Does your work provide you with direct feedback on how well you are doing your work?; Does your supervisor/line manager inform you about how well you are doing your work?; Do your colleagues inform you about how well you are doing your work?

# %%
v_to_count, filename = get_count(df, ['perfCheck4. Do you receive sufficient information on the purpose of your work?', 'perfCheck5. Does your work provide you with direct feedback on how well you are doing your work?', 'perfCheck6. Does your supervisor/line manager inform you about how well you are doing your work?', 'perfCheck7. Do your colleagues inform you about how well you are doing your work?'], "likert", "./../survey_creation/2016/uk/listAnswers/likert_time_5.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)
# Out:
# /home/olivier/git/ssi/international-survey/analysis/include/likertScalePlot.py:143: RuntimeWarning: invalid value encountered in double_scalars
#   return [((x /total) *100) for x in row]

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                      Do you receive sufficient information on the purpose of your work? [Count]  \
# Does your supervisor/line manager inform you ab...
# Never                                                                                             NaN
# Sometimes                                                                                        56.0
# Often                                                                                            65.0
# Very Often                                                                                       92.0
# Always                                                                                           53.0
#
#                                                      Does your work provide you with direct feedback on how well you are doing your work? [Count]  \
# Does your supervisor/line manager inform you ab...
# Never                                                                                             NaN
# Sometimes                                                                                        93.0
# Often                                                                                            81.0
# Very Often                                                                                       61.0
# Always                                                                                           25.0
#
#                                                      Does your supervisor/line manager inform you about how well you are doing your work? [Count]  \
# Does your supervisor/line manager inform you ab...
# Never                                                                                             NaN
# Sometimes                                                                                       100.0
# Often                                                                                            69.0
# Very Often                                                                                       61.0
# Always                                                                                           21.0
#
#                                                      Do your colleagues inform you about how well you are doing your work? [Count]  \
# Does your supervisor/line manager inform you ab...
# Never                                                                                             NaN
# Sometimes                                                                                        94.0
# Often                                                                                            74.0
# Very Often                                                                                       50.0
# Always                                                                                           11.0
#
#                                                      Do you receive sufficient information on the purpose of your work? [Percentage]  \
# Does your supervisor/line manager inform you ab...
# Never                                                                                             NaN
# Sometimes                                                                                        16.0
# Often                                                                                            22.0
# Very Often                                                                                       35.0
# Always                                                                                           48.0
#
#                                                      Does your work provide you with direct feedback on how well you are doing your work? [Percentage]  \
# Does your supervisor/line manager inform you ab...
# Never                                                                                             NaN
# Sometimes                                                                                        27.0
# Often                                                                                            28.0
# Very Often                                                                                       23.0
# Always                                                                                           23.0
#
#                                                      Does your supervisor/line manager inform you about how well you are doing your work? [Percentage]  \
# Does your supervisor/line manager inform you ab...
# Never                                                                                             NaN
# Sometimes                                                                                        29.0
# Often                                                                                            24.0
# Very Often                                                                                       23.0
# Always                                                                                           19.0
#
#                                                      Do your colleagues inform you about how well you are doing your work? [Percentage]
# Does your supervisor/line manager inform you ab...
# Never                                                                                             NaN
# Sometimes                                                                                        27.0
# Often                                                                                            26.0
# Very Often                                                                                       19.0
# Always                                                                                           10.0

# %%
_ = get_plot(v_to_count, "likert")

# %% [markdown]
# ## Group of question: turnOver

# %% [markdown]
# ### How often do you consider leaving your job?; How often do dream about getting another job that will better suit your needs?

# %%
v_to_count, filename = get_count(df, ['turnOver3. How often do you consider leaving your job?', 'turnOver4. How often do dream about getting another job that will better suit your needs?'], "likert", "./../survey_creation/2016/uk/listAnswers/likert_time_5.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                      How often do you consider leaving your job? [Count]  \
# How often do dream about getting another job th...
# Never                                                                                            15.0
# Sometimes                                                                                       162.0
# Often                                                                                            37.0
# Very Often                                                                                        NaN
# Always                                                                                            NaN
#
#                                                      How often do dream about getting another job that will better suit your needs? [Count]  \
# How often do dream about getting another job th...
# Never                                                                                             NaN
# Sometimes                                                                                       114.0
# Often                                                                                            42.0
# Very Often                                                                                       54.0
# Always                                                                                           24.0
#
#                                                      How often do you consider leaving your job? [Percentage]  \
# How often do dream about getting another job th...
# Never                                                                                           100.0
# Sometimes                                                                                        59.0
# Often                                                                                            47.0
# Very Often                                                                                        0.0
# Always                                                                                            0.0
#
#                                                      How often do dream about getting another job that will better suit your needs? [Percentage]
# How often do dream about getting another job th...
# Never                                                                                             0.0
# Sometimes                                                                                        41.0
# Often                                                                                            53.0
# Very Often                                                                                      100.0
# Always                                                                                          100.0

# %%
_ = get_plot(v_to_count, "likert")

# %% [markdown]
# ### My current job satisfies my personal needs; I would accept another job at the same compensation level if I was offered it

# %%
v_to_count, filename = get_count(df, ['turnOver5. My current job satisfies my personal needs', 'turnOver6. I would accept another job at the same compensation level if I was offered it'], "likert", "./../survey_creation/2016/uk/listAnswers/likert_agree.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                              My current job satisfies my personal needs [Count]  \
# My current job satisfies my personal needs
# Strongly disagree                                                                          21
# Disagree                                                                                   50
# Neither agree or disagree                                                                  60
# Agree                                                                                      97
# Strongly Agree                                                                             44
#
#                                              I would accept another job at the same compensation level if I was offered it [Count]  \
# My current job satisfies my personal needs
# Strongly disagree                                                                          56
# Disagree                                                                                   71
# Neither agree or disagree                                                                  79
# Agree                                                                                      47
# Strongly Agree                                                                             19
#
#                                              My current job satisfies my personal needs [Percentage]  \
# My current job satisfies my personal needs
# Strongly disagree                                                                        27.0
# Disagree                                                                                 41.0
# Neither agree or disagree                                                                43.0
# Agree                                                                                    67.0
# Strongly Agree                                                                           70.0
#
#                                              I would accept another job at the same compensation level if I was offered it [Percentage]
# My current job satisfies my personal needs
# Strongly disagree                                                                        73.0
# Disagree                                                                                 59.0
# Neither agree or disagree                                                                57.0
# Agree                                                                                    33.0
# Strongly Agree                                                                           30.0

# %%
_ = get_plot(v_to_count, "likert")

# %% [markdown]
# ## Group of question: affRec

# %% [markdown]
# ### I am satisfied with the recognition I receive from my supervisor/line manager for doing my job; I am satisfied with the compliments from my supervisor/line manager concerning my work; I am satisfied with the encouragement from my supervisor/line manager while doing my job

# %%
v_to_count, filename = get_count(df, ['affRec3. I am satisfied with the recognition I receive from my supervisor/line manager for doing my job', 'affRec4. I am satisfied with the compliments from my supervisor/line manager concerning my work', 'affRec5. I am satisfied with the encouragement from my supervisor/line manager while doing my job'], "likert", "./../survey_creation/2016/uk/listAnswers/likert_agree.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                             I am satisfied with the recognition I receive from my supervisor/line manager for doing my job [Count]  \
# Affective recognition
# Strongly disagree                                                         20
# Disagree                                                                  33
# Neither agree or disagree                                                 65
# Agree                                                                    111
# Strongly Agree                                                            43
#
#                             I am satisfied with the compliments from my supervisor/line manager concerning my work [Count]  \
# Affective recognition
# Strongly disagree                                                         20
# Disagree                                                                  29
# Neither agree or disagree                                                 72
# Agree                                                                    101
# Strongly Agree                                                            50
#
#                             I am satisfied with the encouragement from my supervisor/line manager while doing my job [Count]  \
# Affective recognition
# Strongly disagree                                                         16
# Disagree                                                                  41
# Neither agree or disagree                                                 65
# Agree                                                                    108
# Strongly Agree                                                            42
#
#                             I am satisfied with the recognition I receive from my supervisor/line manager for doing my job [Percentage]  \
# Affective recognition
# Strongly disagree                                                       36.0
# Disagree                                                                32.0
# Neither agree or disagree                                               32.0
# Agree                                                                   35.0
# Strongly Agree                                                          32.0
#
#                             I am satisfied with the compliments from my supervisor/line manager concerning my work [Percentage]  \
# Affective recognition
# Strongly disagree                                                       36.0
# Disagree                                                                28.0
# Neither agree or disagree                                               36.0
# Agree                                                                   32.0
# Strongly Agree                                                          37.0
#
#                             I am satisfied with the encouragement from my supervisor/line manager while doing my job [Percentage]
# Affective recognition
# Strongly disagree                                                       29.0
# Disagree                                                                40.0
# Neither agree or disagree                                               32.0
# Agree                                                                   34.0
# Strongly Agree                                                          31.0

# %%
_ = get_plot(v_to_count, "likert")

# %% [markdown]
# ## Group of question: affSat

# %% [markdown]
# ### I like my job better than the average person

# %%
v_to_count, filename = get_count(df, ['affSat4. I like my job better than the average person'], "likert", "./../survey_creation/2016/uk/listAnswers/likert_agree.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                               Count  Percentage
# I like my job better than the average person
# Strongly disagree                                11         4.0
# Disagree                                         20         7.0
# Neither agree or disagree                        79        29.0
# Agree                                           101        37.0
# Strongly Agree                                   61        22.0

# %%
_ = get_plot(v_to_count, "likert")

# %% [markdown]
# ## Group of question: progRSE

# %% [markdown]
# ### It is likely that I will gain a promotion within my current group; The process I have to complete to gain a promotion is clear and understandable; There are many opportunities within my chosen career plan

# %%
v_to_count, filename = get_count(df, ['progRSE1. It is likely that I will gain a promotion within my current group', 'progRSE2. The process I have to complete to gain a promotion is clear and understandable', 'progRSE3. There are many opportunities within my chosen career plan'], "likert", "./../survey_creation/2016/uk/listAnswers/likert_agree.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                      It is likely that I will gain a promotion within my current group [Count]  \
# It is likely that I will gain a promotion withi...
# Strongly disagree                                                                                  94
# Disagree                                                                                           67
# Neither agree or disagree                                                                          61
# Agree                                                                                              38
# Strongly Agree                                                                                     12
#
#                                                      The process I have to complete to gain a promotion is clear and understandable [Count]  \
# It is likely that I will gain a promotion withi...
# Strongly disagree                                                                                  85
# Disagree                                                                                           78
# Neither agree or disagree                                                                          53
# Agree                                                                                              38
# Strongly Agree                                                                                     18
#
#                                                      There are many opportunities within my chosen career plan [Count]  \
# It is likely that I will gain a promotion withi...
# Strongly disagree                                                                                  40
# Disagree                                                                                           80
# Neither agree or disagree                                                                          85
# Agree                                                                                              44
# Strongly Agree                                                                                     23
#
#                                                      It is likely that I will gain a promotion within my current group [Percentage]  \
# It is likely that I will gain a promotion withi...
# Strongly disagree                                                                                43.0
# Disagree                                                                                         30.0
# Neither agree or disagree                                                                        31.0
# Agree                                                                                            32.0
# Strongly Agree                                                                                   23.0
#
#                                                      The process I have to complete to gain a promotion is clear and understandable [Percentage]  \
# It is likely that I will gain a promotion withi...
# Strongly disagree                                                                                39.0
# Disagree                                                                                         35.0
# Neither agree or disagree                                                                        27.0
# Agree                                                                                            32.0
# Strongly Agree                                                                                   34.0
#
#                                                      There are many opportunities within my chosen career plan [Percentage]
# It is likely that I will gain a promotion withi...
# Strongly disagree                                                                                18.0
# Disagree                                                                                         36.0
# Neither agree or disagree                                                                        43.0
# Agree                                                                                            37.0
# Strongly Agree                                                                                   43.0

# %%
_ = get_plot(v_to_count, "likert")

# %% [markdown]
# # Section: 6

# %% [markdown]
# ## Group of question: skill

# %% [markdown]
# ### In your opinion, what are the three most important skills that a Research Software Engineer must possess?

# %%
 wc = wordcloud(df, ['skill2. In your opinion, what are the three most important skills that a Research Software Engineer must possess?'])
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f552abedc88>

# %%
 plt.imshow(wc, interpolation='bilinear')
 plt.axis("off")
# Out:
# (-0.5, 1499.5, 799.5, -0.5)

# %% [markdown]
# ### In your opinion, what are the three most important skills that a Research Software Engineer must possess?

# %%
 wc = wordcloud(df, ['skill2-1. In your opinion, what are the three most important skills that a Research Software Engineer must possess?'])
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f552af64cf8>

# %%
 plt.imshow(wc, interpolation='bilinear')
 plt.axis("off")
# Out:
# (-0.5, 1499.5, 799.5, -0.5)

# %% [markdown]
# ### In your opinion, what are the three most important skills that a Research Software Engineer must possess?

# %%
 wc = wordcloud(df, ['skill2-2. In your opinion, what are the three most important skills that a Research Software Engineer must possess?'])
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f552affdba8>

# %%
 plt.imshow(wc, interpolation='bilinear')
 plt.axis("off")
# Out:
# (-0.5, 1499.5, 799.5, -0.5)

# %% [markdown]
# ## Group of question: ukrse

# %% [markdown]
# ### Are you a member of the UK RSE Association? (Members are people who have signed up to the UK RSE mailing list)

# %%
v_to_count, filename = get_count(df, ['ukrse1. Are you a member of the UK RSE Association? (Members are people who have signed up to the UK RSE mailing list)'], "y/n/na", "./../survey_creation/2016/uk/listAnswers/.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Yes [Count]  No [Count]  \
# Are you a member of the UK RSE Association? (Me...
#  Are you a member of the UK RSE Association? (M...          131         138
#
#                                                     NaN value  \
# Are you a member of the UK RSE Association? (Me...
#  Are you a member of the UK RSE Association? (M...          4
#
#                                                     Yes [Percentage]  \
# Are you a member of the UK RSE Association? (Me...
#  Are you a member of the UK RSE Association? (M...              49.0
#
#                                                     No [Percentage]
# Are you a member of the UK RSE Association? (Me...
#  Are you a member of the UK RSE Association? (M...             51.0

# %%
_ = get_plot(perc_to_count, "y/n/na")

# %% [markdown]
# ## Group of question: socio

# %% [markdown]
# ### Please select your gender

# %%
v_to_count, filename = get_count(df, ['socio2. Please select your gender'], "one choice", "./../survey_creation/2016/uk/listAnswers/gender.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                            Count  Percentage
# Please select your gender
# Male                         232        88.0
# Female                        30        11.0
# Other                          1         0.0
# NaN                           10         NaN

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ### Please select your age

# %%
v_to_count, filename = get_count(df, ['socio3. Please select your age'], "one choice", "./../survey_creation/2016/uk/listAnswers/age.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                         Count  Percentage
# Please select your age
# 35 to 44 years            107        40.0
# 25 to 34 years             97        36.0
# 45 to 54 years             51        19.0
# 55 to 64 years             11         4.0
# 18 to 24 years              4         1.0
# NaN                         3         NaN

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ### Please select the range of your salary

# %%
v_to_count, filename = get_count(df, ['socio4. Please select the range of your salary'], "one choice", "./../survey_creation/2016/uk/listAnswers/salary.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                         Count  Percentage
# Please select the range of your salary
# £30 000 to £34 999                         81        30.0
# £35 000 to £39 999                         68        25.0
# £40 000 to £44 999                         38        14.0
# £45 000 to £50 000                         31        11.0
# £25 000 to £29 999                         21         8.0
# Less than £25 000                          10         4.0
# £50 000 to £59 999                          9         3.0
# Prefer not to say                           8         3.0
# £60 000 to £69 999                          3         1.0
# £70 000 to £99 000                          1         0.0
# NaN                                         3         NaN

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ## Group of question: tool

# %% [markdown]
# ### What is your Operating System of choice for use at work?

# %%
v_to_count, filename = get_count(df, ['tool2. What is your Operating System of choice for use at work?'], "one choice", "./../survey_creation/2016/uk/listAnswers/os.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Count  Percentage
# What is your Operating System of choice for use...
# GNU/Linux                                             161        59.0
# Windows                                                55        20.0
# OS X                                                   53        20.0
# Other                                                   2         1.0
# NaN                                                     2         NaN

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# # Section: 7

# %% [markdown]
# ## Group of question: contact

# %% [markdown]
# ### Please enter your email address

# %%
 wc = wordcloud(df, ['contact16b. Please enter your email address'])
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f552aae2da0>

# %%
 plt.imshow(wc, interpolation='bilinear')
 plt.axis("off")
# Out:
# (-0.5, 1499.5, 799.5, -0.5)
