# %% [markdown]
# # Section: Importing modules

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from IPython.display import display
import IPython.core.display as di
from include.config import CleaningConfig, PlottingConfig, NotebookConfig
from include.counting import get_count, get_percentage
from include.plotting import get_plot, display_side_by_side
from include.likertScalePlot import likert_scale
from include.textCleaning import wordcloud

# %%
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)

# %% [markdown]
# This text is used to hide the code cell when exported in html

# %%
di.display_html('<script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>', raw=True)
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>

# %%
get_ipython().magic('matplotlib inline')  # Activate that line to use in Jupyter 
matplotlib.rcParams['figure.figsize'] = (15.0, 8.0)

# %% [markdown]
# # Loading dataset

# %%
df =  pd.read_csv('./2016/uk/data/cleaned_data.csv')

# %% [markdown]
# The total of participant after cleaning the dataset. Remove all participants that have not completed the survey passed the first pages and all participants who are not from the country

# %%
len(df)
# Out:
# 273

# %% [markdown]
# # Section: 1

# %% [markdown]
# ## Group of question: socio

# %% [markdown]
# ### In which country do you live?

# %%
v_to_count, filename  = get_count(df, ['socio1. In which country do you live?'], "one choice", "./../survey_creation/2016/uk/listAnswers/countries.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>In which country do you live?</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>United Kingdom</th>
#       <td>273</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>In which country do you live? [PERCENTAGE]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>United Kingdom [PERCENTAGE]</th>
#       <td>100.0</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ## Group of question: edu

# %% [markdown]
# ### What is the highest qualification you have obtained?

# %%
v_to_count, filename  = get_count(df, ['edu1. What is the highest qualification you have obtained?'], "one choice", "./../survey_creation/2016/uk/listAnswers/education.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>What is the highest qualification you have obtained?</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Doctorate</th>
#       <td>183</td>
#     </tr>
#     <tr>
#       <th>Masters degree</th>
#       <td>53</td>
#     </tr>
#     <tr>
#       <th>Undergraduate degree</th>
#       <td>33</td>
#     </tr>
#     <tr>
#       <th>Further Education (NVQ  A-Level ...)</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>None</th>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>What is the highest qualification you have obtained? [PERCENTAGE]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Doctorate</th>
#       <td>67.03</td>
#     </tr>
#     <tr>
#       <th>Masters degree</th>
#       <td>19.41</td>
#     </tr>
#     <tr>
#       <th>Undergraduate degree</th>
#       <td>12.09</td>
#     </tr>
#     <tr>
#       <th>Further Education (NVQ  A-Level ...)</th>
#       <td>1.10</td>
#     </tr>
#     <tr>
#       <th>None</th>
#       <td>0.37</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ### What was your academic subject?

# %%
v_to_count, filename  = get_count(df, ['edu2. What was your academic subject?'], "one choice", "./../survey_creation/2016/uk/listAnswers/academic_field.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>What was your academic subject?</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Physical Sciences</th>
#       <td>110</td>
#     </tr>
#     <tr>
#       <th>Computer Sciences</th>
#       <td>61</td>
#     </tr>
#     <tr>
#       <th>Mathematical and Computer Sciences</th>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>Engineering</th>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>Biological Sciences</th>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>Other</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Social studies</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Combined studies</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Subjects allied to Medicine</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Historical and Philosophical studies</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Linguistics  Classics and related subjects</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>NaN</th>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>What was your academic subject? [PERCENTAGE]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Physical Sciences</th>
#       <td>40.89</td>
#     </tr>
#     <tr>
#       <th>Computer Sciences</th>
#       <td>22.68</td>
#     </tr>
#     <tr>
#       <th>Mathematical and Computer Sciences</th>
#       <td>10.41</td>
#     </tr>
#     <tr>
#       <th>Engineering</th>
#       <td>8.55</td>
#     </tr>
#     <tr>
#       <th>Biological Sciences</th>
#       <td>7.06</td>
#     </tr>
#     <tr>
#       <th>Other</th>
#       <td>2.60</td>
#     </tr>
#     <tr>
#       <th>Social studies</th>
#       <td>2.60</td>
#     </tr>
#     <tr>
#       <th>Combined studies</th>
#       <td>2.60</td>
#     </tr>
#     <tr>
#       <th>Subjects allied to Medicine</th>
#       <td>1.12</td>
#     </tr>
#     <tr>
#       <th>Historical and Philosophical studies</th>
#       <td>0.74</td>
#     </tr>
#     <tr>
#       <th>Linguistics  Classics and related subjects</th>
#       <td>0.74</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ### Enter your academic subject

# %%
 wc = wordcloud(df, ['edu3. Enter your academic subject'])
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f2575feef60>

# %%
 plt.imshow(wc, interpolation='bilinear')
 plt.axis("off")
# Out:
# (-0.5, 1499.5, 799.5, -0.5)

# %% [markdown]
# ## Group of question: rse

# %% [markdown]
# ### Are you employed primarily to develop software for research?; Do you spend more time developing software than conducting research?; Are you employed as a postdoctoral researcher?; Are you the person who "does computers" in your research group?

# %%
v_to_count, filename  = get_count(df, ['rse16a. Are you employed primarily to develop software for research?', 'rse16b. Do you spend more time developing software than conducting research?', 'rse16c. Are you employed as a postdoctoral researcher?', 'rse16d. Are you the person who "does computers" in your research group?'], "y/n/na", "./../survey_creation/2016/uk/listAnswers/.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Yes</th>
#       <th>No</th>
#       <th>nan</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>rse16a. Are you employed primarily to develop software for research?</th>
#       <td>166</td>
#       <td>104</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>rse16b. Do you spend more time developing software than conducting research?</th>
#       <td>225</td>
#       <td>40</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>rse16c. Are you employed as a postdoctoral researcher?</th>
#       <td>82</td>
#       <td>181</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>rse16d. Are you the person who "does computers" in your research group?</th>
#       <td>132</td>
#       <td>85</td>
#       <td>56</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Yes</th>
#       <th>No</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>rse16a. Are you employed primarily to develop software for research?</th>
#       <td>61.48</td>
#       <td>38.52</td>
#     </tr>
#     <tr>
#       <th>rse16b. Do you spend more time developing software than conducting research?</th>
#       <td>84.91</td>
#       <td>15.09</td>
#     </tr>
#     <tr>
#       <th>rse16c. Are you employed as a postdoctoral researcher?</th>
#       <td>31.18</td>
#       <td>68.82</td>
#     </tr>
#     <tr>
#       <th>rse16d. Are you the person who "does computers" in your research group?</th>
#       <td>60.83</td>
#       <td>39.17</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %%
_ = get_plot(perc_to_count, "y/n/na")

# %% [markdown]
# # Section: 2

# %% [markdown]
# ## Group of question: currentEmp

# %% [markdown]
# ### Do you work for a university?

# %%
v_to_count, filename  = get_count(df, ['currentEmp1. Do you work for a university?'], "y/n/na", "./../survey_creation/2016/uk/listAnswers/.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Yes</th>
#       <th>No</th>
#       <th>nan</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Do you work for a university?</th>
#       <td>203</td>
#       <td>68</td>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Yes</th>
#       <th>No</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Do you work for a university? [PERCENTAGE]</th>
#       <td>74.91</td>
#       <td>25.09</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %%
_ = get_plot(perc_to_count, "y/n/na")

# %% [markdown]
# ### Which university?

# %%
v_to_count, filename  = get_count(df, ['currentEmp2. Which university?'], "one choice", "./../survey_creation/2016/uk/listAnswers/universities.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Which university?</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>University of Oxford</th>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>Other/Not listed</th>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>University of Leeds</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>University of Manchester</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>University of Edinburgh</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>University of Reading</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>University of Southampton</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>University of London</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>University of St Andrews</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>University of Sheffield</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>University of Cambridge</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Lancaster University</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Durham University</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Imperial College London</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>University of Bristol</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>University of Glasgow</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>University of Nottingham</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>University of Hull</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Brunel University</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>University of York</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Manchester Metropolitan University</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Newcastle University</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>University of Sussex</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>University of Kent</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Heriot-Watt University</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Cranfield University</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Queen&amp;#039;s University Belfast</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Aberystwyth University</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>University of Liverpool</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>University of Bath</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Northumbria University</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>University of Dundee</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>University of Strathclyde</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>NaN</th>
#       <td>76</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Which university? [PERCENTAGE]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>University of Oxford</th>
#       <td>25.38</td>
#     </tr>
#     <tr>
#       <th>Other/Not listed</th>
#       <td>8.12</td>
#     </tr>
#     <tr>
#       <th>University of Leeds</th>
#       <td>6.60</td>
#     </tr>
#     <tr>
#       <th>University of Manchester</th>
#       <td>6.60</td>
#     </tr>
#     <tr>
#       <th>University of Edinburgh</th>
#       <td>5.58</td>
#     </tr>
#     <tr>
#       <th>University of Reading</th>
#       <td>5.08</td>
#     </tr>
#     <tr>
#       <th>University of Southampton</th>
#       <td>5.08</td>
#     </tr>
#     <tr>
#       <th>University of London</th>
#       <td>5.08</td>
#     </tr>
#     <tr>
#       <th>University of St Andrews</th>
#       <td>4.57</td>
#     </tr>
#     <tr>
#       <th>University of Sheffield</th>
#       <td>4.06</td>
#     </tr>
#     <tr>
#       <th>University of Cambridge</th>
#       <td>3.55</td>
#     </tr>
#     <tr>
#       <th>Lancaster University</th>
#       <td>2.03</td>
#     </tr>
#     <tr>
#       <th>Durham University</th>
#       <td>2.03</td>
#     </tr>
#     <tr>
#       <th>Imperial College London</th>
#       <td>2.03</td>
#     </tr>
#     <tr>
#       <th>University of Bristol</th>
#       <td>1.52</td>
#     </tr>
#     <tr>
#       <th>University of Glasgow</th>
#       <td>1.52</td>
#     </tr>
#     <tr>
#       <th>University of Nottingham</th>
#       <td>1.52</td>
#     </tr>
#     <tr>
#       <th>University of Hull</th>
#       <td>1.02</td>
#     </tr>
#     <tr>
#       <th>Brunel University</th>
#       <td>1.02</td>
#     </tr>
#     <tr>
#       <th>University of York</th>
#       <td>1.02</td>
#     </tr>
#     <tr>
#       <th>Manchester Metropolitan University</th>
#       <td>0.51</td>
#     </tr>
#     <tr>
#       <th>Newcastle University</th>
#       <td>0.51</td>
#     </tr>
#     <tr>
#       <th>University of Sussex</th>
#       <td>0.51</td>
#     </tr>
#     <tr>
#       <th>University of Kent</th>
#       <td>0.51</td>
#     </tr>
#     <tr>
#       <th>Heriot-Watt University</th>
#       <td>0.51</td>
#     </tr>
#     <tr>
#       <th>Cranfield University</th>
#       <td>0.51</td>
#     </tr>
#     <tr>
#       <th>Queen&amp;#039;s University Belfast</th>
#       <td>0.51</td>
#     </tr>
#     <tr>
#       <th>Aberystwyth University</th>
#       <td>0.51</td>
#     </tr>
#     <tr>
#       <th>University of Liverpool</th>
#       <td>0.51</td>
#     </tr>
#     <tr>
#       <th>University of Bath</th>
#       <td>0.51</td>
#     </tr>
#     <tr>
#       <th>Northumbria University</th>
#       <td>0.51</td>
#     </tr>
#     <tr>
#       <th>University of Dundee</th>
#       <td>0.51</td>
#     </tr>
#     <tr>
#       <th>University of Strathclyde</th>
#       <td>0.51</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ### Which organisation do you work for?

# %%
v_to_count, filename  = get_count(df, ['currentEmp4. Which organisation do you work for?'], "one choice", "./../survey_creation/2016/uk/listAnswers/type_organisation.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Which organisation do you work for?</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>University College London</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>King's College London</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>UCL</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Univestiry College London</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Queen Mary University London</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Bogor Agricultural University (IPB), Indonesia</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Not saying</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>University of Reading</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Birkbeck, University of London</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Kings College London + Biomedical Research Centre</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Contract for Collegio Carlo Alberto, Itlay but based in University of Oxford.  Previously had a contract with University of Oxford as a post-doc Research Assistant</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>NaN</th>
#       <td>257</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Which organisation do you work for? [PERCENTAGE]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>University College London</th>
#       <td>18.75</td>
#     </tr>
#     <tr>
#       <th>King's College London</th>
#       <td>18.75</td>
#     </tr>
#     <tr>
#       <th>UCL</th>
#       <td>12.50</td>
#     </tr>
#     <tr>
#       <th>Univestiry College London</th>
#       <td>6.25</td>
#     </tr>
#     <tr>
#       <th>Queen Mary University London</th>
#       <td>6.25</td>
#     </tr>
#     <tr>
#       <th>Bogor Agricultural University (IPB), Indonesia</th>
#       <td>6.25</td>
#     </tr>
#     <tr>
#       <th>Not saying</th>
#       <td>6.25</td>
#     </tr>
#     <tr>
#       <th>University of Reading</th>
#       <td>6.25</td>
#     </tr>
#     <tr>
#       <th>Birkbeck, University of London</th>
#       <td>6.25</td>
#     </tr>
#     <tr>
#       <th>Kings College London + Biomedical Research Centre</th>
#       <td>6.25</td>
#     </tr>
#     <tr>
#       <th>Contract for Collegio Carlo Alberto, Itlay but based in University of Oxford.  Previously had a contract with University of Oxford as a post-doc Research Assistant</th>
#       <td>6.25</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ### In what year did you start your current position?

# %%
v_to_count, filename  = get_count(df, ['currentEmp16a. In what year did you start your current position?'], "freenumeric", "./../survey_creation/2016/uk/listAnswers/.csv", "False", "./2016/uk/output/")

# %%
_ = get_plot(v_to_count, "freenumeric")
# Out:
#        In what year did you start your current position?
# count                                         272.000000
# mean                                         2010.852941
# std                                             5.376633
# min                                          1987.000000
# 25%                                          2009.000000
# 50%                                          2013.000000
# 75%                                          2014.000000
# max                                          2016.000000

# %% [markdown]
# ### What is the duration of your current contract?

# %%
v_to_count, filename  = get_count(df, ['currentEmp11. What is the duration of your current contract?'], "freenumeric", "./../survey_creation/2016/uk/listAnswers/.csv", "False", "./2016/uk/output/")

# %%
_ = get_plot(v_to_count, "freenumeric")
# Out:
#        What is the duration of your current contract?
# count                                      123.000000
# mean                                        28.178862
# std                                         15.718858
# min                                          2.000000
# 25%                                         13.000000
# 50%                                         24.000000
# 75%                                         36.000000
# max                                         96.000000

# %% [markdown]
# ### Do you work full time or part time?

# %%
v_to_count, filename  = get_count(df, ['currentEmp12. Do you work full time or part time?'], "one choice", "./../survey_creation/2016/uk/listAnswers/type_hours.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Do you work full time or part time?</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Full time</th>
#       <td>258</td>
#     </tr>
#     <tr>
#       <th>Part time</th>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>NaN</th>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Do you work full time or part time? [PERCENTAGE]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Full time</th>
#       <td>94.85</td>
#     </tr>
#     <tr>
#       <th>Part time</th>
#       <td>5.15</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ### Is this your first job?

# %%
v_to_count, filename  = get_count(df, ['currentEmp16b. Is this your first job?'], "y/n/na", "./../survey_creation/2016/uk/listAnswers/.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Yes</th>
#       <th>No</th>
#       <th>nan</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Is this your first job?</th>
#       <td>47</td>
#       <td>225</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Yes</th>
#       <th>No</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Is this your first job? [PERCENTAGE]</th>
#       <td>17.28</td>
#       <td>82.72</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %%
_ = get_plot(perc_to_count, "y/n/na")

# %% [markdown]
# ## Group of question: prevEmp

# %% [markdown]
# ### Why did you leave the private sector?

# %%
v_to_count, filename  = get_count(df, ['prevEmp16b. Why did you leave the private sector?'], "one choice", "./../survey_creation/2016/uk/listAnswers/reasons_leave_job.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Why did you leave the private sector?</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Others</th>
#       <td>76</td>
#     </tr>
#     <tr>
#       <th>Mismatch between description and promise during the interview and actual job</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>Lack of opportunity to advance</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>Loss of faith and confidence in corporate leaders</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Excessive overtime hours</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>A work environment that does not encourage teamwork</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>NaN</th>
#       <td>162</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Why did you leave the private sector? [PERCENTAGE]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Others</th>
#       <td>68.47</td>
#     </tr>
#     <tr>
#       <th>Mismatch between description and promise during the interview and actual job</th>
#       <td>10.81</td>
#     </tr>
#     <tr>
#       <th>Lack of opportunity to advance</th>
#       <td>8.11</td>
#     </tr>
#     <tr>
#       <th>Loss of faith and confidence in corporate leaders</th>
#       <td>7.21</td>
#     </tr>
#     <tr>
#       <th>Excessive overtime hours</th>
#       <td>4.50</td>
#     </tr>
#     <tr>
#       <th>A work environment that does not encourage teamwork</th>
#       <td>0.90</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ### What was the official job title of your previous job (i.e. the job title stated on your contact of employment)?

# %%
 wc = wordcloud(df, ['prevEmp16c. What was the official job title of your previous job (i.e. the job title stated on your contact of employment)?'])
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f2570e10cc0>

# %%
 plt.imshow(wc, interpolation='bilinear')
 plt.axis("off")
# Out:
# (-0.5, 1499.5, 799.5, -0.5)

# %% [markdown]
# ### What was the type of your contract?

# %%
v_to_count, filename  = get_count(df, ['prevEmp16d. What was the type of your contract?'], "one choice", "./../survey_creation/2016/uk/listAnswers/type_contract.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>What was the type of your contract?</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Permanent</th>
#       <td>116</td>
#     </tr>
#     <tr>
#       <th>Fixed-term</th>
#       <td>92</td>
#     </tr>
#     <tr>
#       <th>Freelancer  consultant  contractors</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>Zero hour contract</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>NaN</th>
#       <td>50</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>What was the type of your contract? [PERCENTAGE]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Permanent</th>
#       <td>52.02</td>
#     </tr>
#     <tr>
#       <th>Fixed-term</th>
#       <td>41.26</td>
#     </tr>
#     <tr>
#       <th>Freelancer  consultant  contractors</th>
#       <td>5.83</td>
#     </tr>
#     <tr>
#       <th>Zero hour contract</th>
#       <td>0.90</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# # Section: 3

# %% [markdown]
# ## Group of question: currentEmp

# %% [markdown]
# ### What is this job title?

# %%
 wc = wordcloud(df, ['currentEmp5. What is your official job title (i.e. the job title on your contract of employment)?', 'currentEmp5. What is this job title?'])
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f2570a51240>

# %%
 plt.imshow(wc, interpolation='bilinear')
 plt.axis("off")
# Out:
# (-0.5, 1499.5, 799.5, -0.5)

# %% [markdown]
# ### Are you known in your group by a different job title (e.g. the job title on your group website or business cards)?

# %%
v_to_count, filename  = get_count(df, ['currentEmp6. Are you known in your group by a different job title (e.g. the job title on your group website or business cards)?'], "y/n/na", "./../survey_creation/2016/uk/listAnswers/.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Yes</th>
#       <th>No</th>
#       <th>nan</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Are you known in your group by a different job title (e.g</th>
#       <td>37</td>
#       <td>235</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Yes</th>
#       <th>No</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Are you known in your group by a different job title (e.g [PERCENTAGE]</th>
#       <td>13.6</td>
#       <td>86.4</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %%
_ = get_plot(perc_to_count, "y/n/na")

# %% [markdown]
# ## Group of question: currentWork

# %% [markdown]
# ### What percentage of your time do you spend developing software each week?

# %%
 wc = wordcloud(df, ['currentWork16a. What percentage of your time do you spend developing software each week?'])
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f25726ae240>

# %%
 plt.imshow(wc, interpolation='bilinear')
 plt.axis("off")
# Out:
# (-0.5, 1499.5, 799.5, -0.5)

# %% [markdown]
# ## Group of question: paper

# %% [markdown]
# ### Were you acknowledged in the paper?; Were you named as a co-author of the paper?; Were you named as the lead author of the paper?

# %%
v_to_count, filename  = get_count(df, ['paper2. Were you acknowledged in the paper?', 'paper4. Were you named as a co-author of the paper?', 'paper5. Were you named as the lead author of the paper?'], "y/n/na", "./../survey_creation/2016/uk/listAnswers/.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Yes</th>
#       <th>No</th>
#       <th>nan</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>paper2. Were you acknowledged in the paper?</th>
#       <td>182</td>
#       <td>55</td>
#       <td>36</td>
#     </tr>
#     <tr>
#       <th>paper4. Were you named as a co-author of the paper?</th>
#       <td>170</td>
#       <td>69</td>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>paper5. Were you named as the lead author of the paper?</th>
#       <td>103</td>
#       <td>135</td>
#       <td>35</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Yes</th>
#       <th>No</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>paper2. Were you acknowledged in the paper?</th>
#       <td>76.79</td>
#       <td>23.21</td>
#     </tr>
#     <tr>
#       <th>paper4. Were you named as a co-author of the paper?</th>
#       <td>71.13</td>
#       <td>28.87</td>
#     </tr>
#     <tr>
#       <th>paper5. Were you named as the lead author of the paper?</th>
#       <td>43.28</td>
#       <td>56.72</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %%
_ = get_plot(perc_to_count, "y/n/na")

# %% [markdown]
# ## Group of question: stability

# %% [markdown]
# ### What is the bus factor of your most important software project?

# %%
v_to_count, filename  = get_count(df, ['stability1. What is the bus factor of your most important software project?'], "likert", "./../survey_creation/2016/uk/listAnswers/bus_factor.csv", "False", "./2016/uk/output/")

# %%
display(v_to_count)
# Out:
# Empty DataFrame
# Columns: []
# Index: [What is the bus factor of your most important software project?]

# %%
_ = get_plot(v_to_count, "likert")

# %% [markdown]
# # Section: 4

# %% [markdown]
# ## Group of question: perfCheck

# %% [markdown]
# ### Do you receive sufficient information on the results of your work?; Does your work give you the opportunity to check on how well you are doing your work?

# %%
v_to_count, filename  = get_count(df, ['perfCheck1. Do you receive sufficient information on the results of your work?', 'perfCheck2. Does your work give you the opportunity to check on how well you are doing your work?'], "likert", "./../survey_creation/2016/uk/listAnswers/likert_time_5.csv", "False", "./2016/uk/output/")

# %%
display(v_to_count)
# Out:
#                                                     Sometimes  Often  \
# perfCheck1. Do you receive sufficient informati...         99     82
# perfCheck2. Does your work give you the opportu...        107     67
#
#                                                     Very Often  Always
# perfCheck1. Do you receive sufficient informati...          54      29
# perfCheck2. Does your work give you the opportu...          60      23

# %%
_ = get_plot(v_to_count, "likert")

# %% [markdown]
# ## Group of question: turnOver

# %% [markdown]
# ### How often do you feel frustrated when not given the opportunity to achieve your personal work-related goals?; How often do you look forward to another day at work?

# %%
v_to_count, filename  = get_count(df, ['turnOver1. How often do you feel frustrated when not given the opportunity to achieve your personal work-related goals?', 'turnOver2. How often do you look forward to another day at work?'], "likert", "./../survey_creation/2016/uk/listAnswers/likert_time_5.csv", "False", "./2016/uk/output/")

# %%
display(v_to_count)
# Out:
#                                                     Never  Sometimes  Often  \
# turnOver1. How often do you feel frustrated whe...    NaN      129.0   54.0
# turnOver2. How often do you look forward to ano...   27.0      145.0   83.0
#
#                                                     Very Often  Always
# turnOver1. How often do you feel frustrated whe...        50.0    23.0
# turnOver2. How often do you look forward to ano...         NaN     NaN

# %%
_ = get_plot(v_to_count, "likert")

# %% [markdown]
# ## Group of question: affRec

# %% [markdown]
# ### I am satisfied with my supervisor/line manager's confidence in me; I am satisfied with a word of thanks from my supervisor/line manager

# %%
v_to_count, filename  = get_count(df, ["affRec1. I am satisfied with my supervisor/line manager's confidence in me", 'affRec2. I am satisfied with a word of thanks from my supervisor/line manager'], "likert", "./../survey_creation/2016/uk/listAnswers/likert_agree.csv", "False", "./2016/uk/output/")

# %%
display(v_to_count)
# Out:
#                                                     Strongly disagree  \
# affRec1. I am satisfied with my supervisor/line...                 15
# affRec2. I am satisfied with a word of thanks f...                 19
#
#                                                     Disagree  \
# affRec1. I am satisfied with my supervisor/line...        30
# affRec2. I am satisfied with a word of thanks f...        35
#
#                                                     Neither agree or disagree  \
# affRec1. I am satisfied with my supervisor/line...                         37
# affRec2. I am satisfied with a word of thanks f...                         72
#
#                                                     Agree  Strongly Agree
# affRec1. I am satisfied with my supervisor/line...     86             103
# affRec2. I am satisfied with a word of thanks f...     95              50

# %%
_ = get_plot(v_to_count, "likert")

# %% [markdown]
# ## Group of question: percEmp

# %% [markdown]
# ### It would not be very difficult for me to get an equivalent job in a different organisation; I can think of a number of organisations that would probably offer me a job; My experience is in demand on the labour market

# %%
v_to_count, filename  = get_count(df, ['percEmp1. It would not be very difficult for me to get an equivalent job in a different organisation', 'percEmp2. I can think of a number of organisations that would probably offer me a job', 'percEmp3. My experience is in demand on the labour market'], "likert", "./../survey_creation/2016/uk/listAnswers/likert_agree.csv", "False", "./2016/uk/output/")

# %%
display(v_to_count)
# Out:
#                                                     Strongly disagree  \
# percEmp1. It would not be very difficult for me...                 22
# percEmp2. I can think of a number of organisati...                 15
# percEmp3. My experience is in demand on the lab...                 13
#
#                                                     Disagree  \
# percEmp1. It would not be very difficult for me...        48
# percEmp2. I can think of a number of organisati...        32
# percEmp3. My experience is in demand on the lab...        13
#
#                                                     Neither agree or disagree  \
# percEmp1. It would not be very difficult for me...                         70
# percEmp2. I can think of a number of organisati...                         67
# percEmp3. My experience is in demand on the lab...                         76
#
#                                                     Agree  Strongly Agree
# percEmp1. It would not be very difficult for me...     75              56
# percEmp2. I can think of a number of organisati...    102              55
# percEmp3. My experience is in demand on the lab...    108              61

# %%
_ = get_plot(v_to_count, "likert")

# %% [markdown]
# ## Group of question: affSat

# %% [markdown]
# ### I find real enjoyment in my job; Most days I am enthusiastic about my job; I feel fairly well satisfied with my job

# %%
v_to_count, filename  = get_count(df, ['affSat1. I find real enjoyment in my job', 'affSat2. Most days I am enthusiastic about my job', 'affSat3. I feel fairly well satisfied with my job'], "likert", "./../survey_creation/2016/uk/listAnswers/likert_agree.csv", "False", "./2016/uk/output/")

# %%
display(v_to_count)
# Out:
#                                                    Strongly disagree  \
# affSat1. I find real enjoyment in my job                           8
# affSat2. Most days I am enthusiastic about my job                 17
# affSat3. I feel fairly well satisfied with my job                 10
#
#                                                    Disagree  \
# affSat1. I find real enjoyment in my job                 30
# affSat2. Most days I am enthusiastic about my job        30
# affSat3. I feel fairly well satisfied with my job        40
#
#                                                    Neither agree or disagree  \
# affSat1. I find real enjoyment in my job                                  58
# affSat2. Most days I am enthusiastic about my job                         54
# affSat3. I feel fairly well satisfied with my job                         61
#
#                                                    Agree  Strongly Agree
# affSat1. I find real enjoyment in my job             103              72
# affSat2. Most days I am enthusiastic about my job    115              55
# affSat3. I feel fairly well satisfied with my job    104              56

# %%
_ = get_plot(v_to_count, "likert")

# %% [markdown]
# ## Group of question: progRSE

# %% [markdown]
# ### My current position is an integral part of my career plan; It is likely that my next position will be an RSE role

# %%
v_to_count, filename  = get_count(df, ['progRSE4. My current position is an integral part of my career plan', 'progRSE5. It is likely that my next position will be an RSE role'], "likert", "./../survey_creation/2016/uk/listAnswers/likert_agree.csv", "False", "./2016/uk/output/")

# %%
display(v_to_count)
# Out:
#                                                     Strongly disagree  \
# progRSE4. My current position is an integral pa...                 21
# progRSE5. It is likely that my next position wi...                 21
#
#                                                     Disagree  \
# progRSE4. My current position is an integral pa...        35
# progRSE5. It is likely that my next position wi...        44
#
#                                                     Neither agree or disagree  \
# progRSE4. My current position is an integral pa...                         74
# progRSE5. It is likely that my next position wi...                         85
#
#                                                     Agree  Strongly Agree
# progRSE4. My current position is an integral pa...     80              61
# progRSE5. It is likely that my next position wi...     80              41

# %%
_ = get_plot(v_to_count, "likert")

# %% [markdown]
# # Section: 5

# %% [markdown]
# ## Group of question: perfCheck

# %% [markdown]
# ### Do you receive sufficient information on the purpose of your work?; Does your work provide you with direct feedback on how well you are doing your work?; Does your supervisor/line manager inform you about how well you are doing your work?; Do your colleagues inform you about how well you are doing your work?

# %%
v_to_count, filename  = get_count(df, ['perfCheck4. Do you receive sufficient information on the purpose of your work?', 'perfCheck5. Does your work provide you with direct feedback on how well you are doing your work?', 'perfCheck6. Does your supervisor/line manager inform you about how well you are doing your work?', 'perfCheck7. Do your colleagues inform you about how well you are doing your work?'], "likert", "./../survey_creation/2016/uk/listAnswers/likert_time_5.csv", "False", "./2016/uk/output/")

# %%
display(v_to_count)
# Out:
#                                                     Sometimes  Often  \
# perfCheck4. Do you receive sufficient informati...         56     65
# perfCheck5. Does your work provide you with dir...         93     81
# perfCheck6. Does your supervisor/line manager i...        100     69
# perfCheck7. Do your colleagues inform you about...         94     74
#
#                                                     Very Often  Always
# perfCheck4. Do you receive sufficient informati...          92      53
# perfCheck5. Does your work provide you with dir...          61      25
# perfCheck6. Does your supervisor/line manager i...          61      21
# perfCheck7. Do your colleagues inform you about...          50      11

# %%
_ = get_plot(v_to_count, "likert")

# %% [markdown]
# ## Group of question: turnOver

# %% [markdown]
# ### How often do you consider leaving your job?; How often do dream about getting another job that will better suit your needs?

# %%
v_to_count, filename  = get_count(df, ['turnOver3. How often do you consider leaving your job?', 'turnOver4. How often do dream about getting another job that will better suit your needs?'], "likert", "./../survey_creation/2016/uk/listAnswers/likert_time_5.csv", "False", "./2016/uk/output/")

# %%
display(v_to_count)
# Out:
#                                                     Never  Sometimes  Often  \
# turnOver3. How often do you consider leaving yo...   15.0      162.0   37.0
# turnOver4. How often do dream about getting ano...    NaN      114.0   42.0
#
#                                                     Very Often  Always
# turnOver3. How often do you consider leaving yo...         NaN     NaN
# turnOver4. How often do dream about getting ano...        54.0    24.0

# %%
_ = get_plot(v_to_count, "likert")

# %% [markdown]
# ### My current job satisfies my personal needs; I would accept another job at the same compensation level if I was offered it

# %%
v_to_count, filename  = get_count(df, ['turnOver5. My current job satisfies my personal needs', 'turnOver6. I would accept another job at the same compensation level if I was offered it'], "likert", "./../survey_creation/2016/uk/listAnswers/likert_agree.csv", "False", "./2016/uk/output/")

# %%
display(v_to_count)
# Out:
#                                                     Strongly disagree  \
# turnOver5. My current job satisfies my personal...                 21
# turnOver6. I would accept another job at the sa...                 56
#
#                                                     Disagree  \
# turnOver5. My current job satisfies my personal...        50
# turnOver6. I would accept another job at the sa...        71
#
#                                                     Neither agree or disagree  \
# turnOver5. My current job satisfies my personal...                         60
# turnOver6. I would accept another job at the sa...                         79
#
#                                                     Agree  Strongly Agree
# turnOver5. My current job satisfies my personal...     97              44
# turnOver6. I would accept another job at the sa...     47              19

# %%
_ = get_plot(v_to_count, "likert")

# %% [markdown]
# ## Group of question: affRec

# %% [markdown]
# ### I am satisfied with the recognition I receive from my supervisor/line manager for doing my job; I am satisfied with the compliments from my supervisor/line manager concerning my work; I am satisfied with the encouragement from my supervisor/line manager while doing my job

# %%
v_to_count, filename  = get_count(df, ['affRec3. I am satisfied with the recognition I receive from my supervisor/line manager for doing my job', 'affRec4. I am satisfied with the compliments from my supervisor/line manager concerning my work', 'affRec5. I am satisfied with the encouragement from my supervisor/line manager while doing my job'], "likert", "./../survey_creation/2016/uk/listAnswers/likert_agree.csv", "False", "./2016/uk/output/")

# %%
display(v_to_count)
# Out:
#                                                     Strongly disagree  \
# affRec3. I am satisfied with the recognition I ...                 20
# affRec4. I am satisfied with the compliments fr...                 20
# affRec5. I am satisfied with the encouragement ...                 16
#
#                                                     Disagree  \
# affRec3. I am satisfied with the recognition I ...        33
# affRec4. I am satisfied with the compliments fr...        29
# affRec5. I am satisfied with the encouragement ...        41
#
#                                                     Neither agree or disagree  \
# affRec3. I am satisfied with the recognition I ...                         65
# affRec4. I am satisfied with the compliments fr...                         72
# affRec5. I am satisfied with the encouragement ...                         65
#
#                                                     Agree  Strongly Agree
# affRec3. I am satisfied with the recognition I ...    111              43
# affRec4. I am satisfied with the compliments fr...    101              50
# affRec5. I am satisfied with the encouragement ...    108              42

# %%
_ = get_plot(v_to_count, "likert")

# %% [markdown]
# ## Group of question: affSat

# %% [markdown]
# ### I like my job better than the average person

# %%
v_to_count, filename  = get_count(df, ['affSat4. I like my job better than the average person'], "likert", "./../survey_creation/2016/uk/listAnswers/likert_agree.csv", "False", "./2016/uk/output/")

# %%
display(v_to_count)
# Out:
#                                               Strongly disagree  Disagree  \
# I like my job better than the average person                 11        20
#
#                                               Neither agree or disagree  \
# I like my job better than the average person                         79
#
#                                               Agree  Strongly Agree
# I like my job better than the average person    101              61

# %%
_ = get_plot(v_to_count, "likert")

# %% [markdown]
# ## Group of question: progRSE

# %% [markdown]
# ### It is likely that I will gain a promotion within my current group; The process I have to complete to gain a promotion is clear and understandable; There are many opportunities within my chosen career plan

# %%
v_to_count, filename  = get_count(df, ['progRSE1. It is likely that I will gain a promotion within my current group', 'progRSE2. The process I have to complete to gain a promotion is clear and understandable', 'progRSE3. There are many opportunities within my chosen career plan'], "likert", "./../survey_creation/2016/uk/listAnswers/likert_agree.csv", "False", "./2016/uk/output/")

# %%
display(v_to_count)
# Out:
#                                                     Strongly disagree  \
# progRSE1. It is likely that I will gain a promo...                 94
# progRSE2. The process I have to complete to gai...                 85
# progRSE3. There are many opportunities within m...                 40
#
#                                                     Disagree  \
# progRSE1. It is likely that I will gain a promo...        67
# progRSE2. The process I have to complete to gai...        78
# progRSE3. There are many opportunities within m...        80
#
#                                                     Neither agree or disagree  \
# progRSE1. It is likely that I will gain a promo...                         61
# progRSE2. The process I have to complete to gai...                         53
# progRSE3. There are many opportunities within m...                         85
#
#                                                     Agree  Strongly Agree
# progRSE1. It is likely that I will gain a promo...     38              12
# progRSE2. The process I have to complete to gai...     38              18
# progRSE3. There are many opportunities within m...     44              23

# %%
_ = get_plot(v_to_count, "likert")

# %% [markdown]
# # Section: 6

# %% [markdown]
# ## Group of question: skill

# %% [markdown]
# ### In your opinion, what are the three most important skills that a Research Software Engineer must possess?

# %%
 wc = wordcloud(df, ['skill2. In your opinion, what are the three most important skills that a Research Software Engineer must possess?'])
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f2570df3e48>

# %%
 plt.imshow(wc, interpolation='bilinear')
 plt.axis("off")
# Out:
# (-0.5, 1499.5, 799.5, -0.5)

# %% [markdown]
# ### In your opinion, what are the three most important skills that a Research Software Engineer must possess?

# %%
 wc = wordcloud(df, ['skill2-1. In your opinion, what are the three most important skills that a Research Software Engineer must possess?'])
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f2576083cc0>

# %%
 plt.imshow(wc, interpolation='bilinear')
 plt.axis("off")
# Out:
# (-0.5, 1499.5, 799.5, -0.5)

# %% [markdown]
# ### In your opinion, what are the three most important skills that a Research Software Engineer must possess?

# %%
 wc = wordcloud(df, ['skill2-2. In your opinion, what are the three most important skills that a Research Software Engineer must possess?'])
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f2570bc9828>

# %%
 plt.imshow(wc, interpolation='bilinear')
 plt.axis("off")
# Out:
# (-0.5, 1499.5, 799.5, -0.5)

# %% [markdown]
# ## Group of question: ukrse

# %% [markdown]
# ### Are you a member of the UK RSE Association? (Members are people who have signed up to the UK RSE mailing list)

# %%
v_to_count, filename  = get_count(df, ['ukrse1. Are you a member of the UK RSE Association? (Members are people who have signed up to the UK RSE mailing list)'], "y/n/na", "./../survey_creation/2016/uk/listAnswers/.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Yes</th>
#       <th>No</th>
#       <th>nan</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Are you a member of the UK RSE Association? (Members are people who have signed up to the UK RSE mailing list)</th>
#       <td>131</td>
#       <td>138</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Yes</th>
#       <th>No</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Are you a member of the UK RSE Association? (Members are people who have signed up to the UK RSE mailing list) [PERCENTAGE]</th>
#       <td>48.7</td>
#       <td>51.3</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %%
_ = get_plot(perc_to_count, "y/n/na")

# %% [markdown]
# ## Group of question: socio

# %% [markdown]
# ### Please select your gender

# %%
v_to_count, filename  = get_count(df, ['socio2. Please select your gender'], "one choice", "./../survey_creation/2016/uk/listAnswers/gender.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Please select your gender</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Male</th>
#       <td>232</td>
#     </tr>
#     <tr>
#       <th>Female</th>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>Other</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>NaN</th>
#       <td>10</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Please select your gender [PERCENTAGE]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Male</th>
#       <td>88.21</td>
#     </tr>
#     <tr>
#       <th>Female</th>
#       <td>11.41</td>
#     </tr>
#     <tr>
#       <th>Other</th>
#       <td>0.38</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ### Please select your age

# %%
v_to_count, filename  = get_count(df, ['socio3. Please select your age'], "one choice", "./../survey_creation/2016/uk/listAnswers/age.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Please select your age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>35 to 44 years</th>
#       <td>107</td>
#     </tr>
#     <tr>
#       <th>25 to 34 years</th>
#       <td>97</td>
#     </tr>
#     <tr>
#       <th>45 to 54 years</th>
#       <td>51</td>
#     </tr>
#     <tr>
#       <th>55 to 64 years</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>18 to 24 years</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>NaN</th>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Please select your age [PERCENTAGE]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>35 to 44 years</th>
#       <td>39.63</td>
#     </tr>
#     <tr>
#       <th>25 to 34 years</th>
#       <td>35.93</td>
#     </tr>
#     <tr>
#       <th>45 to 54 years</th>
#       <td>18.89</td>
#     </tr>
#     <tr>
#       <th>55 to 64 years</th>
#       <td>4.07</td>
#     </tr>
#     <tr>
#       <th>18 to 24 years</th>
#       <td>1.48</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ### Please select the range of your salary

# %%
v_to_count, filename  = get_count(df, ['socio4. Please select the range of your salary'], "one choice", "./../survey_creation/2016/uk/listAnswers/salary.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Please select the range of your salary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>£30 000 to £34 999</th>
#       <td>81</td>
#     </tr>
#     <tr>
#       <th>£35 000 to £39 999</th>
#       <td>68</td>
#     </tr>
#     <tr>
#       <th>£40 000 to £44 999</th>
#       <td>38</td>
#     </tr>
#     <tr>
#       <th>£45 000 to £50 000</th>
#       <td>31</td>
#     </tr>
#     <tr>
#       <th>£25 000 to £29 999</th>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>Less than £25 000</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>£50 000 to £59 999</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>Prefer not to say</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>£60 000 to £69 999</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>£70 000 to £99 000</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>NaN</th>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Please select the range of your salary [PERCENTAGE]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>£30 000 to £34 999</th>
#       <td>30.00</td>
#     </tr>
#     <tr>
#       <th>£35 000 to £39 999</th>
#       <td>25.19</td>
#     </tr>
#     <tr>
#       <th>£40 000 to £44 999</th>
#       <td>14.07</td>
#     </tr>
#     <tr>
#       <th>£45 000 to £50 000</th>
#       <td>11.48</td>
#     </tr>
#     <tr>
#       <th>£25 000 to £29 999</th>
#       <td>7.78</td>
#     </tr>
#     <tr>
#       <th>Less than £25 000</th>
#       <td>3.70</td>
#     </tr>
#     <tr>
#       <th>£50 000 to £59 999</th>
#       <td>3.33</td>
#     </tr>
#     <tr>
#       <th>Prefer not to say</th>
#       <td>2.96</td>
#     </tr>
#     <tr>
#       <th>£60 000 to £69 999</th>
#       <td>1.11</td>
#     </tr>
#     <tr>
#       <th>£70 000 to £99 000</th>
#       <td>0.37</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ## Group of question: tool

# %% [markdown]
# ### What is your Operating System of choice for use at work?

# %%
v_to_count, filename  = get_count(df, ['tool2. What is your Operating System of choice for use at work?'], "one choice", "./../survey_creation/2016/uk/listAnswers/os.csv", "False", "./2016/uk/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>What is your Operating System of choice for use at work?</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>GNU/Linux</th>
#       <td>161</td>
#     </tr>
#     <tr>
#       <th>Windows</th>
#       <td>55</td>
#     </tr>
#     <tr>
#       <th>OS X</th>
#       <td>53</td>
#     </tr>
#     <tr>
#       <th>Other</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>NaN</th>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>What is your Operating System of choice for use at work? [PERCENTAGE]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>GNU/Linux</th>
#       <td>59.41</td>
#     </tr>
#     <tr>
#       <th>Windows</th>
#       <td>20.30</td>
#     </tr>
#     <tr>
#       <th>OS X</th>
#       <td>19.56</td>
#     </tr>
#     <tr>
#       <th>Other</th>
#       <td>0.74</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# # Section: 7

# %% [markdown]
# ## Group of question: contact

# %% [markdown]
# ### Please enter your email address

# %%
 wc = wordcloud(df, ['contact16b. Please enter your email address'])
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f25760ad160>

# %%
 plt.imshow(wc, interpolation='bilinear')
 plt.axis("off")
# Out:
# (-0.5, 1499.5, 799.5, -0.5)
