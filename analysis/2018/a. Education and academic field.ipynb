a></span></li></ul></li></ul></div>

# %% [markdown]
# # Introduction

# %% [markdown]
# This section contains the information about the type of education the participants have, as well as their highest degree obtained.
#
# We asked the participants, in which field they are working. With that question, it is possible to see which current field employed the most of RSE/RSD. The questions was specific to each country and was multiple choice. Each participant could choose several fields. We then calculate the different proportion by dividing each field by the total of participants that have selected at least one option.

# %% [markdown]
# ## Questions in this section
#
# * `What is the highest level of education you have attained?`: one choice list
# * `In which discipline is your highest academic qualification?`: one choice list
# * `Which professional qualification do you hold?`: free text

# %% [markdown]
# ## Setting up

# %%
# %%capture

# Import notebook containing the imports the functions and the dataset
# %run "./0. Imports and functions.ipynb"

# Import notebook containing sampled dataset
# %run "./1. Overview and sampling.ipynb"

# %%
plt.rcParams['figure.figsize'] = [20.0, 10.0]

# %% [markdown]
# # Levels of education

# %%
education_column = 'edu1. What is the highest level of education you have attained?'

# %% [markdown]
# ## Australia

# %%
# Set up variables
country = 'Australia'
category = 'Highest level of education'

# Get the count
result = count_diff(df, columns=education_column, category=category, country=country)

# Showing the results
result
# Out:
#                                                     Count  Percentage
# Highest level of education for Australia
# AQF 10 - Doctoral Degree                               63   64.285714
# AQF 8 - Bachelor Honours Degree / Graduate Cert...     13   13.265306
# AQF 7 - Bachelor Degree                                11   11.224490
# AQF 9 - Masters Degree                                 11   11.224490

# %%
plot_cat_comparison(result, country, category)

# %% [markdown]
# ## Germany

# %%
# Set up variables
country = 'Germany'
category = 'Highest level of education'

# Get the count
result = count_diff(df, columns=education_column, category=category, country=country)

# Showing the results
result
# Out:
#                                                     Count  Percentage  \
# Highest level of education for Germany
# Master degree                                         169   50.903614
# Doctorate                                             133   40.060241
# Undergraduate degree                                   19    5.722892
# Final secondary-school examinations, general qu...      7    2.108434
# Other                                                   4    1.204819
#
#                                                     Percentage in 2017  \
# Highest level of education for Germany
# Master degree                                                43.076923
# Doctorate                                                    48.307692
# Undergraduate degree                                          4.615385
# Final secondary-school examinations, general qu...            1.538462
# Other                                                         2.153846
#
#                                                     Difference with previous year
# Highest level of education for Germany
# Master degree                                                            7.826691
# Doctorate                                                               -8.247451
# Undergraduate degree                                                     1.107507
# Final secondary-school examinations, general qu...                       0.569972
# Other                                                                   -0.949027

# %%
plot_cat_comparison(result, country, category)

# %% [markdown]
# ## Netherlands

# %%
# Set up variables
country = 'Netherlands'
category = 'Highest level of education'

# Get the count
result = count_diff(df, columns=education_column, category=category, country=country)

# Showing the results
result
# Out:
#                                             Count  Percentage  \
# Highest level of education for Netherlands
# PhD                                            27   50.000000
# WO (Wetenschappelijk onderwijs) Master         20   37.037037
# WO (Wetenschappelijk onderwijs) Bachelor        3    5.555556
# HBO (Hoger beroepsonderwijs) Master             3    5.555556
# HBO (Hoger beroepsonderwijs) Bachelor           1    1.851852
#
#                                             Percentage in 2017  \
# Highest level of education for Netherlands
# PhD                                                  57.333333
# WO (Wetenschappelijk onderwijs) Master               36.000000
# WO (Wetenschappelijk onderwijs) Bachelor              2.666667
# HBO (Hoger beroepsonderwijs) Master                   1.333333
# HBO (Hoger beroepsonderwijs) Bachelor                 2.666667
#
#                                             Difference with previous year
# Highest level of education for Netherlands
# PhD                                                             -7.333333
# WO (Wetenschappelijk onderwijs) Master                           1.037037
# WO (Wetenschappelijk onderwijs) Bachelor                         2.888889
# HBO (Hoger beroepsonderwijs) Master                              4.222222
# HBO (Hoger beroepsonderwijs) Bachelor                           -0.814815

# %%
plot_cat_comparison(result, country, category)

# %% [markdown]
# ## New Zealand

# %%
# Set up variables
country = 'New Zealand'
category = 'Highest level of education'

# Get the count
result = count_diff(df, columns=education_column, category=category, country=country)

# Showing the results
result
# Out:
#                                             Count  Percentage
# Highest level of education for New Zealand
# Doctorate                                      14   37.837838
# Master degree                                  10   27.027027
# Undergraduate degree                           10   27.027027
# Further Education (NVQ A-Level, ...)            2    5.405405
# Other                                           1    2.702703

# %%
plot_cat_comparison(result, country, category)

# %% [markdown]
# ## South Africa

# %%
# Set up variables
country = 'South Africa'
category = 'Highest level of education'

# Get the count
result = count_diff(df, columns=education_column, category=category, country=country)

# Showing the results
result
# Out:
#                                              Count  Percentage  \
# Highest level of education for South Africa
# Doctorate                                        7   30.434783
# Master degree                                    6   26.086957
# Undergraduate degree                             6   26.086957
# Further Education (NVQ A-Level, ...)             2    8.695652
# Other                                            2    8.695652
#
#                                              Percentage in 2017  \
# Highest level of education for South Africa
# Doctorate                                             73.684211
# Master degree                                         15.789474
# Undergraduate degree                                        NaN
# Further Education (NVQ A-Level, ...)                        NaN
# Other                                                       NaN
#
#                                              Difference with previous year
# Highest level of education for South Africa
# Doctorate                                                       -43.249428
# Master degree                                                    10.297483
# Undergraduate degree                                                   NaN
# Further Education (NVQ A-Level, ...)                                   NaN
# Other                                                                  NaN

# %%
plot_cat_comparison(result, country, category)

# %% [markdown]
# ## United Kingdom

# %% [markdown]
# In 2018, the proportion of participants that hold a PhD is 70%. This majority confirm the tendency from last year with an increase of 2%.
# Only 20% holds a Master degree as the highest education, and 8% an Undergraduate degree.

# %%
# Get the count for the 2017 year
country = 'United Kingdom'
category = 'Highest level of education'

# Get the count
result = count_diff(df, columns=education_column, category=category, country=country)

# Showing the results
result
# Out:
#                                                Count  Percentage  \
# Highest level of education for United Kingdom
# Doctorate                                        166   70.338983
# Master degree                                     48   20.338983
# Undergraduate degree                              21    8.898305
# GSCEs                                              1    0.423729
#
#                                                Percentage in 2017  \
# Highest level of education for United Kingdom
# Doctorate                                               67.886179
# Master degree                                           22.357724
# Undergraduate degree                                     9.349593
# GSCEs                                                         NaN
#
#                                                Difference with previous year
# Highest level of education for United Kingdom
# Doctorate                                                           2.452804
# Master degree                                                      -2.018741
# Undergraduate degree                                               -0.451288
# GSCEs                                                                    NaN

# %%
plot_cat_comparison(result, country, category)

# %% [markdown]
# ## United States

# %%
# Set up variables
country = 'United States'
category = 'Highest level of education'

# Get the count
result = count_diff(df, columns=education_column, category=category, country=country)

# Showing the results
result
# Out:
#                                               Count  Percentage  \
# Highest level of education for United States
# Doctorate                                        67   45.578231
# Master degree                                    46   31.292517
# Undergraduate degree                             33   22.448980
# Other                                             1    0.680272
#
#                                               Percentage in 2017  \
# Highest level of education for United States
# Doctorate                                              60.122699
# Master degree                                          25.153374
# Undergraduate degree                                   11.656442
# Other                                                   0.613497
#
#                                               Difference with previous year
# Highest level of education for United States
# Doctorate                                                        -14.544468
# Master degree                                                      6.139143
# Undergraduate degree                                              10.792538
# Other                                                              0.066775

# %%
plot_cat_comparison(result, country, category)

# %% [markdown]
# ## Rest of the World

# %% [markdown]
# For the rest of the world, the question is a `free text` type. Therefore, some cleaning are needed to render the results intelligible.
# After manually cleaning the data, it appears that a vast majority of participants hold a PhD (64%), while 14% have a Master degree and only 9% have an Undergraduate degree.

# %%
dict_values = {'phd': 'Doctorate', 
               'phd in progress': 'Doctorate',
               'mphil to phd transfer': 'Doctorate',
               'dr phil': 'Doctorate',
               'master of science': 'Master degree',
               'master': 'Master degree',
               'masters': 'Master degree',
               'master in science': 'Master degree',
               'postgraduate': 'Master degree',
               'msc': 'Master degree',
               'bachelors degree': 'Undergraduate degree',
               'bachelors  in computer science': 'Undergraduate degree',
               'bachelor': 'Undergraduate degree',
               'bachelors': 'Undergraduate degree',
               'nan': np.NaN
               }
df.loc[df['Country'] == 'World', education_column] = df.loc[df['Country'] == 'World', education_column].str.replace('.', '').str.replace("'", "").str.replace('degree', '').str.strip().str.lower()
df.loc[df['Country'] == 'World', education_column] = df.loc[df['Country'] == 'World', education_column].replace(dict_values)

# %%
# Set up variables
country = 'World'
category = 'Highest level of education'

# Get the count
result = count_diff(df, columns=education_column, category=category, country=country)

# Showing the results
result
# Out:
#                                       Count  Percentage
# Highest level of education for World
# Doctorate                                35   64.814815
# Master degree                            14   25.925926
# Undergraduate degree                      5    9.259259

# %%
plot_cat_comparison(result, country, category)

# %% [markdown]
# ## Comparison between countries

# %% [markdown]
# Even if the countries have different education levels, it is possible to match them on the common "Doctorate" and "Master degree".
# Therefore we compare them with these two equivalent levels and merge all others under the category "other".

# %%
# Create dictionary to replace values. These values may not be present in the current df but are present in the
# potential answers
dict_values = {'PhD': 'Doctorate', 
               'AQF 10 - Doctoral Degree': 'Doctorate',
               'HBO (Hoger beroepsonderwijs) Master': 'Master degree',
               'WO (Wetenschappelijk onderwijs) Master': 'Master degree',
               'AQF 9 - Masters Degree': 'Master degree'}
list_value_to_keep = ['Doctorate', 'Master degree', np.NaN]

# Replace the value in education
df['education comparison'] = df[education_column].replace(dict_values)

# Create a new columns if "World" if the country is not in the list
def merge_edu(x):
    if x in list_value_to_keep:
        return x
    elif x == np.NaN:
        return x
    else:
        return 'Other'
    
# Apply the function to a new columns
df['education comparison'] = df['education comparison'].apply(merge_edu)

# Count the values per countries
df_edu_comparison = df[['Country', 'education comparison']].groupby('Country')['education comparison'].value_counts().rename('Total count').reset_index()

# Add a percentage of each type of diploma per countries
df_edu_comparison['Percentage per countries'] = (df_edu_comparison['Total count'] / df_edu_comparison.groupby('Country')['Total count'].transform('sum')*100).round(2)

# Display the results
df_edu_comparison
# Out:
#            Country education comparison  Total count  Percentage per countries
# 0        Australia            Doctorate           63                     64.29
# 1        Australia                Other           24                     24.49
# 2        Australia        Master degree           11                     11.22
# 3          Germany        Master degree          309                     47.03
# 4          Germany            Doctorate          290                     44.14
# 5          Germany                Other           58                      8.83
# 6      Netherlands            Doctorate           70                     54.26
# 7      Netherlands        Master degree           51                     39.53
# 8      Netherlands                Other            8                      6.20
# 9      New Zealand            Doctorate           14                     37.84
# 10     New Zealand                Other           13                     35.14
# 11     New Zealand        Master degree           10                     27.03
# 12    South Africa            Doctorate           21                     50.00
# 13    South Africa                Other           12                     28.57
# 14    South Africa        Master degree            9                     21.43
# 15  United Kingdom            Doctorate          333                     69.09
# 16  United Kingdom        Master degree          103                     21.37
# 17  United Kingdom                Other           46                      9.54
# 18   United States            Doctorate          165                     53.23
# 19   United States        Master degree           87                     28.06
# 20   United States                Other           58                     18.71
# 21           World            Doctorate           35                     64.81
# 22           World        Master degree           14                     25.93
# 23           World                Other            5                      9.26

# %%
fig, ax = plt.subplots()
df_plot = df_edu_comparison.pivot(index='Country', 
                        columns='education comparison', 
                        values='Percentage per countries')
df_plot.plot(kind='barh',
                  title='Percentage of Doctorate and Master per country',
                  grid=False, ax=ax)

ax.set(xlabel="Percentage", ylabel="Country")

ax.invert_yaxis()  # when barh option, the bars are inverted 
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False) 
for p in ax.patches:
    if int(round(p.get_width())) > 0:
        ax.annotate('{}%'.format(str(int(round(p.get_width())))), 
                                 (p.get_x() + p.get_width(), p.get_y()), 
                                  xytext=(5, -9),
                                  textcoords='offset points')
plt.show();

# %% [markdown]
# # Academic field for education and professional development

# %% [markdown]
# Alongside of question about education level we also asked the participants in which field they finished their highest level of education.
# Here again the propositions were specific to each countries so the comparison is difficult despite lot of overlapping in the categories.

# %%
# Create a column that merge all education columns
df_edu_field = df[['Year', 'Country']].copy()

# There are numbers in some of the fields, removing them as they are not needed
def remove_digit(s):
    try:
        return ''.join([i for i in s if not i.isdigit()])
    except TypeError:
        return s

df['Academic field'] = df['edu2. In which discipline is your highest academic qualification?'].apply(remove_digit)
columns = 'Academic field'

prof_qual = ['edu4. List any professional qualifications you hold (eg. P. Eng, PMP, …)?']

# %% [markdown]
# ## Australia

# %%
# Set up variables
country = 'Australia'
category = 'Field of education'
result = count_diff(df, columns, country, category)
result
# Out:
#                                        Count  Percentage
# Field of education for Australia
#  Physical Sciences                        27   27.835052
#  Information and Computing Sciences       21   21.649485
#  Biological Sciences                      15   15.463918
#  Engineering                              10   10.309278
#  Earth Sciences                            8    8.247423
#  Mathematical Sciences                     8    8.247423
#  Medical and Health Sciences               2    2.061856
#  Environmental Sciences                    1    1.030928
#  Studies in Creative Arts and Writing      1    1.030928
#  Technology                                1    1.030928
#  Psychology and Cognitive Sciences         1    1.030928
#  Chemical Sciences                         1    1.030928
#  Philosophy and Religious Studies          1    1.030928

# %%
plot_cat_comparison(result, country, 'Field of education')

# %%
plot_wordcloud(df, country=country, category='Professional qualification', columns=prof_qual)

# %% [markdown]
# ## Germany

# %%
# Set up variables
country = 'Germany'
category = 'Field of education'
result = count_diff(df, columns, country, category)
result
# Out:
#                                           Count  Percentage  \
# Field of education for Germany
# Computer Science                             85   25.835866
# Physics and Astronomy                        75   22.796353
# Geography & Environmental Sciences           25    7.598784
# Biological Sciences                          24    7.294833
# Mathematics                                  24    7.294833
# Electrical & Electronic Engineering          18    5.471125
# Mechanical Engineering                       11    3.343465
# Geology                                       9    2.735562
# Materials Technology                          6    1.823708
# Chemical Engineering                          5    1.519757
# General Engineering                           5    1.519757
# History                                       5    1.519757
# Civil Engineering                             4    1.215805
# German                                        3    0.911854
# Philosophy                                    3    0.911854
# Chemistry                                     3    0.911854
# Librarianship & Information Management        3    0.911854
# Economics                                     3    0.911854
# Psychology                                    2    0.607903
# Classics & Ancient History                    2    0.607903
# Linguistics                                   2    0.607903
# Robotics                                      2    0.607903
# Agriculture & Forestry                        1    0.303951
# Aeronautical & Manufacturing Engineering      1    0.303951
# Medicine                                      1    0.303951
# Business & Management Studies                 1    0.303951
# Art & Design                                  1    0.303951
# Education                                     1    0.303951
# Communication & Media Studies                 1    0.303951
# Theology & Religious Studies                  1    0.303951
# English                                       1    0.303951
# Criminology                                   1    0.303951
#
#                                           Percentage in 2017  \
# Field of education for Germany
# Computer Science                                   16.615385
# Physics and Astronomy                              25.538462
# Geography & Environmental Sciences                  7.076923
# Biological Sciences                                11.384615
# Mathematics                                         5.230769
# Electrical & Electronic Engineering                 2.461538
# Mechanical Engineering                              1.538462
# Geology                                             1.846154
# Materials Technology                                     NaN
# Chemical Engineering                                1.230769
# General Engineering                                 0.923077
# History                                             0.923077
# Civil Engineering                                   0.615385
# German                                              0.923077
# Philosophy                                          0.615385
# Chemistry                                           1.846154
# Librarianship & Information Management              0.923077
# Economics                                           0.307692
# Psychology                                          2.461538
# Classics & Ancient History                          0.923077
# Linguistics                                         0.307692
# Robotics                                                 NaN
# Agriculture & Forestry                              0.923077
# Aeronautical & Manufacturing Engineering            0.615385
# Medicine                                            0.307692
# Business & Management Studies                            NaN
# Art & Design                                             NaN
# Education                                                NaN
# Communication & Media Studies                       0.615385
# Theology & Religious Studies                             NaN
# English                                             0.307692
# Criminology                                              NaN
#
#                                           Difference with previous year
# Field of education for Germany
# Computer Science                                               9.220482
# Physics and Astronomy                                         -2.742109
# Geography & Environmental Sciences                             0.521861
# Biological Sciences                                           -4.089783
# Mathematics                                                    2.064064
# Electrical & Electronic Engineering                            3.009586
# Mechanical Engineering                                         1.805004
# Geology                                                        0.889408
# Materials Technology                                                NaN
# Chemical Engineering                                           0.288988
# General Engineering                                            0.596680
# History                                                        0.596680
# Civil Engineering                                              0.600421
# German                                                        -0.011223
# Philosophy                                                     0.296469
# Chemistry                                                     -0.934300
# Librarianship & Information Management                        -0.011223
# Economics                                                      0.604162
# Psychology                                                    -1.853636
# Classics & Ancient History                                    -0.315174
# Linguistics                                                    0.300210
# Robotics                                                            NaN
# Agriculture & Forestry                                        -0.619126
# Aeronautical & Manufacturing Engineering                      -0.311433
# Medicine                                                      -0.003741
# Business & Management Studies                                       NaN
# Art & Design                                                        NaN
# Education                                                           NaN
# Communication & Media Studies                                 -0.311433
# Theology & Religious Studies                                        NaN
# English                                                       -0.003741
# Criminology                                                         NaN

# %%
plot_cat_comparison(result, country, category)

# %%
plot_wordcloud(df, country=country, category='Professional qualification', columns=prof_qual)

# %% [markdown]
# ## Netherlands

# %%
# Set up variables
country = 'Netherlands'
category = 'Field of education'
result = count_diff(df, columns, country, category)
result
# Out:
#                                           Count  Percentage  \
# Field of education for Netherlands
# Physics and Astronomy                        18   33.333333
# Computer Science                             11   20.370370
# Biological Sciences                           8   14.814815
# Chemistry                                     3    5.555556
# Electrical & Electronic Engineering           2    3.703704
# Civil Engineering                             2    3.703704
# Geography & Environmental Sciences            2    3.703704
# Politics                                      1    1.851852
# Chemical Engineering                          1    1.851852
# Aeronautical & Manufacturing Engineering      1    1.851852
# Psychology                                    1    1.851852
# General Engineering                           1    1.851852
# Mathematics                                   1    1.851852
# Communication & Media Studies                 1    1.851852
# Art & Design                                  1    1.851852
#
#                                           Percentage in 2017  \
# Field of education for Netherlands
# Physics and Astronomy                              24.000000
# Computer Science                                   26.666667
# Biological Sciences                                12.000000
# Chemistry                                           9.333333
# Electrical & Electronic Engineering                 1.333333
# Civil Engineering                                        NaN
# Geography & Environmental Sciences                  5.333333
# Politics                                                 NaN
# Chemical Engineering                                     NaN
# Aeronautical & Manufacturing Engineering                 NaN
# Psychology                                               NaN
# General Engineering                                      NaN
# Mathematics                                         2.666667
# Communication & Media Studies                       4.000000
# Art & Design                                             NaN
#
#                                           Difference with previous year
# Field of education for Netherlands
# Physics and Astronomy                                          9.333333
# Computer Science                                              -6.296296
# Biological Sciences                                            2.814815
# Chemistry                                                     -3.777778
# Electrical & Electronic Engineering                            2.370370
# Civil Engineering                                                   NaN
# Geography & Environmental Sciences                            -1.629630
# Politics                                                            NaN
# Chemical Engineering                                                NaN
# Aeronautical & Manufacturing Engineering                            NaN
# Psychology                                                          NaN
# General Engineering                                                 NaN
# Mathematics                                                   -0.814815
# Communication & Media Studies                                 -2.148148
# Art & Design                                                        NaN

# %%
plot_cat_comparison(result, country, category)

# %%
plot_wordcloud(df, country=country, category='Professional qualification', columns=prof_qual)

# %% [markdown]
# ## New Zealand

# %%
# Set up variables
country = 'New Zealand'
category = 'Field of education'
result = count_diff(df, columns, country, category)
result
# Out:
#                                      Count  Percentage
# Field of education for New Zealand
# Computer Science                        11   29.729730
# Biological Sciences                      7   18.918919
# Mathematics                              4   10.810811
# Physics and Astronomy                    4   10.810811
# Mechanical Engineering                   2    5.405405
# Electrical & Electronic Engineering      2    5.405405
# Business & Management Studies            2    5.405405
# Geography & Environmental Sciences       1    2.702703
# General Engineering                      1    2.702703
# Chemical Engineering                     1    2.702703
# Chemistry                                1    2.702703
# Civil Engineering                        1    2.702703

# %%
plot_cat_comparison(result, country, category)

# %%
plot_wordcloud(df, country=country, category='Professional qualification', columns=prof_qual)

# %% [markdown]
# ## South Africa

# %%
# Set up variables
country = 'South Africa'
category = 'Field of education'
result = count_diff(df, columns, country, category)
result
# Out:
#                                      Count  Percentage  Percentage in 2017  \
# Field of education for South Africa
# Computer Science                        10   45.454545            5.263158
# Biological Sciences                      4   18.181818                 NaN
# Mathematics                              3   13.636364                 NaN
# Physics and Astronomy                    1    4.545455           63.157895
# Economics                                1    4.545455            5.263158
# Communication & Media Studies            1    4.545455                 NaN
# Psychology                               1    4.545455                 NaN
# Business & Management Studies            1    4.545455                 NaN
#
#                                      Difference with previous year
# Field of education for South Africa
# Computer Science                                         40.191388
# Biological Sciences                                            NaN
# Mathematics                                                    NaN
# Physics and Astronomy                                   -58.612440
# Economics                                                -0.717703
# Communication & Media Studies                                  NaN
# Psychology                                                     NaN
# Business & Management Studies                                  NaN

# %%
plot_cat_comparison(result, country, category)

# %%
plot_wordcloud(df, country=country, category='Professional qualification', columns=prof_qual)

# %% [markdown]
# ## United Kingdom

# %%
# Set up variables
country = 'United Kingdom'
category = 'Field of education'
result = count_diff(df, columns, country, category)
result
# Out:
#                                           Count  Percentage  \
# Field of education for United Kingdom
# Physics and Astronomy                        81   34.468085
# Computer Science                             56   23.829787
# Biological Sciences                          28   11.914894
# Mathematics                                  18    7.659574
# Chemistry                                    12    5.106383
# Geography & Environmental Sciences           11    4.680851
# Electrical & Electronic Engineering           6    2.553191
# General Engineering                           4    1.702128
# Geology                                       4    1.702128
# Mechanical Engineering                        2    0.851064
# Aeronautical & Manufacturing Engineering      2    0.851064
# Medicine                                      2    0.851064
# English                                       2    0.851064
# Sociology                                     2    0.851064
# History                                       1    0.425532
# Robotics                                      1    0.425532
# Theology & Religious Studies                  1    0.425532
# Civil Engineering                             1    0.425532
# Materials Technology                          1    0.425532
#
#                                           Percentage in 2017  \
# Field of education for United Kingdom
# Physics and Astronomy                              28.163265
# Computer Science                                   26.938776
# Biological Sciences                                 6.122449
# Mathematics                                         7.755102
# Chemistry                                           6.530612
# Geography & Environmental Sciences                  4.081633
# Electrical & Electronic Engineering                 3.265306
# General Engineering                                 1.224490
# Geology                                             1.224490
# %%
plot_cat_comparison(result, country, category)

# %%
plot_wordcloud(df, country=country, category='Professional qualification', columns=prof_qual)

# %% [markdown]
# ## Rest of the world

# %%
# Set up variables
country = 'World'
category = 'Field of education'
result = count_diff(df, columns, country, category)
result
# Out:
#                                         Count  Percentage
# Field of education for World
# Physics and Astronomy                      10   18.518519
# Biological Sciences                        10   18.518519
# Computer Science                            9   16.666667
# Mathematics                                 6   11.111111
# Geography & Environmental Sciences          3    5.555556
# Electrical & Electronic Engineering         2    3.703704
# Psychology                                  2    3.703704
# Education                                   2    3.703704
# Business & Management Studies               1    1.851852
# Accounting & Finance                        1    1.851852
# Pharmacology & Pharmacy                     1    1.851852
# Marketing                                   1    1.851852
# Chemistry                                   1    1.851852
# Librarianship & Information Management      1    1.851852
# Geology                                     1    1.851852
# Chemical Engineering                        1    1.851852
# Medicine                                    1    1.851852
# History of Art, Architecture & Design       1    1.851852

# %%
plot_cat_comparison(result, country, category)

# %%
plot_wordcloud(df, country=country, category='Professional qualification', columns=prof_qual)

# %% [markdown]
# ## Comparison between countries

# %%
# Count the values per countries
#df_edu_comparison = df_edu_field.groupby('Country')['Academic field'].value_counts().rename('Total count').reset_index()

# Add a percentage of each type of diploma per countries
#df_edu_comparison['Percentage per countries'] = (df_edu_comparison['Total count'] / df_edu_comparison.groupby('Country')['Total count'].transform('sum')*100)

# Display the results
#df_edu_comparison

# %%
#fig, ax = plt.subplots()
#df_plot = df_edu_comparison.pivot(index='Country', 
#                        columns='Academic field', 
#                        values='Percentage per countries')

#df_plot.plot(kind='barh',
#                  title='Percentage of academic field per country',
#                  grid=False, ax=ax, stacked=True)

#ax.set(xlabel="Country", ylabel="Percentage")

#ax.invert_yaxis()  # when barh option, the bars are inverted 
#ax.spines['top'].set_visible(False)
#ax.spines['right'].set_visible(False)
#ax.spines['left'].set_visible(False) 
# Put a legend below current axis
#ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1),
#          fancybox=True, shadow=True, ncol=5)
#for p in ax.patches:
#    if int(round(p.get_width())) >= 5:
#        ax.annotate('{}%'.format(str(int(round(p.get_width())))), 
#                    (p.get_x() + int(p.get_width())/2., p.get_y()+ int(p.get_height())/2.),
#                    ha='center')

#plt.show();

# %% [markdown]
# # Academic field of work

# %%
# Getting all the questions about the academic field of the current employment. 
to_sub = [x for x in df.columns if x[:12] == 'currentEmp13']

# %% [markdown]
# ## Australia

# %%
country = 'Australia'

# %%
category = 'field of work'

# Get the count
result = count_diff(df, columns=to_sub, category=category, country=country, multi_choice=True)

# Showing the results
result
# Out:
#                                                Count  Percentage
# field of work for Australia
# 08 Information and Computing Sciences             45   45.454545
# 02 Physical Sciences                              36   36.363636
# 06 Biological Sciences                            34   34.343434
# 10 Technology                                     26   26.262626
# 01 Mathematical Sciences                          24   24.242424
# 11 Medical and Health Sciences                    24   24.242424
# 09 Engineering                                    23   23.232323
# 04 Earth Sciences                                 22   22.222222
# 05 Environmental Sciences                         21   21.212121
# 03 Chemical Sciences                              10   10.101010
# 07 Agricultural and Veterinary Sciences           10   10.101010
# 13 Education                                       9    9.090909
# 20 Language, Communication and Culture             5    5.050505
# 16 Studies in Human Society                        4    4.040404
# 19 Studies in Creative Arts and Writing            3    3.030303
# 21 History and Archaeology                         3    3.030303
# 22 Philosophy and Religious Studies                3    3.030303
# 17 Psychology and Cognitive Sciences               3    3.030303
# 15 Commerce, Management, Tourism and Services      2    2.020202
# 14 Economics                                       2    2.020202
# 12 Built Environment and Design                    2    2.020202
# 18 Law and Legal Studies                           1    1.010101

# %%
plot_cat_comparison(result, country, category)

# %% [markdown]
# ## Germany

# %%
country = 'Germany'

# %%
category = 'field of work'

# Get the count
result = count_diff(df, columns=to_sub, category=category, country=country, multi_choice=True)

# Showing the results
result
# Out:
#                
# German                                                  1.538462
# History                                                 2.769231
# Agriculture & Forestry                                  2.153846
# Communication & Media Studies                           0.923077
# Civil Engineering                                       0.923077
# Linguistics                                             3.076923
# Classics & Ancient History                              3.076923
# Economics                                               2.769231
# Chemical Engineering                                    1.846154
# Theology & Religious Studies                            1.538462
# Law                                                     0.615385
# Psychology                                              2.769231
# Philosophy                                              0.615385
# Politics                                                0.307692
# Art & Design                                            0.615385
# Pharmacology & Pharmacy                                 0.923077
# History of Art, Architecture & Design                   0.923077
# Business & Management Studies                           0.615385
# Sociology                                                    NaN
# Marketing                                               0.307692
# Music                                                   0.307692
# Accounting & Finance                                    0.923077
# Food Science                                            0.615385
# American Studies                                             NaN
# Criminology                                                  NaN
# Land & Property Management                                   NaN
# Veterinary Medicine                                     0.615385
# English                                                      NaN
# Middle Eastern and African Studies                      0.307692
# Social Work                                                  NaN
# Anthropology                                            0.307692
# Architecture                                            0.307692
# Town & Country Planning and Landscape Design            0.307692
# Sports Science                                          0.307692
# Anatomy & Physiology                                    1.230769
# Social Policy                                                NaN
# Russian & East European Languages                            NaN
# Counselling                                             0.615385
# Complementary Medicine                                       NaN
# Physiotherapy                                                NaN
# Iberian Languages/Hispanic Studies                      0.307692
# Dentistry                                                    NaN
# Ophthalmics                                                  NaN
# Nursing                                                 0.307692
# East & South Asian Studies                                   NaN
# Fashion                                                      NaN
# French                                                  0.307692
# Hospitality, Leisure, Recreation & Tourism                   NaN
# Youth Work                                                   NaN
#
#                                               Difference with previous year
# field of work for Germany
# Computer Science                                                   6.672211
# Physics and Astronomy                                             -3.060291
# Geography & Environmental Sciences                                -3.490875
# Biological Sciences                                              -10.853315
# Electrical & Electronic Engineering                                8.319704
# Mathematics                                                        1.580042
# Mechanical Engineering                                             6.855163
# Robotics                                                           5.338877
# General Engineering                                                3.829984
# Geology                                                           -0.477708
# Materials Technology                                               6.298914
# Aeronautical & Manufacturing Engineering                           4.782629
# Chemistry                                                         -1.349041
# Medicine                                                          -0.425964
# Education                                                         -0.726265
# Librarianship & Information Management                            -1.334257
# German                                                             2.065142
# History                                                            0.834373
# Agriculture & Forestry                                             1.449757
# Communication & Media Studies                                      2.079926
# Civil Engineering                                                  2.079926
# Linguistics                                                       -0.374220
# Classics & Ancient History                                        -0.374220
# Economics                                                         -0.366828
# Chemical Engineering                                               0.556249
# Theology & Religious Studies                                       0.563641
# Law                                                                1.186417
# Psychology                                                        -0.967429
# Philosophy                                                         0.886117
# Politics                                                           1.193809
# Art & Design                                                       0.585817
# Pharmacology & Pharmacy                                            0.278124
# History of Art, Architecture & Design                              0.278124
# Business & Management Studies                                      0.585817
# Sociology                                                               NaN
# Marketing                                                          0.593209
# Music                                                              0.593209
# Accounting & Finance                                              -0.022176
# Food Science                                                       0.285516
# American Studies                                                        NaN
# Criminology                                                             NaN
# Land & Property Management                                              NaN
# Veterinary Medicine                                               -0.014784
# English                                                                 NaN
# Middle Eastern and African Studies                                 0.292908
# Social Work                                                             NaN
# Anthropology                                                       0.292908
# Architecture                                                      -0.007392
# Town & Country Planning and Landscape Design                      -0.007392
# Sports Science                                                    -0.007392
# Anatomy & Physiology                                              -0.930469
# Social Policy                                                           NaN
# Russian & East European Languages                                       NaN
# Counselling                                                       -0.315084
# Complementary Medicine                                                  NaN
# Physiotherapy                                                           NaN
# Iberian Languages/Hispanic Studies                                -0.007392
# Dentistry                                                               NaN
# Ophthalmics                                                             NaN
# Nursing                                                           -0.007392
# East & South Asian Studies                                              NaN
# Fashion                                                                 NaN
# French                                                            -0.007392
# Hospitality, Leisure, Recreation & Tourism                              NaN
# Youth Work                                                              NaN

# %% [markdown]
# ## Netherlands

# %%
country = 'Netherlands'

# %%
category = 'field of work'

# Get the count
result = count_diff(df, columns=to_sub, category=category, country=country, multi_choice=True)

# Showing the results
result
# Out:
#                                        Count  Percentage  Percentage in 2017  \
# field of work for Netherlands
# Computer Science                          20   37.037037           53.333333
# Physics and Astronomy                     15   27.777778           26.666667
# Biological Sciences                       14   25.925926           28.000000
# Medicine                                  11   20.370370           14.666667
# Geography & Environmental Sciences         8   14.814815           13.333333
# Chemistry                                  5    9.259259           14.666667
# Linguistics                                4    7.407407           13.333333
# Communication & Media Studies              3    5.555556            6.666667
# Education                                  3    5.555556            8.000000
# History                                    3    5.555556           12.000000
# Civil Engineering                          2    3.703704            5.333333
# Psychology                                 2    3.703704            2.666667
# Politics                                   1    1.851852                 NaN
# Philosophy                                 1    1.851852            1.333333
# Pharmacology & Pharmacy                    1    1.851852            5.333333
# Ophthalmics                                1    1.851852                 NaN
# Mathematics                                1    1.851852            6.666667
# Anatomy & Physiology                       1    1.851852                 NaN
# History of Art, Architecture & Design      1    1.851852            1.333333
# General Engineering                        1    1.851852            1.333333
# Art & Design                               1    1.851852            1.333333
# Food Science                               1    1.851852            6.666667
# Electrical & Electronic Engineering        1    1.851852                 NaN
# Dentistry                                  1    1.851852                 NaN
# Classics & Ancient History                 1    1.851852            4.000000
# Chemical Engineering                       1    1.851852            1.333333
# Sociology                                  1    1.851852            1.333333
#
#                                        Difference with previous year
# field of work for Netherlands
# Computer Science                                          -16.296296
# Physics and Astronomy                                       1.111111
# Biological Sciences                                        -2.074074
# Medicine                                                    5.703704
# Geography & Environmental Sciences                          1.481481
# Chemistry                                                  -5.407407
# Linguistics                                                -5.925926
# Communication & Media Studies                              -1.111111
# Education                                                  -2.444444
# History                                                    -6.444444
# Civil Engineering                                          -1.629630
# Psychology                                                  1.037037
# Politics                                                         NaN
# Philosophy                                                  0.518519
# Pharmacology & Pharmacy                                    -3.481481
# Ophthalmics                                                      NaN
# Mathematics                                                -4.814815
# Anatomy & Physiology                                             NaN
# History of Art, Architecture & Design                       0.518519
# General Engineering                                         0.518519
# Art & Design                                                0.518519
# Food Science                                               -4.814815
# Electrical & Electronic Engineering                              NaN
# Dentistry                                                        NaN
# Classics & Ancient History                                 -2.148148
# Chemical Engineering                                        0.518519
# Sociology                                                   0.518519

# %% [markdown]
# ## New Zealand

# %%
country = 'New Zealand'

# %%
category = 'field of work'

# Get the count
result = count_diff(df, columns=to_sub, category=category, country=country, multi_choice=True)

# Showing the results
result
# Out:
#                                           Count  Percentage
# field of work for New Zealand
# Computer Science                             17   45.945946
# Geography & Environmental Sciences           15   40.540541
# Biological Sciences                          10   27.027027
# Physics and Astronomy                         9   24.324324
# Mathematics                                   7   18.918919
# Civil Engineering                             5   13.513514
# Mechanical Engineering                        4   10.810811
# General Engineering                           4   10.810811
# Electrical & Electronic Engineering           4   10.810811
# Geology                                       3    8.108108
# Materials Technology                          3    8.108108
# Chemistry                                     3    8.108108
# Agriculture & Forestry                        3    8.108108
# Education                                     2    5.405405
# Aeronautical & Manufacturing Engineering      2    5.405405
# Linguistics                                   2    5.405405
# Medicine                                      2    5.405405
# Psychology                                    1    2.702703
# Robotics                                      1    2.702703
# Social Work                                   1    2.702703
# Accounting & Finance                          1    2.702703
# History                                       1    2.702703
# Communication & Media Studies                 1    2.702703
# Chemical Engineering                          1    2.702703
# Art & Design                                  1    2.702703
# Anthropology                                  1    2.702703
# Anatomy & Physiology                          1    2.702703
# Youth Work                                    1    2.702703

# %% [markdown]
# ## South Africa

# %%
country = 'South Africa'

# %%
category = 'field of work'

# Get the count
result = count_diff(df, columns=to_sub, category=category, country=country, multi_choice=True)

# Showing the results
result
# Out:
#                                         Count  Percentage  Percentage in 2017  \
# field of work for South Africa
# Computer Science                           12   52.173913           26.315789
# Biological Sciences                        10   43.478261                 NaN
# Education                                   4   17.391304           10.526316
# Physics and Astronomy                       4   17.391304           63.157895
# Electrical & Electronic Engineering         2    8.695652            5.263158
# Mathematics                                 2    8.695652           21.052632
# Communication & Media Studies               1    4.347826            5.263158
# Economics                                   1    4.347826                 NaN
# Librarianship & Information Management      1    4.347826                 NaN
# Linguistics                                 1    4.347826            5.263158
# Psychology                                  1    4.347826                 NaN
#
#                                         Difference with previous year
# field of work for South Africa
# Computer Science                                            25.858124
# Biological Sciences                                               NaN
# Education                                                    6.864989
# Physics and Astronomy                                      -45.766590
# Electrical & Electronic Engineering                          3.432494
# Mathematics                                                -12.356979
# Communication & Media Studies                               -0.915332
# Economics                                                         NaN
# Librarianship & Information Management                            NaN
# Linguistics                                                 -0.915332
# Psychology                                                        NaN

# %% [markdown]
# ## United Kingdom

# %% [markdown]
# Most RSEs derive from a background in Physics and Astronomy (38%), followed by Computer science (37%) and finally by Biological sciences (28%). This top three is very different than the results in 2017, while Computer science was the first academic field (42%) and second was Physics and Astronomy (33%).

# %%
country = 'United Kingdom'

# %%
category = 'field of work'

# Get the count
result = count_diff(df, columns=to_sub, category=category, country=country, multi_choice=True)

# Showing the results
result
# Out:
#                                               Count  Percentage  \
# field of work for United Kingdom
# Physics and Astronomy                            90   38.135593
# Computer Science                                 88   37.288136
# Biological Sciences                              67   28.389831
# Geography & Environmental Sciences               43   18.220339
# Medicine                                         39   16.525424
# Chemistry                                        37   15.677966
# Mathematics                                      30   12.711864
# Mechanical Engineering                           20    8.474576
# General Engineering                              17    7.203390
# Education                                        17    7.203390
# Materials Technology                             17    7.203390
# Aeronautical & Manufacturing Engineering         16    6.779661
# Chemical Engineering                             14    5.932203
# Civil Engineering                                13    5.508475
# Electrical & Electronic Engineering              12    5.084746
# Geology                                          12    5.084746
# Agriculture & Forestry                           12    5.084746
# Economics                                        11    4.661017
# Robotics                                         11    4.661017
# Sociology                                        11    4.661017
# History                                          10    4.237288
# Iberian Languages/Hispanic Studies                      0.406504
# Food Science                                            1.626016
# Architecture                                            3.252033
# Social Work                                             0.406504
# Anthropology                                            2.032520
# Veterinary Medicine                                     0.406504
# German                                                  0.406504
# Philosophy                                              0.813008
# Middle Eastern and African Studies                      2.032520
# Marketing                                               0.406504
# East & South Asian Studies                              0.406504
# Law                                                     0.813008
# Youth Work                                              0.406504
# Physiotherapy                                           0.406504
# Politics                                                0.813008
# Russian & East European Languages                            NaN
# Counselling                                             0.406504
# American Studies                                        0.406504
# Fashion                                                 0.406504
# Hospitality, Leisure, Recreation & Tourism              0.406504
#
#                                               Difference with previous year
# field of work for United Kingdom
# Physics and Astronomy                                              5.615268
# Computer Science                                                  -5.801295
# Biological Sciences                                               -6.569519
# Geography & Environmental Sciences                                 4.399201
# Medicine                                                           1.484773
# Chemistry                                                         -0.175692
# Mathematics                                                       -3.954802
# Mechanical Engineering                                            -1.281521
# General Engineering                                               -0.926691
# Education                                                          2.325341
# Materials Technology                                               0.699325
# Aeronautical & Manufacturing Engineering                           2.308116
# Chemical Engineering                                               1.054155
# Civil Engineering                                                  0.630426
# Electrical & Electronic Engineering                               -5.077856
# Geology                                                            0.613201
# Agriculture & Forestry                                             2.645721
# Economics                                                          1.408984
# Robotics                                                           1.002480
# Sociology                                                          2.221993
# History                                                            0.985256
# Linguistics                                                       -0.251481
# Pharmacology & Pharmacy                                            0.950806
# Classics & Ancient History                                         0.544302
# Psychology                                                        -0.675210
# Librarianship & Information Management                             0.137798
# Social Policy                                                      0.120573
# Art & Design                                                       0.916357
# English                                                            1.729365
# History of Art, Architecture & Design                              0.899132
# Accounting & Finance                                                    NaN
# Communication & Media Studies                                      0.899132
# Anatomy & Physiology                                              -2.352901
# Dentistry                                                          1.288411
# French                                                             1.288411
# Music                                                              1.288411
# Town & Country Planning and Landscape Design                       0.068899
# Criminology                                                        1.288411
# Business & Management Studies                                     -1.167838
# Nursing                                                            0.051674
# Complementary Medicine                                             0.864682
# Ophthalmics                                                       -0.354830
# Sports Science                                                     0.864682
# Theology & Religious Studies                                      -0.354830
# Land & Property Management                                         0.458178
# Iberian Languages/Hispanic Studies                                 0.864682
# Food Science                                                      -0.354830
# Architecture                                                      -1.980846
# Social Work                                                        0.440954
# Anthropology                                                      -1.185063
# Veterinary Medicine                                                0.440954
# German                                                             0.440954
# Philosophy                                                         0.034449
# Middle Eastern and African Studies                                -1.185063
# Marketing                                                          0.440954
# East & South Asian Studies                                         0.440954
# Law                                                                0.034449
# Youth Work                                                         0.440954
# Physiotherapy                                                      0.017225
# Politics                                                          -0.389279
# Russian & East European Languages                                       NaN
# Counselling                                                        0.017225
# American Studies                                                   0.017225
# Fashion                                                            0.017225
# Hospitality, Leisure, Recreation & Tourism                         0.017225

# %% [markdown]
# ## United States

# %%
country = 'United States'

# %%
category = 'field of work'

# Get the count
result = count_diff(df, columns=to_sub, category=category, country=country, multi_choice=True)

# Showing the results
result
# Out:
#                
# Computer Science                                                 -16.305663
# Biological Sciences                                               -5.984725
# Geography & Environmental Sciences                                 3.376320
# Mathematics                                                       -3.906348
# Medicine                                                          -1.853011
# Economics                                                          1.761195
# Electrical & Electronic Engineering                               -2.533283
# Geology                                                          -10.028797
# Chemical Engineering                                              -1.439840
# Materials Technology                                              -4.574100
# Education                                                         -2.733609
# Social Policy                                                      2.787864
# Sociology                                                         -0.279621
# Chemistry                                                        -11.389341
# Pharmacology & Pharmacy                                            1.494095
# Anthropology                                                       0.880598
# Mechanical Engineering                                            -9.548850
# Politics                                                          -0.413171
# Communication & Media Studies                                      1.427319
# Anatomy & Physiology                                               0.813822
# Psychology                                                        -1.640165
# Business & Management Studies                                      0.813822
# History                                                            1.427319
# Librarianship & Information Management                            -1.640165
# Linguistics                                                        0.813822
# Robotics                                                          -2.933934
# Theology & Religious Studies                                            NaN
# Middle Eastern and African Studies                                      NaN
# Accounting & Finance                                               0.747047
# General Engineering                                               -4.160928
# Agriculture & Forestry                                            -1.706940
# Civil Engineering                                                 -4.160928
# Art & Design                                                       0.747047
# Architecture                                                       0.747047
# American Studies                                                        NaN
# Veterinary Medicine                                                0.133550
# Marketing                                                         -1.160219
# Law                                                                     NaN
# Land & Property Management                                              NaN
# English                                                                 NaN
# Philosophy                                                              NaN
# Criminology                                                             NaN
# Complementary Medicine                                                  NaN
# Classics & Ancient History                                              NaN
# Town & Country Planning and Landscape Design                       0.066775

# %% [markdown]
# ## Rest of the World

# %%
country = 'World'

# %%
category = 'field of work'

# Get the count
result = count_diff(df, columns=to_sub, category=category, country=country, multi_choice=True)

# Showing the results
result
# Out:
#                                         Count  Percentage
# field of work for World
# Biological Sciences                        22   40.000000
# Computer Science                           20   36.363636
# Mathematics                                 9   16.363636
# Physics and Astronomy                       8   14.545455
# Geography & Environmental Sciences          8   14.545455
# Medicine                                    6   10.909091
# Education                                   5    9.090909
# General Engineering                         4    7.272727
# Agriculture & Forestry                      3    5.454545
# Psychology                                  3    5.454545
# Sociology                                   3    5.454545
# Economics                                   2    3.636364
# Anatomy & Physiology                        2    3.636364
# Politics                                    2    3.636364
# Pharmacology & Pharmacy                     2    3.636364
# Chemistry                                   2    3.636364
# Materials Technology                        2    3.636364
# Communication & Media Studies               2    3.636364
# History                                     2    3.636364
# Marketing                                   2    3.636364
# Civil Engineering                           2    3.636364
# Geology                                     2    3.636364
# Classics & Ancient History                  2    3.636364
# Electrical & Electronic Engineering         2    3.636364
# English                                     1    1.818182
# Social Work                                 1    1.818182
# Social Policy                               1    1.818182
# Architecture                                1    1.818182
# Art & Design                                1    1.818182
# Philosophy                                  1    1.818182
# Middle Eastern and African Studies          1    1.818182
# Ophthalmics                                 1    1.818182
# History of Art, Architecture & Design       1    1.818182
# Business & Management Studies               1    1.818182
# French                                      1    1.818182
# Linguistics                                 1    1.818182
# Librarianship & Information Management      1    1.818182
# Iberian Languages/Hispanic Studies          1    1.818182
# German                                      1    1.818182
