# %% [markdown]
# # Introduction

# %% [markdown]
# ## Setting up

# %%
# %%capture  
# Import notebook containing the imports the functions and the dataset
# %run "./0. Imports and functions.ipynb"

# Import notebook containing sampled dataset
# %run "./1. Overview and sampling.ipynb"

# %% [markdown]
# # Questions about previous employment

# %% [markdown]
# Several questions were about the participants previous job. The idea is to collect insights of their career path and understand what are their motivations to be an RSE.
#
# We also asked the participants to rank the reasons why they chose their actual position among 8 different ones:
# * Desire to work in a research environment
# * Freedom to choose own working practices
# * Desire to advance research
# * I want to learn new skills
# * Opportunity to develop software
# * Flexible working hours
# * Ability to work across disciplines
# * Opportunity for career advancement
# * The salary

# %%
prev_work = ['prevEmp1. Where was your previous job based?']
reason_choice = [x for x in df.columns if x[:8] == 'prevEmp2']

# %% [markdown]
# ## Australia

# %% [markdown]
# ### Where the previous job was based

# %%
country = 'Australia'
category = 'Where the previous job was based'
results = count_diff(df, prev_work, country, category)
results
# Out:
#                                                 Count  Percentage
# Where the previous job was based for Australia
# University                                         44   55.696203
# Private company                                    19   24.050633
# Government                                          8   10.126582
# National laboratory                                 4    5.063291
# Other                                               3    3.797468
# Non-profit organization                             1    1.265823

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### What were the reasons to choose the current job

# %%
category = 'Reasons to choose current job'
results = count_ranking(df, reason_choice, country, category)
results
# Out:
#                                              Rank 1     Rank 2     Rank 3  \
# Reasons to choose current job
# Desire to work in a research environment  31.707317  17.073171  13.580247
# Freedom to choose own working practices   15.853659   9.756098   9.876543
# Desire to advance research                14.634146  13.414634  14.814815
# Opportunity to develop software           13.414634  12.195122  11.111111
# Ability to work across disciplines         7.317073  10.975610   7.407407
# I want to learn new skills                 7.317073  12.195122  11.111111
# Flexible working hours                     4.878049  13.414634   8.641975
# Opportunity for career advancement         3.658537   7.317073  11.111111
# The salary                                 1.219512   3.658537  12.345679
#
#                                              Rank 4     Rank 5  Rank 6  \
# Reasons to choose current job
# Desire to work in a research environment   8.641975   8.641975     NaN
# Freedom to choose own working practices   16.049383   8.641975     NaN
# Desire to advance research                13.580247   8.641975     NaN
# Opportunity to develop software            9.876543  12.345679     NaN
# Ability to work across disciplines         7.407407  12.345679     NaN
# I want to learn new skills                11.111111  11.111111     NaN
# Flexible working hours                    11.111111  14.814815     NaN
# Opportunity for career advancement         9.876543  12.345679     NaN
# The salary                                12.345679  11.111111     NaN
#
#                                           Rank 7  Rank 8
# Reasons to choose current job
# Desire to work in a research environment     NaN     NaN
# Freedom to choose own working practices      NaN     NaN
# Desire to advance research                   NaN     NaN
# Opportunity to develop software              NaN     NaN
# Ability to work across disciplines           NaN     NaN
# I want to learn new skills                   NaN     NaN
# Flexible working hours                       NaN     NaN
# Opportunity for career advancement           NaN     NaN
# The salary                                   NaN     NaN

# %%
plot_ranking(results, category, country)

# %% [markdown]
# ## Germany

# %% [markdown]
# ### Where the previous job was based

# %%
country = 'Germany'
category = 'Where the previous job was based'
results = count_diff(df, prev_work, country, category)
results
# Out:
#                                                   Count  Percentage  \
# Where the previous job was based for Germany
# University                                          142   46.254072
# Private Company                                      56   18.241042
# Other                                                39   12.703583
# Helmholtz Association of German Research Centres     31   10.097720
# Leibniz Association                                  11    3.583062
# Fraunhofer Society                                   10    3.257329
# Max Planck Society                                    8    2.605863
# Government                                            5    1.628664
# University of Applied Sciences                        5    1.628664
#
#                                                   Difference with previous year
# Where the previous job was based for Germany
# University                                                            -7.859852
# Private Company                                                        7.798004
# Other                                                                  2.260545
# Helmholtz Association of German Research Centres                       3.135695
# Leibniz Association                                                   -0.214406
# Fraunhofer Society                                                          NaN
# Max Planck Society                                                    -8.470086
# Government                                                            -0.586525
# University of Applied Sciences                                         0.679297

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### What were the reasons to choose the current job

# %%
category = 'Reasons to choose current job'
results = count_ranking(df, reason_choice, country, category)
results
# Out:
#                                              Rank 1     Rank 2     Rank 3  \
# Reasons to choose current job
# Desire to work in a research environment  24.050633  15.506329  14.920635
# Freedom to choose own working practices   24.050633  17.088608  15.238095
# Desire to advance research                16.772152  12.974684   8.253968
# I want to learn new skills                12.341772  13.607595  15.555556
# Opportunity to develop software            8.544304  13.291139  14.920635
# Opportunity for career advancement         4.746835   4.113924   6.666667
# Ability to work across disciplines         3.481013  11.392405   9.206349
# Flexible working hours                     3.481013   9.810127  11.746032
# The salary                                 2.531646   2.215190   3.492063
#
#                                              Rank 4     Rank 5  Rank 6  \
# Reasons to choose current job
# Desire to work in a research environment   8.253968   7.324841     NaN
# Freedom to choose own working practices    8.888889  13.057325     NaN
# Desire to advance research                 9.523810   7.006369     NaN
# I want to learn new skills                15.555556  14.649682     NaN
# Opportunity to develop software           10.793651   9.872611     NaN
# Opportunity for career advancement         7.301587   7.324841     NaN
# Ability to work across disciplines        15.238095  12.738854     NaN
# Flexible working hours                    16.825397  18.471338     NaN
# The salary                                 7.619048   9.554140     NaN
#
#                                           Rank 7  Rank 8
# Reasons to choose current job
# Desire to work in a research environment     NaN     NaN
# Freedom to choose own working practices      NaN     NaN
# Desire to advance research                   NaN     NaN
# I want to learn new skills                   NaN     NaN
# Opportunity to develop software              NaN     NaN
# Opportunity for career advancement           NaN     NaN
# Ability to work across disciplines           NaN     NaN
# Flexible working hours                       NaN     NaN
# The salary                                   NaN     NaN

# %%
plot_ranking(results, category, country)

# %% [markdown]
# ## New Zealand

# %% [markdown]
# ### Where the previous job was based

# %%
country = 'New Zealand'
category = 'Where the previous job was based'
results = count_diff(df, prev_work, country, category)
results
# Out:
#                                                   Count  Percentage
# Where the previous job was based for New Zealand
# University                                           14   41.176471
# Private company                                       8   23.529412
# Government                                            5   14.705882
# Non-profit organization                               4   11.764706
# National laboratory                                   2    5.882353
# Other                                                 1    2.941176

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### What were the reasons to choose the current job

# %%
category = 'Reasons to choose current job'
results = count_ranking(df, reason_choice, country, category)
results
# Out:
#                                              Rank 1     Rank 2     Rank 3  \
# Reasons to choose current job
# Desire to work in a research environment  22.857143  14.285714  20.000000
# Freedom to choose own working practices   20.000000   5.714286        NaN
# Desire to advance research                14.285714   5.714286  20.000000
# Opportunity to develop software           14.285714  22.857143  11.428571
# The salary                                 8.571429   5.714286   2.857143
# Ability to work across disciplines         5.714286   8.571429  14.285714
# I want to learn new skills                 5.714286  14.285714   8.571429
# Opportunity for career advancement         5.714286   5.714286   2.857143
# Flexible working hours                     2.857143  17.142857  20.000000
#
#                                              Rank 4     Rank 5  Rank 6  \
# Reasons to choose current job
# Desire to work in a research environment        NaN  11.428571     NaN
# Freedom to choose own working practices   11.428571  14.285714     NaN
# Desire to advance research                 8.571429   8.571429     NaN
# Opportunity to develop software           20.000000   8.571429     NaN
# The salary                                17.142857   2.857143     NaN
# Ability to work across disciplines        11.428571   5.714286     NaN
# I want to learn new skills                17.142857  20.000000     NaN
# Opportunity for career advancement         5.714286  17.142857     NaN
# Flexible working hours                     8.571429  11.428571     NaN
#
#                                           Rank 7  Rank 8
# Reasons to choose current job
# Desire to work in a research environment     NaN     NaN
# Freedom to choose own working practices      NaN     NaN
# Desire to advance research                   NaN     NaN
# Opportunity to develop software              NaN     NaN
# The salary                                   NaN     NaN
# Ability to work across disciplines           NaN     NaN
# I want to learn new skills                   NaN     NaN
# Opportunity for career advancement           NaN     NaN
# Flexible working hours                       NaN     NaN

# %%
plot_ranking(results, category, country)

# %% [markdown]
# ## South Africa

# %% [markdown]
# ### Where the previous job was based

# %%
country = 'South Africa'
category = 'Where the previous job was based'
results = count_diff(df, prev_work, country, category)
results
# Out:
#                                                    Count  Percentage  \
# Where the previous job was based for South Africa
# University                                            13   61.904762
# National laboratory                                    3   14.285714
# Non-profit organization                                2    9.523810
# Government                                             1    4.761905
# Private company                                        1    4.761905
# Other                                                  1    4.761905
#
#                                                    Difference with previous year
# Where the previous job was based for South Africa
# University                                                              4.010025
# National laboratory                                                          NaN
# Non-profit organization                                                      NaN
# Government                                                                   NaN
# Private company                                                              NaN
# Other                                                                        NaN

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### What were the reasons to choose the current job

# %%
category = 'Reasons to choose current job'
results = count_ranking(df, reason_choice, country, category)
results
# Out:
#                                              Rank 1     Rank 2     Rank 3  \
# Reasons to choose current job
# Desire to work in a research environment  26.086957   8.695652  17.391304
# Freedom to choose own working practices   17.391304   8.695652   8.695652
# Desire to advance research                13.043478  17.391304  30.434783
# I want to learn new skills                13.043478   8.695652   8.695652
# Flexible working hours                     8.695652  17.391304   4.347826
# Opportunity for career advancement         8.695652   8.695652   8.695652
# The salary                                 8.695652  13.043478   8.695652
# Opportunity to develop software            4.347826   4.347826  13.043478
# Ability to work across disciplines              NaN  13.043478        NaN
#
#                                              Rank 4     Rank 5  Rank 6  \
# Reasons to choose current job
# Desire to work in a research environment  13.043478        NaN     NaN
# Freedom to choose own working practices    4.347826   4.347826     NaN
# Desire to advance research                 8.695652   8.695652     NaN
# I want to learn new skills                 8.695652  17.391304     NaN
# Flexible working hours                     8.695652  13.043478     NaN
# Opportunity for career advancement        13.043478  17.391304     NaN
# The salary                                 4.347826   8.695652     NaN
# Opportunity to develop software            8.695652   8.695652     NaN
# Ability to work across disciplines        30.434783  21.739130     NaN
#
#                                           Rank 7  Rank 8
# Reasons to choose current job
# Desire to work in a research environment     NaN     NaN
# Freedom to choose own working practices      NaN     NaN
# Desire to advance research                   NaN     NaN
# I want to learn new skills                   NaN     NaN
# Flexible working hours                       NaN     NaN
# Opportunity for career advancement           NaN     NaN
# The salary                                   NaN     NaN
# Opportunity to develop software              NaN     NaN
# Ability to work across disciplines           NaN     NaN

# %%
plot_ranking(results, category, country)

# %% [markdown]
# ## United Kingdom

# %% [markdown]
# ### Where the previous job was based

# %%
country = 'United Kingdom'
category = 'Where the previous job was based'
results = count_diff(df, prev_work, country, category)
results
# Out:
#                                                     Count  Percentage  \
# Where the previous job was based for United Kin...
# University                                            136   64.454976
# Private company                                        43   20.379147
# Other                                                  13    6.161137
# National laboratory                                     9    4.265403
# Government                                              6    2.843602
# Non-profit organization                                 4    1.895735
#
#                                                     Difference with previous year
# Where the previous job was based for United Kin...
# University                                                              15.288310
# Private company                                                         -5.454186
# Other                                                                    2.827804
# National laboratory                                                     -1.984597
# Government                                                              -0.489731
# Non-profit organization                                                       NaN

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### What were the reasons to choose the current job

# %%
category = 'Reasons to choose current job'
results = count_ranking(df, reason_choice, country, category)
results
# Out:
#                                              Rank 1     Rank 2     Rank 3  \
# Reasons to choose current job
# Desire to work in a research environment  25.892857  17.488789  14.798206
# Desire to advance research                22.321429  18.834081  10.313901
# Opportunity to develop software           16.071429  17.040359  15.246637
# Freedom to choose own working practices    8.928571   7.623318  11.659193
# Opportunity for career advancement         8.928571   9.865471   8.968610
# I want to learn new skills                 7.589286  10.762332  10.313901
# Flexible working hours                     5.357143   7.623318   9.865471
# The salary                                 2.678571   3.587444   8.071749
# Ability to work across disciplines         2.232143   7.174888  10.762332
#
#                                              Rank 4     Rank 5  Rank 6  \
# Reasons to choose current job
# Desire to work in a research environment  10.313901  10.313901     NaN
# Desire to advance research                11.659193   5.829596     NaN
# Opportunity to develop software            9.865471   8.071749     NaN
# Freedom to choose own working practices   12.556054  16.143498     NaN
# Opportunity for career advancement         7.174888   8.968610     NaN
# I want to learn new skills                13.901345  16.591928     NaN
# Flexible working hours                    11.659193  15.246637     NaN
# The salary                                 6.726457   8.071749     NaN
# Ability to work across disciplines        16.143498  10.762332     NaN
#
#                                           Rank 7  Rank 8
# Reasons to choose current job
# Desire to work in a research environment     NaN     NaN
# Desire to advance research                   NaN     NaN
# Opportunity to develop software              NaN     NaN
# Freedom to choose own working practices      NaN     NaN
# Opportunity for career advancement           NaN     NaN
# I want to learn new skills                   NaN     NaN
# Flexible working hours                       NaN     NaN
# The salary                                   NaN     NaN
# Ability to work across disciplines           NaN     NaN

# %%
plot_ranking(results, category, country)

# %% [markdown]
# ## United States

# %% [markdown]
# ### Where the previous job was based

# %%
country = 'United States'
category = 'Where the previous job was based'
results = count_diff(df, prev_work, country, category)
results
# Out:
#                                                     Count  Percentage  \
# Where the previous job was based for United States
# University                                             76   53.900709
# Private company                                        40   28.368794
# National laboratory                                     8    5.673759
# Other                                                   7    4.964539
# Non-profit organization                                 6    4.255319
# Government                                              4    2.836879
#
#                                                     Difference with previous year
# Where the previous job was based for United States
# University                                                               5.493066
# Private company                                                          5.438858
# National laboratory                                                     -0.695668
# Other                                                                         NaN
# Non-profit organization                                                       NaN
# Government                                                                    NaN

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### What were the reasons to choose the current job

# %%
category = 'Reasons to choose current job'
results = count_ranking(df, reason_choice, country, category)
results
# Out:
#                                              Rank 1     Rank 2     Rank 3  \
# Reasons to choose current job
# Desire to work in a research environment  27.777778  20.138889  11.805556
# Desire to advance research                22.916667  13.194444  13.194444
# Opportunity to develop software           12.500000   7.638889  12.500000
# I want to learn new skills                 9.027778   8.333333  11.805556
# The salary                                 8.333333   9.722222   6.250000
# Freedom to choose own working practices    7.638889  11.805556  15.277778
# Opportunity for career advancement         7.638889  12.500000   9.027778
# Flexible working hours                     2.777778   6.250000  10.416667
# Ability to work across disciplines         1.388889  10.416667   9.722222
#
#                                              Rank 4     Rank 5  Rank 6  \
# Reasons to choose current job
# Desire to work in a research environment  11.888112   9.790210     NaN
# Desire to advance research                 7.692308   6.293706     NaN
# Opportunity to develop software           17.482517  12.587413     NaN
# I want to learn new skills                11.888112  15.384615     NaN
# The salary                                 6.293706   8.391608     NaN
# Freedom to choose own working practices   12.587413   9.790210     NaN
# Opportunity for career advancement         6.993007   6.293706     NaN
# Flexible working hours                    16.083916  17.482517     NaN
# Ability to work across disciplines         9.090909  13.986014     NaN
#
#                                           Rank 7  Rank 8
# Reasons to choose current job
# Desire to work in a research environment     NaN     NaN
# Desire to advance research                   NaN     NaN
# Opportunity to develop software              NaN     NaN
# I want to learn new skills                   NaN     NaN
# The salary                                   NaN     NaN
# Freedom to choose own working practices      NaN     NaN
# Opportunity for career advancement           NaN     NaN
# Flexible working hours                       NaN     NaN
# Ability to work across disciplines           NaN     NaN

# %%
plot_ranking(results, category, country)

# %% [markdown]
# ## Rest of the world

# %% [markdown]
# ### Where the previous job was based

# %%
country = 'World'
category = 'Where the previous job was based'
results = count_diff(df, prev_work, country, category)
results
# Out:
#                                             Count  Percentage
# Where the previous job was based for World
# University                                     22   46.808511
# Private company                                11   23.404255
# National laboratory                             5   10.638298
# Non-profit organization                         3    6.382979
# Government                                      3    6.382979
# Other                                           2    4.255319
# NGO                                             1    2.127660

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### What were the reasons to choose the current job

# %%
category = 'Reasons to choose current job'
results = count_ranking(df, reason_choice, country, category)
results
# Out:
#                                              Rank 1     Rank 2     Rank 3  \
# Reasons to choose current job
# Freedom to choose own working practices   31.250000  14.583333   6.250000
# Desire to advance research                18.750000  10.416667  12.500000
# Desire to work in a research environment  18.750000  22.916667  16.666667
# Flexible working hours                     8.333333  12.500000  12.500000
# I want to learn new skills                 6.250000   4.166667  14.583333
# Opportunity for career advancement         6.250000  10.416667   2.083333
# Opportunity to develop software            6.250000  14.583333   8.333333
# The salary                                 4.166667   4.166667   6.250000
# Ability to work across disciplines              NaN   6.250000  20.833333
#
#                                              Rank 4     Rank 5  Rank 6  \
# Reasons to choose current job
# Freedom to choose own working practices   10.416667   6.250000     NaN
# Desire to advance research                10.416667   8.333333     NaN
# Desire to work in a research environment  12.500000  10.416667     NaN
# Flexible working hours                    12.500000  16.666667     NaN
# I want to learn new skills                14.583333  18.750000     NaN
# Opportunity for career advancement         4.166667   6.250000     NaN
# Opportunity to develop software           16.666667  10.416667     NaN
# The salary                                 6.250000  10.416667     NaN
# Ability to work across disciplines        12.500000  12.500000     NaN
#
#                                           Rank 7  Rank 8
# Reasons to choose current job
# Freedom to choose own working practices      NaN     NaN
# Desire to advance research                   NaN     NaN
# Desire to work in a research environment     NaN     NaN
# Flexible working hours                       NaN     NaN
# I want to learn new skills                   NaN     NaN
# Opportunity for career advancement           NaN     NaN
# Opportunity to develop software              NaN     NaN
# The salary                                   NaN     NaN
# Ability to work across disciplines           NaN     NaN

# %%
plot_ranking(results, category, country)
