# %% [markdown]
# # Introduction

# %% [markdown]
# ## Setting up

# %%
# %%capture  
# Import notebook containing the imports the functions and the dataset
# %run "./0. Imports and functions.ipynb"

# Import notebook containing sampled dataset
# %run "./1. Overview and sampling.ipynb"

# %% [markdown]
# # Socio demographic

# %%
age = ['socio3. Please select your age']
age_order = ['18 to 24 years', '25 to 34 years', '35 to 44 years', '45 to 54 years', '55 to 64 years', 'Age 65 or older', 'Prefer not to say']

gender = ["socio2. Please select your gender"]

ethnicity = [x for x in df.columns if x[:7] == 'socio5.']
ethn_us = ['socio5us. Do you consider yourself Hispanic or Latino']

disability = ['disa1. Do you have a condition that is defined as a disability by your country?']

# %% [markdown]
# ## Australia

# %%
country = 'Australia'

# %% [markdown]
# ### Age

# %%
category = 'Age'
results = count_diff(df, age, country, category, order_index=age_order)
results
# Out:
#                    Count  Percentage
# Age for Australia
# 18 to 24 years       1.0    1.408451
# 25 to 34 years      22.0   30.985915
# 35 to 44 years      24.0   33.802817
# 45 to 54 years      17.0   23.943662
# 55 to 64 years       4.0    5.633803
# Age 65 or older      NaN         NaN
# Prefer not to say    3.0    4.225352

# %%
plot_cat_comparison(results, country=country, category=category, order_index=age_order)

# %% [markdown]
# ### Gender

# %%
category = 'Gender'
results = count_diff(df, gender, country, category)
results
# Out:
#                       Count  Percentage
# Gender for Australia
# Male                     57   80.281690
# Female                   12   16.901408
# Prefer not to say         2    2.816901

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ## Germany

# %%
country = 'Germany'

# %% [markdown]
# ### Age

# %%
category = 'Age'
results = count_diff(df, age, country, category, order_index=age_order)
results
# Out:
#                    Count  Percentage  Difference with previous year
# Age for Germany
# 18 to 24 years       5.0    1.811594                      -0.096803
# 25 to 34 years     139.0   50.362319                       5.324151
# 35 to 44 years      91.0   32.971014                      -5.578604
# 45 to 54 years      28.0   10.144928                       1.366302
# 55 to 64 years      11.0    3.985507                      -1.739684
# Age 65 or older      NaN         NaN                            NaN
# Prefer not to say    2.0    0.724638                            NaN

# %%
plot_cat_comparison(results, country=country, category=category, order_index=age_order)

# %% [markdown]
# ### Gender

# %%
category = 'Gender'
results = count_diff(df, gender, country, category)
results
# Out:
#                     Count  Percentage  Difference with previous year
# Gender for Germany
# Male                  238   86.231884                       2.961922
# Female                 27    9.782609                      -3.145148
# Prefer not to say      11    3.985507                       0.183226

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ## Netherlands

# %%
country = 'Netherlands'

# %% [markdown]
# ### Age

# %%
category = 'Age'
results = count_diff(df, age, country, category, order_index=age_order)
results
# Out:
#                      Count  Percentage  Difference with previous year
# Age for Netherlands
# 18 to 24 years         NaN         NaN                            NaN
# 25 to 34 years        15.0   34.090909                      -7.938076
# 35 to 44 years        22.0   50.000000                       6.521739
# 45 to 54 years         6.0   13.636364                       3.491436
# 55 to 64 years         1.0    2.272727                      -2.075099
# Age 65 or older        NaN         NaN                            NaN
# Prefer not to say      NaN         NaN                            NaN

# %%
plot_cat_comparison(results, country=country, category=category, order_index=age_order)

# %% [markdown]
# ### Gender

# %%
category = 'Gender'
results = count_diff(df, gender, country, category)
results
# Out:
#                         Count  Percentage  Difference with previous year
# Gender for Netherlands
# Male                       40   90.909091                       2.503294
# Female                      3    6.818182                      -0.428195
# Prefer not to say           1    2.272727                      -2.075099

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ## New Zealand

# %%
country = 'New Zealand'

# %% [markdown]
# ### Age

# %%
category = 'Age'
results = count_diff(df, age, country, category, order_index=age_order)
results
# Out:
#                      Count  Percentage
# Age for New Zealand
# 18 to 24 years         NaN         NaN
# 25 to 34 years         9.0   27.272727
# 35 to 44 years         9.0   27.272727
# 45 to 54 years         8.0   24.242424
# 55 to 64 years         5.0   15.151515
# Age 65 or older        2.0    6.060606
# Prefer not to say      NaN         NaN

# %%
plot_cat_comparison(results, country=country, category=category, order_index=age_order)

# %% [markdown]
# ### Gender

# %%
category = 'Gender'
results = count_diff(df, gender, country, category)
results
# Out:
#                         Count  Percentage
# Gender for New Zealand
# Male                       30   90.909091
# Female                      3    9.090909

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ## South Africa

# %%
country = 'South Africa'

# %% [markdown]
# ### Age

# %%
category = 'Age'
results = count_diff(df, age, country, category, order_index=age_order)
results
# Out:
#                       Count  Percentage  Difference with previous year
# Age for South Africa
# 18 to 24 years          1.0    5.263158                            NaN
# 25 to 34 years          6.0   31.578947                      -4.784689
# 35 to 44 years          9.0   47.368421                      11.004785
# 45 to 54 years          2.0   10.526316                      -7.655502
# 55 to 64 years          1.0    5.263158                            NaN
# Age 65 or older         NaN         NaN                            NaN
# Prefer not to say       NaN         NaN                            NaN

# %%
plot_cat_comparison(results, country=country, category=category, order_index=age_order)

# %% [markdown]
# ### Gender

# %%
category = 'Gender'
results = count_diff(df, gender, country, category)
results
# Out:
#                          Count  Percentage  Difference with previous year
# Gender for South Africa
# Male                        17   89.473684                      -1.435407
# Female                       2   10.526316                       1.435407

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ## United Kingdom

# %%
country = 'United Kingdom'

# %% [markdown]
# ### Age

# %%
category = 'Age'
results = count_diff(df, age, country, category, order_index=age_order)
results
# Out:
#                         Count  Percentage  Difference with previous year
# Age for United Kingdom
# 18 to 24 years              1         0.5                      -0.888889
# 25 to 34 years             71        35.5                      -0.611111
# 35 to 44 years             83        41.5                       0.759259
# 45 to 54 years             34        17.0                      -0.129630
# 55 to 64 years              7         3.5                      -1.129630
# Age 65 or older             1         0.5                            NaN
# Prefer not to say           3         1.5                            NaN

# %%
plot_cat_comparison(results, country=country, category=category, order_index=age_order)

# %% [markdown]
# ### Gender

# %%
category = 'Gender'
results = count_diff(df, gender, country, category)
results
# Out:
#                            Count  Percentage  Difference with previous year
# Gender for United Kingdom
# Male                         162        81.0                      -3.507042
# Female                        28        14.0                      -1.023474
# Prefer not to say              9         4.5                            NaN
# Other                          1         0.5                       0.030516

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Ethnicity

# %%
category = 'Ethnicity'
results = count_diff(df, ethnicity, country, category, multi_choice=True)
results
# Out:
#                                                     Count  Percentage
# Ethnicity for United Kingdom
# White: English / Welsh / Scottish / Northern Ir...  124.0   53.218884
# White: Any other White background                    57.0   24.463519
# White: Irish                                         10.0    4.291845
# Do not wish to declare                                5.0    2.145923
# Mixed / Multiple Ethnic groups: Any other Mixed...    4.0    1.716738
# Asian / Asian British: Indian                         2.0    0.858369
# Other Ethnic group: Arab                              2.0    0.858369
# Mixed / Multiple Ethnic groups: White and Asian       1.0    0.429185
# Asian / Asian British: Bangladeshi                    1.0    0.429185
# Black / African / Caribbean / Black British: Ca...    1.0    0.429185
# Mixed / Multiple Ethnic groups: White and Black...    0.0    0.000000
# Mixed / Multiple Ethnic groups: White and Black...    0.0    0.000000
# White: Gypsy or Irish Traveller                       0.0    0.000000
# Asian / Asian British: Chinese                        0.0    0.000000
# Asian / Asian British: Any other Asian background     0.0    0.000000
# Black / African / Caribbean / Black British: Af...    0.0    0.000000
# Black / African / Caribbean / Black British: An...    0.0    0.000000
# Other Ethnic group: Any other ethnic group            0.0    0.000000
# Asian / Asian British: Pakistani                      0.0    0.000000

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Disability

# %%
category = "Officially recognised disability"
results = count_diff(df, disability, country, category, y_n=True)

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ## United States

# %%
country = 'United States'

# %% [markdown]
# ### Age

# %%
category = 'Age'
results = count_diff(df, age, country, category, order_index=age_order)
results
# Out:
#                        Count  Percentage  Difference with previous year
# Age for United States
# 18 to 24 years             1    0.751880                      -0.686969
# 25 to 34 years            43   32.330827                      -5.798669
# 35 to 44 years            36   27.067669                      -3.867583
# 45 to 54 years            26   19.548872                      -0.595013
# 55 to 64 years            19   14.285714                       5.652621
# Age 65 or older            4    3.007519                       2.288094
# Prefer not to say          4    3.007519                            NaN

# %%
plot_cat_comparison(results, country=country, category=category, order_index=age_order)

# %% [markdown]
# ### Gender

# %%
category = 'Gender'
results = count_diff(df, gender, country, category)
results
# Out:
#                           Count  Percentage  Difference with previous year
# Gender for United States
# Male                         98   73.134328                      -8.880060
# Female                       29   21.641791                       7.972726
# Prefer not to say             4    2.985075                      -1.331472
# Other                         3    2.238806                            NaN

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Ethnicity

# %%
category = 'Ethnicity'
results = count_diff(df, ethnicity, country, category, multi_choice=True)
results
# Out:
#                                             Count  Percentage
# Ethnicity for United States
# White                                       114.0   77.551020
# Asian                                         7.0    4.761905
# Do not wish to answer                         7.0    4.761905
# Black or African American                     3.0    2.040816
# Some other race                               3.0    2.040816
# American Indian and Alaska Native             1.0    0.680272
# Native Hawaiian and Other Pacific Islander    0.0    0.000000
# NaN                                           0.0    0.000000

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Hispano or Latino

# %%
category = 'Ethnicity USA'
results = count_diff(df, ethn_us, country, category, y_n=True)
results
# Out:
#                                  Count  Percentage
# Ethnicity USA for United States
# Yes                                  8         6.4
# No                                 117        93.6

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ## Rest of the world

# %%
country = 'World'

# %% [markdown]
# ### Age

# %%
category = 'Age'
results = count_diff(df, age, country, category, order_index=age_order)
results
# Out:
#                    Count  Percentage
# Age for World
# 18 to 24 years       NaN         NaN
# 25 to 34 years      18.0   47.368421
# 35 to 44 years      17.0   44.736842
# 45 to 54 years       2.0    5.263158
# 55 to 64 years       1.0    2.631579
# Age 65 or older      NaN         NaN
# Prefer not to say    NaN         NaN

# %%
plot_cat_comparison(results, country=country, category=category, order_index=age_order)

# %% [markdown]
# ### Gender

# %%
category = 'Gender'
results = count_diff(df, gender, country, category)
results
# Out:
#                   Count  Percentage
# Gender for World
# Male                 35   92.105263
# Female                3    7.894737

# %%
plot_cat_comparison(results, country=country, category=category)
