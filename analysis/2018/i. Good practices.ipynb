# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span><ul class="toc-item"><li><span><a href="#Setting-up" data-toc-modified-id="Setting-up-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Setting up</a></span></li></ul></li><li><span><a href="#Good-practices" data-toc-modified-id="Good-practices-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Good practices</a></span><ul class="toc-item"><li><span><a href="#Australia" data-toc-modified-id="Australia-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Australia</a></span><ul class="toc-item"><li><span><a href="#Bus-Factor" data-toc-modified-id="Bus-Factor-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Bus Factor</a></span></li><li><span><a href="#Transition-plan" data-toc-modified-id="Transition-plan-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Transition plan</a></span></li><li><span><a href="#Version-control" data-toc-modified-id="Version-control-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Version control</a></span></li><li><span><a href="#Testing" data-toc-modified-id="Testing-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>Testing</a></span></li><li><span><a href="#Repository" data-toc-modified-id="Repository-2.1.5"><span class="toc-item-num">2.1.5&nbsp;&nbsp;</span>Repository</a></span></li></ul></li><li><span><a href="#Germany" data-toc-modified-id="Germany-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Germany</a></span><ul class="toc-item"><li><span><a href="#Bus-Factor" data-toc-modified-id="Bus-Factor-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Bus Factor</a></span></li><li><span><a href="#Transition-plan" data-toc-modified-id="Transition-plan-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Transition plan</a></span></li><li><span><a href="#Version-control" data-toc-modified-id="Version-control-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Version control</a></span></li><li><span><a href="#Testing" data-toc-modified-id="Testing-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>Testing</a></span></li><li><span><a href="#Repository" data-toc-modified-id="Repository-2.2.5"><span class="toc-item-num">2.2.5&nbsp;&nbsp;</span>Repository</a></span></li></ul></li><li><span><a href="#Netherlands" data-toc-modified-id="Netherlands-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Netherlands</a></span><ul class="toc-item"><li><span><a href="#Bus-Factor" data-toc-modified-id="Bus-Factor-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Bus Factor</a></span></li><li><span><a href="#Transition-plan" data-toc-modified-id="Transition-plan-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Transition plan</a></span></li><li><span><a href="#Version-control" data-toc-modified-id="Version-control-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Version control</a></span></li><li><span><a href="#Testing" data-toc-modified-id="Testing-2.3.4"><span class="toc-item-num">2.3.4&nbsp;&nbsp;</span>Testing</a></span></li><li><span><a href="#Repository" data-toc-modified-id="Repository-2.3.5"><span class="toc-item-num">2.3.5&nbsp;&nbsp;</span>Repository</a></span></li></ul></li><li><span><a href="#New-Zealand" data-toc-modified-id="New-Zealand-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>New Zealand</a></span><ul class="toc-item"><li><span><a href="#Bus-Factor" data-toc-modified-id="Bus-Factor-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Bus Factor</a></span></li><li><span><a href="#Transition-plan" data-toc-modified-id="Transition-plan-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Transition plan</a></span></li><li><span><a href="#Version-control" data-toc-modified-id="Version-control-2.4.3"><span class="toc-item-num">2.4.3&nbsp;&nbsp;</span>Version control</a></span></li><li><span><a href="#Testing" data-toc-modified-id="Testing-2.4.4"><span class="toc-item-num">2.4.4&nbsp;&nbsp;</span>Testing</a></span></li><li><span><a href="#Repository" data-toc-modified-id="Repository-2.4.5"><span class="toc-item-num">2.4.5&nbsp;&nbsp;</span>Repository</a></span></li></ul></li><li><span><a href="#South-Africa" data-toc-modified-id="South-Africa-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>South Africa</a></span><ul class="toc-item"><li><span><a href="#Bus-Factor" data-toc-modified-id="Bus-Factor-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Bus Factor</a></span></li><li><span><a href="#Transition-plan" data-toc-modified-id="Transition-plan-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>Transition plan</a></span></li><li><span><a href="#Version-control" data-toc-modified-id="Version-control-2.5.3"><span class="toc-item-num">2.5.3&nbsp;&nbsp;</span>Version control</a></span></li><li><span><a href="#Testing" data-toc-modified-id="Testing-2.5.4"><span class="toc-item-num">2.5.4&nbsp;&nbsp;</span>Testing</a></span></li><li><span><a href="#Repository" data-toc-modified-id="Repository-2.5.5"><span class="toc-item-num">2.5.5&nbsp;&nbsp;</span>Repository</a></span></li></ul></li><li><span><a href="#United-Kingdom" data-toc-modified-id="United-Kingdom-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>United Kingdom</a></span><ul class="toc-item"><li><span><a href="#Bus-Factor" data-toc-modified-id="Bus-Factor-2.6.1"><span class="toc-item-num">2.6.1&nbsp;&nbsp;</span>Bus Factor</a></span></li><li><span><a href="#Transition-plan" data-toc-modified-id="Transition-plan-2.6.2"><span class="toc-item-num">2.6.2&nbsp;&nbsp;</span>Transition plan</a></span></li><li><span><a href="#Version-control" data-toc-modified-id="Version-control-2.6.3"><span class="toc-item-num">2.6.3&nbsp;&nbsp;</span>Version control</a></span></li><li><span><a href="#Testing" data-toc-modified-id="Testing-2.6.4"><span class="toc-item-num">2.6.4&nbsp;&nbsp;</span>Testing</a></span></li><li><span><a href="#Repository" data-toc-modified-id="Repository-2.6.5"><span class="toc-item-num">2.6.5&nbsp;&nbsp;</span>Repository</a></span></li></ul></li><li><span><a href="#United-States" data-toc-modified-id="United-States-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>United States</a></span><ul class="toc-item"><li><span><a href="#Bus-Factor" data-toc-modified-id="Bus-Factor-2.7.1"><span class="toc-item-num">2.7.1&nbsp;&nbsp;</span>Bus Factor</a></span></li><li><span><a href="#Transition-plan" data-toc-modified-id="Transition-plan-2.7.2"><span class="toc-item-num">2.7.2&nbsp;&nbsp;</span>Transition plan</a></span></li><li><span><a href="#Version-control" data-toc-modified-id="Version-control-2.7.3"><span class="toc-item-num">2.7.3&nbsp;&nbsp;</span>Version control</a></span></li><li><span><a href="#Testing" data-toc-modified-id="Testing-2.7.4"><span class="toc-item-num">2.7.4&nbsp;&nbsp;</span>Testing</a></span></li><li><span><a href="#Repository" data-toc-modified-id="Repository-2.7.5"><span class="toc-item-num">2.7.5&nbsp;&nbsp;</span>Repository</a></span></li></ul></li><li><span><a href="#Rest-of-the-world" data-toc-modified-id="Rest-of-the-world-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Rest of the world</a></span><ul class="toc-item"><li><span><a href="#Bus-Factor" data-toc-modified-id="Bus-Factor-2.8.1"><span class="toc-item-num">2.8.1&nbsp;&nbsp;</span>Bus Factor</a></span></li><li><span><a href="#Transition-plan" data-toc-modified-id="Transition-plan-2.8.2"><span class="toc-item-num">2.8.2&nbsp;&nbsp;</span>Transition plan</a></span></li><li><span><a href="#Version-control" data-toc-modified-id="Version-control-2.8.3"><span class="toc-item-num">2.8.3&nbsp;&nbsp;</span>Version control</a></span></li><li><span><a href="#Testing" data-toc-modified-id="Testing-2.8.4"><span class="toc-item-num">2.8.4&nbsp;&nbsp;</span>Testing</a></span></li><li><span><a href="#Repository" data-toc-modified-id="Repository-2.8.5"><span class="toc-item-num">2.8.5&nbsp;&nbsp;</span>Repository</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Introduction

# %% [markdown]
# This section comprises sections that focus on the technical and development aspects of the RSEs' work. They aim to understand good practices in developing software.
#
# We chose two broad measures to provide an insight into sustainability: the **bus factor** and **technical hand over planning**.
# * The bus factor is a measure of the number of developers who understand a specific software project and could, with only a cursory review of the project, maintain or extend the code. A project with a bus factor of 1 is completely reliant on only one developer. If this developer finds new employment, becomes ill or is hit by the titular bus, then the project will fail. A high bus factor provides some confidence that the project can be sustained even if a developer leaves.
#
# * A technical hand over plan is used to introduce a new developer to a software project. These plans cover basic information, such as the license and location of the software, a repository, a description of the software architecture, a summary of development plans and any other information that a new developer would need to understand the software. A project that has written (and maintained) a technical hand over plan can withstand the departure of a developer, even a key developer, significantly better than one without such a plan.
#
# Developing software requires a set of good practices to ensure the quality of the subsequent analysis as well as the robustness of the developed software, to name a few of important aspects. We wanted to see if the implementation of some simple but essential good practices were a reality beside the bus factor and technical hand over planning.
#
# When developing software, **version control** and **testing** can be seen as tool to enhance the quality of the developed software, especially considering the importance of code review and sharing in public funded places such as academia.
#
# For testing, we asked the participants to choose any of the following testing methods:
# * Test engineers conduct testing
# * Developers conduct testing
# * Users conduct testing
# * No formal testing
#
# Obviously, the *test engineers conduct testing* is the most robust testing method but may not be possible in smaller projects while no formal testing should not occur in any ideal scenario, regardless of the size of the project.
#
# We also asked the participants if they use any version control tools through a list of choice. And finaly we asked them which repository they are currently using for their most important project.

# %% [markdown]
# ## Setting up

# %%
# %%capture  
# Import notebook containing the imports the functions and the dataset
# %run "./0. Imports and functions.ipynb"

# Import notebook containing sampled dataset
# %run "./1. Overview and sampling.ipynb"

# %% [markdown]
# # Good practices

# %%
# Good practices
bus_factor = ['stability1. What is the bus factor of your most important software project? (The bus factor designates the minimal number of developers that have to be hit by a bus (or quit) before a project is incapacitated)']

transition_plan = ['stability2. Do the projects you work on typically have a plan to cope with developers leaving the group?']

version_control = [x for x in df.columns if x[:8] == 'proj5zaf']

testing = [x for x in df.columns if x[:8] == 'proj4can']

order_testing = ['No formal testing', 'No formal testing but users provide feedback', 'The developers do their own testing', 'Test engineers conduct testing']

repo_tool = ['proj6zaf. Which online collaboration tools and open repositories do you use for software development?']

# %%
df[testing]
# Out:
#      proj4can. How are your projects typically tested? Please check all that apply. [No formal testing]  \
# 0                                                    No
# 1                                                    No
# 2                                                    No
# 3                                                    No
# 4                                                    No
# 5                                                    No
# 6                                                    No
# 7                                                    No
# 8                                                    No
# 9                                                   NaN
# 10                                                   No
# 11                                                   No
# 12                                                   No
# 13                                                  Yes
# 14                                                   No
# 15                                                   No
# 16                                                   No
# 17                                                   No
# 18                                                   No
# 19                                                  NaN
# 20                                                  Yes
# 21                                                   No
# 22                                                   No
# 23                                                   No
# 24                                                   No
# 25                                                   No
# 26                                                   No
# 27                                                   No
# 28                                                  Yes
# 29                                                   No
# 30                                                   No
# 31                                                  NaN
# 32                                                   No
# 33                                                   No
# 34                                                   No
# 35                                                   No
# 36                                                   No
# 37                                                   No
# 38                                                   No
# 39                                                   No
# 40                                                  Yes
# 41                                                   No
# 42                                                  Yes
# 43                                                   No
# 44                                                  NaN
# 45                                                   No
# 46                                                   No
# 47                                                   No
# 48                                                   No
# 49                                                   No
# 50                                                   No
# 51                                                  Yes
# 52                                                   No
# 53                                                   No
# 54                                                  Yes
# 55                                                  Yes
# 56                                                  NaN
# 57                                                   No
# 58                                                   No
# 59                                                   No
# 60                                                   No
# 61                                                   No
# 62                                                   No
# 63                                                   No
# 64                                                  Yes
# 65                                                  NaN
# 66                                                   No
# 67                                                  Yes
# 68                                                  Yes
# 69                                                   No
# 70                                                   No
# 71                                                   No
# 72                                                   No
# 73                                                   No
# 74                                                   No
# 75                                                  Yes
# 76                                                   No
# 77                                                   No
# 78                                                   No
# 79                                                   No
# 80                                                   No
# 81                                                   No
# 82                                                   No
# 83                                                   No
# 85                                                   No
# 86                                                   No
# 87                                                   No
# 88                                                   No
# 89                                                   No
# 90                                                   No
# 91                                                  NaN
# 92                                                   No
# 93                                                  Yes
# 94                                                  Yes
# 95                                                   No
# 96                                                   No
# 97                                                   No
# 98                                                   No
# 99                                                   No
# 100                                                  No
# 101                                                  No
# 102                                                  No
# 103                                                  No
# 104                                                  No
# 105                                                  No
# 106                                                 Yes
# 107                                                  No
# 108                                                 Yes
# 109                                                  No
# 110                                                  No
# 111                                                 Yes
# 112                                                  No
# 113                                                 NaN
# 114                                                  No
# 115                                                  No
# 116                                                  No
# 117                                                  No
# 118                                                 NaN
# 119                                                  No
# 120                                                  No
# 121                                                  No
# 122                                                  No
# 123                                                  No
# 124                                                  No
# 125                                                  No
# 126                                                  No
# 127                                                 Yes
# 128                                                  No
# 129                                                 Yes
# 130                                                  No
# 131                                                  No
# 132                                                 Yes
# 133                                                  No
# 134                                                 Yes
# 135                                                  No
# 136                                                  No
# 137                                                  No
# 138                                                  No
# 139                                                  No
# 140                                                  No
# 141                                                 NaN
# 142                                                  No
# 143                                                  No
# 144                                                  No
# 145                                                  No
# 146                                                  No
# 147                                                  No
# 148                                                  No
# 149                                                  No
# 150                                                  No
# 151                                                  No
# 152                                                  No
# 153                                                  No
# 154                                                  No
# 155                                                  No
# 156                                                  No
# 157                                                 NaN
# 158                                                  No
# 159                                                 Yes
# 160                                                  No
# 161                                                  No
# 162                                                  No
# 163                                                  No
# 164                                                  No
# 165                                                  No
# 166                                                  No
# 167                                                  No
# 168                                                  No
# 169                                                  No
# 170                                                  No
# 171                                                  No
# 172                                                  No
# 173                                                  No
# 174                                                  No
# 175                                                  No
# 176                                                  No
# 177                                                  No
# 178                                                  No
# 179                                                  No
# 180                                                  No
# 181                                                  No
# 182                                                  No
# 183                                                  No
# 184                                                  No
# 185                                                  No
# 186                                                  No
# 187                                                  No
# 188                                                  No
# 189                                                  No
# 190                                                 NaN
# 191                                                 NaN
# 192                                                  No
# 193                                                 NaN
# 194                                                  No
# 195                                                  No
# 196                                                  No
# 197                                                 NaN
# 198                                                  No
# 199                                                  No
# 200                                                  No
# 201                                                  No
# 202                                                  No
# 203                                                 Yes
# 204                                                  No
# 205                                                 Yes
# 206                                                  No
# 207                                                  No
# 208                                                  No
# 209                                                  No
# 210                                                  No
# 211                                                  No
# 212                                                  No
# 213                                                  No
# 214                                                  No
# 215                                                  No
# 216                                                  No
# 217                                                  No
# 218                                                  No
# 219                                                  No
# 220                                                 NaN
# 221                                                 NaN
# 222                                                  No
# 223                                                  No
# 224                                                  No
# 225                                                 Yes
# 226                                                 Yes
# 227                                                  No
# 228                                                  No
# 229                                                 Yes
# 230                                                  No
# 232                                                  No
# 233                                                 Yes
# 234                                                  No
# 235                                                  No
# 236                                                  No
# 237                                                 NaN
# 238                                                  No
# 239                                                 Yes
# 240                                                  No
# 241                                                  No
# 242                                                  No
# 243                                                  No
# 244                                                  No
# 245                                                  No
# 246                                                  No
# 247                                                  No
# 248                                                  No
# 249                                                  No
# 250                                                  No
# 251                                                  No
# 252                                                  No
# 253                                                  No
# 254                                                  No
# 255                                                  No
# 256                                                 Yes
# 257                                                  No
# 258                                                  No
# 259                                                  No
# 260                                                  No
# 261                                                  No
# 262                                                 NaN
# 263                                                 NaN
# 264                                                  No
# 265                                                  No
# 266                                                  No
# 267                                                  No
# 268                                                  No
# 269                                                  No
# 270                                                  No
# 271                                                  No
# 272                                                  No
# 273                                                 Yes
# 274                                                  No
# 275                                                  No
# 276                                                  No
# 277                                                 NaN
# 278                                                 NaN
# 279                                                  No
# 280                                                  No
# 281                                                  No
# 282                                                  No
# 283                                                  No
# 284                                                 NaN
# 285                                                  No
# 286                                                  No
# 287                                                  No
# 288                                                  No
# 289                                                  No
# 290                                                  No
# 291                                                  No
# 292                                                  No
# 293                                                  No
# 294                                                  No
# 295                                                  No
# 296                                                  No
# 297                                                  No
# 298                                                  No
# 299                                                  No
# 300                                                  No
# 301                                                  No
# 302                                                  No
# 303                                                  No
# 304                                                 Yes
# 305                                                  No
# 306                                                  No
# 307                                                  No
# 308                                                  No
# 309                                                  No
# 310                                                  No
# 311                                                 Yes
# 312                                                  No
# 313                                                 NaN
# 314                                                  No
# 315                                                 NaN
# 316                                                  No
# 317                                                  No
# 318                                                  No
# 319                                                  No
# 320                                                  No
# 321                                                  No
# 322                                                 Yes
# 323                                                  No
# 324                                                  No
# 325                                                  No
# 326                                                  No
# 327                                                  No
# 328                                                  No
# 329                                                  No
# 330                                                  No
# 331                                                  No
# 332                                                  No
# 333                                                  No
# 334                                                 Yes
# 335                                                  No
# 336                                                  No
# 337                                                 NaN
# 338                                                  No
# 339                                                  No
# 340                                                  No
# 341                                                  No
# 342                                                  No
# 343                                                  No
# 344                                                  No
# 345                                                  No
# 346                                                 NaN
# 347                                                  No
# 349                                                  No
# 350                                                 NaN
# 351                                                  No
# 352                                                  No
# 353                                                  No
# 354                                                  No
# 355                                                 NaN
# 356                                                  No
# 357                                                  No
# 358                                                 NaN
# 359                                                 Yes
# 360                                                 Yes
# 361                                                  No
# 362                                                  No
# 363                                                 NaN
# 364                                                 Yes
# 365                                                  No
# 366                                                  No
# 367                                                  No
# 368                                                  No
# 369                                                 Yes
# 370                                                 Yes
# 371                                                  No
# 372                                                  No
# 373                                                 NaN
# 374                                                  No
# 375                                                  No
# 376                                                  No
# 377                                                  No
# 378                                                  No
# 379                                                  No
# 380                                                  No
# 381                                                  No
# 382                                                  No
# 383                                                  No
# 384                                                  No
# 385                                                  No
# 386                                                 Yes
# 387                                                  No
# 388                                                  No
# 389                                                 Yes
# 390                                                  No
# 391                                                 Yes
# 392                                                  No
# 393                                                  No
# 394                                                  No
# 395                                                 NaN
# 396                                                  No
# 397                                                  No
# 398                                                  No
# 399                                                 Yes
# 400                                                  No
# 401                                                  No
# 402                                                 Yes
# 403                                                  No
# 404                                                  No
# 405                                                  No
# 406                                                  No
# 407                                                  No
# 408                                                  No
# 409                                                  No
# 410                                                 Yes
# 411                                                 Yes
# 412                                                  No
# 413                                                  No
# 414                                                  No
# 415                                                  No
# 417                                                  No
# 418                                                 NaN
# 419                                                  No
# 420                                                  No
# 421                                                  No
# 422                                                  No
# 423                                                 Yes
# 424                                                  No
# 425                                                 Yes
# 426                                                  No
# 427                                                  No
# 428                                                  No
# 429                                                 NaN
# 430                                                  No
# 431                                                  No
# 432                                                  No
# 433                                                  No
# 434                                                  No
# 435                                                  No
# 436                                                  No
# 437                                                  No
# 438                                                  No
# 439                                                  No
# 440                                                 Yes
# 441                                                  No
# 442                                                  No
# 443                                                  No
# 444                                                  No
# 445                                                 Yes
# 446                                                 NaN
# 447                                                 Yes
# 448                                                 NaN
# 449                                                  No
# 450                                                 NaN
# ...
# 1701                                                 No
# 1702                                                 No
# 1703                                                 No
# 1704                                                 No
# 1705                                                 No
# 1706                                                 No
# 1707                                                 No
# 1708                                                 No
# 1709                                                 No
# 1710                                                 No
# 1711                                                 No
# 1712                                                 No
# 1713                                                 No
# 1714                                                 No
# 1715                                                 No
# 1716                                                Yes
# 1717                                                 No
# 1718                                                 No
# 1719                                                 No
# 1720                                                 No
# 1721                                                 No
# 1722                                                 No
# 1723                                                 No
# 1724                                                 No
# 1725                                                 No
# 1726                                                 No
# 1727                                                 No
# 1728                                                 No
# 1729                                                 No
# 1730                                                 No
# 1731                                                 No
# 1732                                                 No
# 1733                                                Yes
# 1734                                                 No
# 1735                                                 No
# 1736                                                 No
# 1737                                                 No
# 1738                                                 No
# 1739                                                 No
# 1740                                                 No
# 1741                                                Yes
# 1742                                                 No
# 1743                                                 No
# 1745                                                 No
# 1746                                                NaN
# 1747                                                 No
# 1748                                                 No
# 1749                                                 No
# 1750                                                 No
# 1751                                                 No
# 1752                                                 No
# 1753                                                 No
# 1754                                                 No
# 1755                                                 No
# 1756                                                 No
# 1757                                                 No
# 1758                                                 No
# 1759                                                 No
# 1760                                                 No
# 1761                                                 No
# 1762                                                 No
# 1763                                                 No
# 1764                                                 No
# 1765                                                 No
# 1766                                                 No
# 1767                                                NaN
# 1768                                                NaN
# 1769                                                NaN
# 1770                                                 No
# 1771                                                 No
# 1772                                                Yes
# 1773                                                 No
# 1774                                                 No
# 1775                                                 No
# 1776                                                 No
# 1777                                                 No
# 1778                                                 No
# 1779                                                 No
# 1780                                                 No
# 1781                                                NaN
# 1782                                                 No
# 1783                                                 No
# 1784                                                 No
# 1785                                                 No
# 1786                                                 No
# 1787                                                 No
# 1789                                                 No
# 1790                                                 No
# 1791                                                 No
# 1792                                                 No
# 1793                                                 No
# 1794                                                 No
# 1795                                                Yes
# 1796                                                 No
# 1797                                                 No
# 1798                                                 No
# 1799                                                 No
# 1800                                                Yes
# 1801                                                 No
# 1802                                                 No
# 1803                                                 No
# 1804                                                NaN
# 1805                                                 No
# 1806                                                 No
# 1807                                                 No
# 1809                                                 No
# 1810                                                 No
# 1811                                                Yes
# 1812                                                Yes
# 1813                                                 No
# 1814                                                 No
# 1815                                                 No
# 1816                                                 No
# 1817                                                 No
# 1818                                                NaN
# 1819                                                 No
# 1820                                                 No
# 1821                                                 No
# 1822                                                 No
# 1823                                                NaN
# 1824                                                 No
# 1825                                                 No
# 1826                                                NaN
# 1827                                                 No
# 1828                                                 No
# 1829                                                Yes
# 1830                                                 No
# 1831                                                 No
# 1832                                                 No
# 1833                                                Yes
# 1834                                                 No
# 1835                                                 No
# 1836                                                 No
# 1837                                                 No
#
# [1812 rows x 4 columns]

# %% [markdown]
# ## Australia

# %%
country = 'Australia'

# %% [markdown]
# ### Bus Factor

# %%
category = 'Bus Factor'
results = count_diff(df, bus_factor, country, category, order_index=True)
results
# Out:
#                           Count  Percentage
# Bus Factor for Australia
# 0.0                           2    2.272727
# 1.0                          60   68.181818
# 2.0                          16   18.181818
# 3.0                           5    5.681818
# 4.0                           2    2.272727
# 5.0                           3    3.409091

# %%
plot_cat_comparison(results, country=country, category=category, order_index=True)

# %% [markdown]
# ### Transition plan

# %%
category = 'Presence of a transition plan'
results = count_diff(df, transition_plan, country, category, y_n=True)
results
# Out:
#                                              Count  Percentage
# Presence of a transition plan for Australia
# Yes                                              9   10.227273
# No                                              79   89.772727

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Version control

# %%
category = 'Use of version control'
results = count_diff(df, version_control, country, category, multi_choice=True)
results
# Out:
#                                       Count  Percentage
# Use of version control for Australia
# Git                                      81   81.818182
# SVN                                      20   20.202020
# CVS                                       7    7.070707
# Mercurial                                 4    4.040404
# None                                      2    2.020202

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Testing

# %%
category = 'Testing strategies'
results = count_diff(df, testing, country, category, multi_choice=True, order_index=order_testing)
results
# Out:
#                                               Count  Percentage
# Testing strategies for Australia
# No formal testing                                12   12.121212
# No formal testing but users provide feedback     33   33.333333
# The developers do their own testing              73   73.737374
# Test engineers conduct testing                    4    4.040404

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_testing)

# %% [markdown]
# ### Repository

# %%
category = 'Repository'
plot_wordcloud(df, repo_tool, country, category)

# %% [markdown]
# ## Germany

# %%
country = 'Germany'

# %% [markdown]
# ### Bus Factor

# %%
category = 'Bus Factor'
results = count_diff(df, bus_factor, country, category, order_index=True)
results
# Out:
#                         Count  Percentage
# Bus Factor for Germany
# 0.0                        17    5.762712
# 0.5                         1    0.338983
# 1.0                       169   57.288136
# 1.2                         1    0.338983
# 1.5                         2    0.677966
# 2.0                        78   26.440678
# 3.0                        17    5.762712
# 4.0                         3    1.016949
# 5.0                         3    1.016949
# 6.0                         2    0.677966
# 50.0                        1    0.338983
# 200.0                       1    0.338983

# %%
plot_cat_comparison(results, country=country, category=category, order_index=True)

# %% [markdown]
# ### Transition plan

# %%
category = 'Presence of a transition plan'
results = count_diff(df, transition_plan, country, category, y_n=True)
results
# Out:
#                                            Count  Percentage  \
# Presence of a transition plan for Germany
# Yes                                           48   16.216216
# No                                           248   83.783784
#
#                                            Percentage in 2017  \
# Presence of a transition plan for Germany
# Yes                                                 18.666667
# No                                                  81.333333
#
#                                            Difference with previous year
# Presence of a transition plan for Germany
# Yes                                                             -2.45045
# No                                                               2.45045

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Version control

# %%
category = 'Use of version control'
results = count_diff(df, version_control, country, category, multi_choice=True)
results
# Out:
#                                     Count  Percentage
# Use of version control for Germany
# Git                                   263   78.978979
# SVN                                    94   28.228228
# None                                   22    6.606607
# Mercurial                              15    4.504505
# CVS                                    13    3.903904

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Testing

# %%
category = 'Testing strategies'
results = count_diff(df, testing, country, category, multi_choice=True, order_index=order_testing)
results
# Out:
#                                               Count  Percentage  \
# Testing strategies for Germany
# No formal testing                                47   14.114114
# No formal testing but users provide feedback    116   34.834835
# The developers do their own testing             257   77.177177
# Test engineers conduct testing                   14    4.204204
#
#                                               Percentage in 2017  \
# Testing strategies for Germany
# No formal testing                                      25.230769
# No formal testing but users provide feedback           56.000000
# The developers do their own testing                    80.923077
# Test engineers conduct testing                          6.153846
#
#                                               Difference with previous year
# Testing strategies for Germany
# No formal testing                                                -11.116655
# No formal testing but users provide feedback                     -21.165165
# The developers do their own testing                               -3.745900
# Test engineers conduct testing                                    -1.949642

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_testing)

# %% [markdown]
# ### Repository

# %%
category = 'Repository'
plot_wordcloud(df, repo_tool, country, category)

# %% [markdown]
# ## Netherlands

# %%
country = 'Netherlands'

# %% [markdown]
# ### Bus Factor

# %%
category = 'Bus Factor'
results = count_diff(df, bus_factor, country, category, order_index=True)
results
# Out:
#                             Count  Percentage
# Bus Factor for Netherlands
# 1.0                            27   52.941176
# 2.0                            17   33.333333
# 3.0                             4    7.843137
# 4.0                             1    1.960784
# 10.0                            2    3.921569

# %%
plot_cat_comparison(results, country=country, category=category, order_index=True)

# %% [markdown]
# ### Transition plan

# %%
category = 'Presence of a transition plan'
results = count_diff(df, transition_plan, country, category, y_n=True)
results
# Out:
#                                                Count  Percentage  \
# Presence of a transition plan for Netherlands
# Yes                                               10   19.607843
# No                                                41   80.392157
#
#                                                Percentage in 2017  \
# Presence of a transition plan for Netherlands
# Yes                                                     20.547945
# No                                                      79.452055
#
#                                                Difference with previous year
# Presence of a transition plan for Netherlands
# Yes                                                                -0.940102
# No                                                                  0.940102

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Version control

# %%
category = 'Use of version control'
results = count_diff(df, version_control, country, category, multi_choice=True)
results
# Out:
#                                         Count  Percentage
# Use of version control for Netherlands
# Git                                      49.0   90.740741
# SVN                                      13.0   24.074074
# Mercurial                                 3.0    5.555556
# CVS                                       1.0    1.851852
# None                                      0.0    0.000000

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Testing

# %%
category = 'Testing strategies'
results = count_diff(df, testing, country, category, multi_choice=True, order_index=order_testing)
results
# Out:
#                                               Count  Percentage  \
# Testing strategies for Netherlands
# No formal testing                                 6   11.111111
# No formal testing but users provide feedback     23   42.592593
# The developers do their own testing              42   77.777778
# Test engineers conduct testing                    1    1.851852
#
#                                               Percentage in 2017  \
# Testing strategies for Netherlands
# No formal testing                                      22.666667
# No formal testing but users provide feedback           56.000000
# The developers do their own testing                    84.000000
# Test engineers conduct testing                          9.333333
#
#                                               Difference with previous year
# Testing strategies for Netherlands
# No formal testing                                                -11.555556
# No formal testing but users provide feedback                     -13.407407
# The developers do their own testing                               -6.222222
# Test engineers conduct testing                                    -7.481481

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_testing)

# %% [markdown]
# ### Repository

# %%
category = 'Repository'
plot_wordcloud(df, repo_tool, country, category)

# %% [markdown]
# ## New Zealand

# %%
country = 'New Zealand'

# %% [markdown]
# ### Bus Factor

# %%
category = 'Bus Factor'
results = count_diff(df, bus_factor, country, category, order_index=True)
results
# Out:
#                             Count  Percentage
# Bus Factor for New Zealand
# 1.0                            23   67.647059
# 2.0                             6   17.647059
# 3.0                             3    8.823529
# 4.0                             1    2.941176
# 5.0                             1    2.941176

# %%
plot_cat_comparison(results, country=country, category=category, order_index=True)

# %% [markdown]
# ### Transition plan

# %%
category = 'Presence of a transition plan'
results = count_diff(df, transition_plan, country, category, y_n=True)
results
# Out:
#                                                Count  Percentage
# Presence of a transition plan for New Zealand
# Yes                                                3    8.823529
# No                                                31   91.176471

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Version control

# %%
category = 'Use of version control'
results = count_diff(df, version_control, country, category, multi_choice=True)
results
# Out:
#                                         Count  Percentage
# Use of version control for New Zealand
# Git                                      33.0   89.189189
# SVN                                       9.0   24.324324
# Mercurial                                 1.0    2.702703
# CVS                                       0.0    0.000000
# None                                      0.0    0.000000

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Testing

# %%
category = 'Testing strategies'
results = count_diff(df, testing, country, category, multi_choice=True, order_index=order_testing)
results
# Out:
#                                               Count  Percentage
# Testing strategies for New Zealand
# No formal testing                               6.0   16.216216
# No formal testing but users provide feedback   15.0   40.540541
# The developers do their own testing            29.0   78.378378
# Test engineers conduct testing                  0.0    0.000000

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_testing)

# %% [markdown]
# ### Repository

# %%
category = 'Repository'
plot_wordcloud(df, repo_tool, country, category)

# %% [markdown]
# ## South Africa

# %%
country = 'South Africa'

# %% [markdown]
# ### Bus Factor

# %%
category = 'Bus Factor'
results = count_diff(df, bus_factor, country, category, order_index=True)
results
# Out:
#                              Count  Percentage
# Bus Factor for South Africa
# 0.0                              2    9.523810
# 1.0                             14   66.666667
# 2.0                              3   14.285714
# 3.0                              2    9.523810

# %%
plot_cat_comparison(results, country=country, category=category, order_index=True)

# %% [markdown]
# ### Transition plan

# %%
category = 'Presence of a transition plan'
results = count_diff(df, transition_plan, country, category, y_n=True)
results
# Out:
#                                                 Count  Percentage  \
# Presence of a transition plan for South Africa
# Yes                                                 5   23.809524
# No                                                 16   76.190476
#
#                                                 Percentage in 2017  \
# Presence of a transition plan for South Africa
# Yes                                                      13.333333
# No                                                       86.666667
#
#                                                 Difference with previous year
# Presence of a transition plan for South Africa
# Yes                                                                  10.47619
# No                                                                  -10.47619

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Version control

# %%
category = 'Use of version control'
results = count_diff(df, version_control, country, category, multi_choice=True)
results
# Out:
#                                          Count  Percentage  \
# Use of version control for South Africa
# Git                                       17.0   73.913043
# SVN                                        3.0   13.043478
# None                                       3.0   13.043478
# CVS                                        0.0    0.000000
# Mercurial                                  0.0    0.000000
#
#                                          Percentage in 2017  \
# Use of version control for South Africa
# Git                                                     NaN
# SVN                                               10.526316
# None                                              15.789474
# CVS                                                5.263158
# Mercurial                                          0.000000
#
#                                          Difference with previous year
# Use of version control for South Africa
# Git                                                                NaN
# SVN                                                           2.517162
# None                                                         -2.745995
# CVS                                                          -5.263158
# Mercurial                                                     0.000000

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Testing

# %%
category = 'Testing strategies'
results = count_diff(df, testing, country, category, multi_choice=True, order_index=order_testing)
results
# Out:
#                                               Count  Percentage  \
# Testing strategies for South Africa
# No formal testing                                 3   13.043478
# No formal testing but users provide feedback     11   47.826087
# The developers do their own testing              14   60.869565
# Test engineers conduct testing                    1    4.347826
#
#                                               Percentage in 2017  \
# Testing strategies for South Africa
# No formal testing                                      26.315789
# No formal testing but users provide feedback           42.105263
# The developers do their own testing                    57.894737
# Test engineers conduct testing                         10.526316
#
#                                               Difference with previous year
# Testing strategies for South Africa
# No formal testing                                                -13.272311
# No formal testing but users provide feedback                       5.720824
# The developers do their own testing                                2.974828
# Test engineers conduct testing                                    -6.178490

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_testing)

# %% [markdown]
# ### Repository

# %%
category = 'Repository'
plot_wordcloud(df, repo_tool, country, category)

# %% [markdown]
# ## United Kingdom

# %% [markdown]
# Almost the half of the RSEs' projects have a bus factor of 1 (38%), followed by a bus factor of 2 (35%). Higher bus factor is only marginal with only 9% of the projects having a bus factor of 3 and 6% a bus factor of 4. Higher number are anecdotal. However, it has to be said that, the majority of project are conducted by only one developer, as seen in  Collaboration and training.
#
# Big or small projects, the presence of a transition plan can mitigate the low bus factor and the risk of project failures. However, only 24% of them are doing so.
#
# On a better news, 98% of the participants are using version control, with a massive preference for Git (84%). Keep in mind it is a multichoice question. The percentage represents the percentage of participants that have selected that option and it could be alonside other choices.
#
# For testing, 7% of the participants confessed they were not implementing any testing at all. It may seems a low number but we think it is still a high percentage considering the specific work of this population. However, it is a big decrease compared to last year (-7%).
# When they are conducting testing, the RSEs seems to prefer (or only able to implement) *Developer testing* (80% of them) or letting the users conduct the testing (22%), while the use of test engineers is marginal (7%).

# %%
country = 'United Kingdom'

# %% [markdown]
# ### Bus Factor

# %%
category = 'Bus Factor'
results = count_diff(df, bus_factor, country, category, order_index=True)
results
# Out:
#                                Count  Percentage
# Bus Factor for United Kingdom
# 0.0                                5    2.336449
# 1.0                               82   38.317757
# 2.0                               77   35.981308
# 3.0                               21    9.813084
# 4.0                               14    6.542056
# 5.0                                4    1.869159
# 6.0                                3    1.401869
# 7.0                                3    1.401869
# 8.0                                1    0.467290
# 9.0                                1    0.467290
# 10.0                               1    0.467290
# 11.0                               1    0.467290
# 700.0                              1    0.467290

# %%
plot_cat_comparison(results, country=country, category=category, order_index=True)

# %% [markdown]
# ### Transition plan

# %%
category = 'Presence of a transition plan'
results = count_diff(df, transition_plan, country, category, y_n=True)
results
# Out:
#                                                   Count  Percentage  \
# Presence of a transition plan for United Kingdom
# Yes                                                  52   24.299065
# No                                                  162   75.700935
#
#                                                   Percentage in 2017  \
# Presence of a transition plan for United Kingdom
# Yes                                                        25.327511
# No                                                         74.672489
#
#                                                   Difference with previous year
# Presence of a transition plan for United Kingdom
# Yes                                                                   -1.028445
# No                                                                     1.028445

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Version control

# %%
category = 'Use of version control'
results = count_diff(df, version_control, country, category, multi_choice=True)
results
# Out:
#                                            Count  Percentage
# Use of version control for United Kingdom
# Git                                          199   84.322034
# SVN                                           53   22.457627
# Mercurial                                     23    9.745763
# CVS                                           11    4.661017
# None                                           4    1.694915

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Testing

# %%
category = 'Testing strategies'
results = count_diff(df, testing, country, category, multi_choice=True, order_index=order_testing)
results
# Out:
#                                               Count  Percentage  \
# Testing strategies for United Kingdom
# No formal testing                                18    7.627119
# No formal testing but users provide feedback     53   22.457627
# The developers do their own testing             192   81.355932
# Test engineers conduct testing                    7    2.966102
#
#                                               Percentage in 2017  \
# Testing strategies for United Kingdom
# No formal testing                                      15.040650
# No formal testing but users provide feedback           38.211382
# The developers do their own testing                    80.487805
# Test engineers conduct testing                          7.317073
#
#                                               Difference with previous year
# Testing strategies for United Kingdom
# No formal testing                                                 -7.413532
# No formal testing but users provide feedback                     -15.753755
# The developers do their own testing                                0.868127
# Test engineers conduct testing                                    -4.350971

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_testing)

# %% [markdown]
# ### Repository

# %%
category = 'Repository'
plot_wordcloud(df, repo_tool, country, category)

# %% [markdown]
# ## United States

# %%
country = 'United States'

# %% [markdown]
# ### Bus Factor

# %%
category = 'Bus Factor'
results = count_diff(df, bus_factor, country, category, order_index=True)
results
# Out:
#                               Count  Percentage
# Bus Factor for United States
# 0.0                               2    1.449275
# 1.0                              73   52.898551
# 2.0                              39   28.260870
# 3.0                              13    9.420290
# 4.0                               8    5.797101
# 5.0                               1    0.724638
# 7.0                               1    0.724638
# 20.0                              1    0.724638

# %%
plot_cat_comparison(results, country=country, category=category, order_index=True)

# %% [markdown]
# ### Transition plan

# %%
category = 'Presence of a transition plan'
results = count_diff(df, transition_plan, country, category, y_n=True)
results
# Out:
#                                                  Count  Percentage  \
# Presence of a transition plan for United States
# Yes                                                 28   20.289855
# No                                                 110   79.710145
#
#                                                  Percentage in 2017  \
# Presence of a transition plan for United States
# Yes                                                       18.248175
# No                                                        81.751825
#
#                                                  Difference with previous year
# Presence of a transition plan for United States
# Yes                                                                    2.04168
# No                                                                    -2.04168

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Version control

# %%
category = 'Use of version control'
results = count_diff(df, version_control, country, category, multi_choice=True)
results
# Out:
#                                           Count  Percentage
# Use of version control for United States
# Git                                         134   91.156463
# SVN                                          22   14.965986
# CVS                                           9    6.122449
# Mercurial                                     6    4.081633
# None                                          5    3.401361

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Testing

# %%
category = 'Testing strategies'
results = count_diff(df, testing, country, category, multi_choice=True, order_index=order_testing)
results
# Out:
#                                               Count  Percentage  \
# Testing strategies for United States
# No formal testing                                10    6.802721
# No formal testing but users provide feedback     43   29.251701
# The developers do their own testing             125   85.034014
# Test engineers conduct testing                   16   10.884354
#
#                                               Percentage in 2017  \
# Testing strategies for United States
# No formal testing                                      11.042945
# No formal testing but users provide feedback           55.828221
# The developers do their own testing                    83.435583
# Test engineers conduct testing                          9.202454
#
#                                               Difference with previous year
# Testing strategies for United States
# No formal testing                                                 -4.240224
# No formal testing but users provide feedback                     -26.576520
# The developers do their own testing                                1.598431
# Test engineers conduct testing                                     1.681900

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_testing)

# %% [markdown]
# ### Repository

# %%
category = 'Repository'
plot_wordcloud(df, repo_tool, country, category)

# %% [markdown]
# ## Rest of the world

# %%
country = 'World'

# %% [markdown]
# ### Bus Factor

# %%
category = 'Bus Factor'
results = count_diff(df, bus_factor, country, category, order_index=True)
results
# Out:
#                       Count  Percentage
# Bus Factor for World
# 0.0                       3    7.317073
# 1.0                      18   43.902439
# 2.0                      12   29.268293
# 3.0                       6   14.634146
# 5.0                       1    2.439024
# 6.0                       1    2.439024

# %%
plot_cat_comparison(results, country=country, category=category, order_index=True)

# %% [markdown]
# ### Transition plan

# %%
category = 'Presence of a transition plan'
results = count_diff(df, transition_plan, country, category, y_n=True)
results
# Out:
#                                          Count  Percentage
# Presence of a transition plan for World
# Yes                                          6   14.634146
# No                                          35   85.365854

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Version control

# %%
category = 'Use of version control'
results = count_diff(df, version_control, country, category, multi_choice=True)
results
# Out:
#                                   Count  Percentage
# Use of version control for World
# Git                                38.0   69.090909
# SVN                                 7.0   12.727273
# Mercurial                           3.0    5.454545
# None                                2.0    3.636364
# CVS                                 0.0    0.000000

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Testing

# %%
category = 'Testing strategies'
results = count_diff(df, testing, country, category, multi_choice=True, order_index=order_testing)
results
# Out:
#                                               Count  Percentage
# Testing strategies for World
# No formal testing                                 6   10.909091
# No formal testing but users provide feedback     14   25.454545
# The developers do their own testing              35   63.636364
# Test engineers conduct testing                    4    7.272727

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_testing)

# %% [markdown]
# ### Repository

# %%
category = 'Repository'
plot_wordcloud(df, repo_tool, country, category)
