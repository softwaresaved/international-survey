# %% [markdown]
# # Introduction

# %% [markdown]
# ## Setting up

# %%
# %%capture  
# Import notebook containing the imports the functions and the dataset
# %run "./0. Imports and functions.ipynb"

# Import notebook containing sampled dataset
# %run "./1. Overview and sampling.ipynb"

# %% [markdown]
# # Publications and citations

# %%
paper = ['paper2mod. In general, when your software contributes to a paper, are you acknowledged in that paper?']
order_paper = ['Not mentioned at all', 'Acknowledged in the main text', 'Acknowledged in acknowledgements section', 'Named as co-author', 'Named as main author']

conf1 = ['conf1can. Have you presented your software work at a conference or workshop?']

conf2 = ['conf2can. At which conference(s)/workshop(s) have you presented your software work?']

# %% [markdown]
# ## Australia

# %%
country = 'Australia'

# %% [markdown]
# ### Acknowledgment in paper

# %%
category = 'Acknowledgment in paper'
results = count_diff(df, paper, country, category, order_index=order_paper)
results
# Out:
#                                           Count  Percentage
# Acknowledgment in paper for Australia
# Not mentioned at all                         15   20.000000
# Acknowledged in the main text                 3    4.000000
# Acknowledged in acknowledgements section     17   22.666667
# Named as co-author                           36   48.000000
# Named as main author                          4    5.333333

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_paper)

# %% [markdown]
# ### Participation to conferences

# %%
category = 'Did you participate to conference'
results = count_diff(df, conf1, country, category, y_n=True)
results
# Out:
#                                                  Count  Percentage
# Did you participate to conference for Australia
# Yes                                                 38   54.285714
# No                                                  32   45.714286

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Conference name

# %%
plot_wordcloud(df, conf2, country, category)

# %% [markdown]
# ## Germany

# %%
country = 'Germany'

# %% [markdown]
# ### Acknowledgment in paper

# %%
category = 'Acknowledgment in paper'
results = count_diff(df, paper, country, category, order_index=order_paper)
results
# Out:
#                                           Count  Percentage
# Acknowledgment in paper for Germany
# Not mentioned at all                         62   21.453287
# Acknowledged in the main text                28    9.688581
# Acknowledged in acknowledgements section     54   18.685121
# Named as co-author                          121   41.868512
# Named as main author                         24    8.304498

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_paper)

# %% [markdown]
# ### Participation to conferences

# %%
category = 'Did you participate to conference'
results = count_diff(df, conf1, country, category, y_n=True)
results
# Out:
#                                                Count  Percentage  \
# Did you participate to conference for Germany
# Yes                                              147   54.243542
# No                                               124   45.756458
#
#                                                Difference with previous year
# Did you participate to conference for Germany
# Yes                                                                -1.423124
# No                                                                  1.423124

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Conference name

# %%
plot_wordcloud(df, conf2, country, category)

# %% [markdown]
# ## Netherlands

# %%
country = 'Netherlands'

# %% [markdown]
# ### Acknowledgment in paper

# %%
category = 'Acknowledgment in paper'
results = count_diff(df, paper, country, category, order_index=order_paper)
results
# Out:
#                                           Count  Percentage
# Acknowledgment in paper for Netherlands
# Not mentioned at all                         10   21.739130
# Acknowledged in the main text                 6   13.043478
# Acknowledged in acknowledgements section      7   15.217391
# Named as co-author                           22   47.826087
# Named as main author                          1    2.173913

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_paper)

# %% [markdown]
# ### Participation to conferences

# %%
category = 'Did you participate to conference'
results = count_diff(df, conf1, country, category, y_n=True)
results
# Out:
#                                                    Count  Percentage  \
# Did you participate to conference for Netherlands
# Yes                                                   21   46.666667
# No                                                    24   53.333333
#
#                                                    Difference with previous year
# Did you participate to conference for Netherlands
# Yes                                                                   -31.415525
# No                                                                     31.415525

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Conference name

# %%
plot_wordcloud(df, conf2, country, category)

# %% [markdown]
# ## New Zealand

# %%
country = 'New Zealand'

# %% [markdown]
# ### Acknowledgment in paper

# %%
category = 'Acknowledgment in paper'
results = count_diff(df, paper, country, category, order_index=order_paper)
results
# Out:
#                                           Count  Percentage
# Acknowledgment in paper for New Zealand
# Not mentioned at all                          6   18.181818
# Acknowledged in the main text                 3    9.090909
# Acknowledged in acknowledgements section      6   18.181818
# Named as co-author                           15   45.454545
# Named as main author                          3    9.090909

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_paper)

# %% [markdown]
# ### Participation to conferences

# %%
category = 'Did you participate to conference'
results = count_diff(df, conf1, country, category, y_n=True)
results
# Out:
#                                                    Count  Percentage
# Did you participate to conference for New Zealand
# Yes                                                   17    54.83871
# No                                                    14    45.16129

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Conference name

# %%
plot_wordcloud(df, conf2, country, category)

# %% [markdown]
# ## South Africa

# %%
country = 'South Africa'

# %% [markdown]
# ### Acknowledgment in paper

# %%
category = 'Acknowledgment in paper'
results = count_diff(df, paper, country, category, order_index=order_paper)
results
# Out:
#                                           Count  Percentage
# Acknowledgment in paper for South Africa
# Not mentioned at all                          5   23.809524
# Acknowledged in the main text                 1    4.761905
# Acknowledged in acknowledgements section      4   19.047619
# Named as co-author                           10   47.619048
# Named as main author                          1    4.761905

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_paper)

# %% [markdown]
# ### Participation to conferences

# %%
category = 'Did you participate to conference'
results = count_diff(df, conf1, country, category, y_n=True)
results
# Out:
#                                                     Count  Percentage  \
# Did you participate to conference for South Africa
# Yes                                                    12        60.0
# No                                                      8        40.0
#
#                                                     Difference with previous year
# Did you participate to conference for South Africa
# Yes                                                                         28.75
# No                                                                         -28.75

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Conference name

# %%
plot_wordcloud(df, conf2, country, category)

# %% [markdown]
# ## United Kingdom

# %%
country = 'United Kingdom'

# %% [markdown]
# ### Acknowledgment in paper

# %%
category = 'Acknowledgment in paper'
results = count_diff(df, paper, country, category, order_index=order_paper)
results
# Out:
#                                             Count  Percentage
# Acknowledgment in paper for United Kingdom
# Not mentioned at all                           39   18.483412
# Acknowledged in the main text                  10    4.739336
# Acknowledged in acknowledgements section       41   19.431280
# Named as co-author                            110   52.132701
# Named as main author                           11    5.213270

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_paper)

# %% [markdown]
# ### Participation to conferences

# %%
category = 'Did you participate to conference'
results = count_diff(df, conf1, country, category, y_n=True)
results
# Out:
#                                                     Count  Percentage  \
# Did you participate to conference for United Ki...
# Yes                                                   120   58.536585
# No                                                     85   41.463415
#
#                                                     Difference with previous year
# Did you participate to conference for United Ki...
# Yes                                                                      0.710498
# No                                                                      -0.710498

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Conference name

# %%
plot_wordcloud(df, conf2, country, category)

# %% [markdown]
# ## United States

# %%
country = 'United States'

# %% [markdown]
# ### Acknowledgment in paper

# %%
category = 'Acknowledgment in paper'
results = count_diff(df, paper, country, category, order_index=order_paper)
results
# Out:
#                                            Count  Percentage
# Acknowledgment in paper for United States
# Not mentioned at all                          30   21.739130
# Acknowledged in the main text                 17   12.318841
# Acknowledged in acknowledgements section      23   16.666667
# Named as co-author                            65   47.101449
# Named as main author                           3    2.173913

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_paper)

# %% [markdown]
# ### Participation to conferences

# %%
category = 'Did you participate to conference'
results = count_diff(df, conf1, country, category, y_n=True)
results
# Out:
#                                                     Count  Percentage  \
# Did you participate to conference for United St...
# Yes                                                    79   59.848485
# No                                                     53   40.151515
#
#                                                     Difference with previous year
# Did you participate to conference for United St...
# Yes                                                                     -6.108962
# No                                                                       6.108962

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Conference name

# %%
plot_wordcloud(df, conf2, country, category)

# %% [markdown]
# ## Rest of the world

# %%
country = 'World'

# %% [markdown]
# ### Acknowledgment in paper

# %%
category = 'Acknowledgment in paper'
results = count_diff(df, paper, country, category, order_index=order_paper)
results
# Out:
#                                           Count  Percentage
# Acknowledgment in paper for World
# Not mentioned at all                         10   25.641026
# Acknowledged in the main text                 2    5.128205
# Acknowledged in acknowledgements section      5   12.820513
# Named as co-author                           20   51.282051
# Named as main author                          2    5.128205

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_paper)

# %% [markdown]
# ### Participation to conferences

# %%
category = 'Did you participate to conference'
results = count_diff(df, conf1, country, category, y_n=True)
results
# Out:
#                                              Count  Percentage
# Did you participate to conference for World
# Yes                                             20   52.631579
# No                                              18   47.368421

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Conference name

# %%
plot_wordcloud(df, conf2, country, category)
