# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span><ul class="toc-item"><li><span><a href="#Questions-in-the-section" data-toc-modified-id="Questions-in-the-section-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Questions in the section</a></span></li><li><span><a href="#Setting-up" data-toc-modified-id="Setting-up-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Setting up</a></span></li></ul></li><li><span><a href="#Publications-and-citations" data-toc-modified-id="Publications-and-citations-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Publications and citations</a></span><ul class="toc-item"><li><span><a href="#Australia" data-toc-modified-id="Australia-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Australia</a></span><ul class="toc-item"><li><span><a href="#Acknowledgment-in-paper" data-toc-modified-id="Acknowledgment-in-paper-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Acknowledgment in paper</a></span></li><li><span><a href="#Participation-to-conferences" data-toc-modified-id="Participation-to-conferences-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Participation to conferences</a></span></li><li><span><a href="#Conference-name" data-toc-modified-id="Conference-name-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Conference name</a></span></li></ul></li><li><span><a href="#Germany" data-toc-modified-id="Germany-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Germany</a></span><ul class="toc-item"><li><span><a href="#Acknowledgment-in-paper" data-toc-modified-id="Acknowledgment-in-paper-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Acknowledgment in paper</a></span></li><li><span><a href="#Participation-to-conferences" data-toc-modified-id="Participation-to-conferences-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Participation to conferences</a></span></li><li><span><a href="#Conference-name" data-toc-modified-id="Conference-name-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Conference name</a></span></li></ul></li><li><span><a href="#Netherlands" data-toc-modified-id="Netherlands-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Netherlands</a></span><ul class="toc-item"><li><span><a href="#Acknowledgment-in-paper" data-toc-modified-id="Acknowledgment-in-paper-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Acknowledgment in paper</a></span></li><li><span><a href="#Participation-to-conferences" data-toc-modified-id="Participation-to-conferences-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Participation to conferences</a></span></li><li><span><a href="#Conference-name" data-toc-modified-id="Conference-name-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Conference name</a></span></li></ul></li><li><span><a href="#New-Zealand" data-toc-modified-id="New-Zealand-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>New Zealand</a></span><ul class="toc-item"><li><span><a href="#Acknowledgment-in-paper" data-toc-modified-id="Acknowledgment-in-paper-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Acknowledgment in paper</a></span></li><li><span><a href="#Participation-to-conferences" data-toc-modified-id="Participation-to-conferences-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Participation to conferences</a></span></li><li><span><a href="#Conference-name" data-toc-modified-id="Conference-name-2.4.3"><span class="toc-item-num">2.4.3&nbsp;&nbsp;</span>Conference name</a></span></li></ul></li><li><span><a href="#South-Africa" data-toc-modified-id="South-Africa-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>South Africa</a></span><ul class="toc-item"><li><span><a href="#Acknowledgment-in-paper" data-toc-modified-id="Acknowledgment-in-paper-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Acknowledgment in paper</a></span></li><li><span><a href="#Participation-to-conferences" data-toc-modified-id="Participation-to-conferences-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>Participation to conferences</a></span></li><li><span><a href="#Conference-name" data-toc-modified-id="Conference-name-2.5.3"><span class="toc-item-num">2.5.3&nbsp;&nbsp;</span>Conference name</a></span></li></ul></li><li><span><a href="#United-Kingdom" data-toc-modified-id="United-Kingdom-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>United Kingdom</a></span><ul class="toc-item"><li><span><a href="#Acknowledgment-in-paper" data-toc-modified-id="Acknowledgment-in-paper-2.6.1"><span class="toc-item-num">2.6.1&nbsp;&nbsp;</span>Acknowledgment in paper</a></span></li><li><span><a href="#Participation-to-conferences" data-toc-modified-id="Participation-to-conferences-2.6.2"><span class="toc-item-num">2.6.2&nbsp;&nbsp;</span>Participation to conferences</a></span></li><li><span><a href="#Conference-name" data-toc-modified-id="Conference-name-2.6.3"><span class="toc-item-num">2.6.3&nbsp;&nbsp;</span>Conference name</a></span></li></ul></li><li><span><a href="#United-States" data-toc-modified-id="United-States-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>United States</a></span><ul class="toc-item"><li><span><a href="#Acknowledgment-in-paper" data-toc-modified-id="Acknowledgment-in-paper-2.7.1"><span class="toc-item-num">2.7.1&nbsp;&nbsp;</span>Acknowledgment in paper</a></span></li><li><span><a href="#Participation-to-conferences" data-toc-modified-id="Participation-to-conferences-2.7.2"><span class="toc-item-num">2.7.2&nbsp;&nbsp;</span>Participation to conferences</a></span></li><li><span><a href="#Conference-name" data-toc-modified-id="Conference-name-2.7.3"><span class="toc-item-num">2.7.3&nbsp;&nbsp;</span>Conference name</a></span></li></ul></li><li><span><a href="#Rest-of-the-world" data-toc-modified-id="Rest-of-the-world-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Rest of the world</a></span><ul class="toc-item"><li><span><a href="#Acknowledgment-in-paper" data-toc-modified-id="Acknowledgment-in-paper-2.8.1"><span class="toc-item-num">2.8.1&nbsp;&nbsp;</span>Acknowledgment in paper</a></span></li><li><span><a href="#Participation-to-conferences" data-toc-modified-id="Participation-to-conferences-2.8.2"><span class="toc-item-num">2.8.2&nbsp;&nbsp;</span>Participation to conferences</a></span></li><li><span><a href="#Conference-name" data-toc-modified-id="Conference-name-2.8.3"><span class="toc-item-num">2.8.3&nbsp;&nbsp;</span>Conference name</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Introduction

# %% [markdown]
# RSEs is an hybrid role between a researcher and a software developer. We investigated both of these aspects concerning publication and dissemination of their work, one on the traditional aspect of it (publications and conference).
# One essential aspect of career in academia is the publications and the conferences to gain recognition. However, the role of RSE being less about writing articles than creating the infrastructure and the software for the article to exist, there is some fear that they will fail to have recognition through the papers and conferences.

# %% [markdown]
# ## Questions in the section
# * `In general, when your software contributes to a paper, are you acknowledged in that paper?`: one choice
# * `Have you presented your software work at a conference or workshop?`: yes-no
# * `At which conference(s)/workshop(s) have you presented your software work?`: free text

# %% [markdown]
# ## Setting up

# %%
# %%capture  
# Import notebook containing the imports the functions and the dataset
# %run "./0. Imports and functions.ipynb"

# Import notebook containing sampled dataset
# %run "./1. Overview and sampling.ipynb"

# %% [markdown]
# # Publications and citations

# %%
paper = ['paper2mod. In general, when your software contributes to a paper, are you acknowledged in that paper?']
order_paper = ['Not mentioned at all', 'Acknowledged in the main text', 'Acknowledged in acknowledgements section', 'Named as co-author', 'Named as main author']

conf1 = ['conf1can. Have you presented your software work at a conference or workshop?']

conf2 = ['conf2can. At which conference(s)/workshop(s) have you presented your software work?']

# %% [markdown]
# ## Australia

# %%
country = 'Australia'

# %% [markdown]
# ### Acknowledgment in paper

# %%
category = 'Acknowledgment in paper'
results = count_diff(df, paper, country, category, order_index=order_paper)
results
# Out:
#                                           Count  Percentage
# Acknowledgment in paper for Australia
# Not mentioned at all                         18   20.224719
# Acknowledged in the main text                 3    3.370787
# Acknowledged in acknowledgements section     18   20.224719
# Named as co-author                           45   50.561798
# Named as main author                          5    5.617978

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_paper)

# %% [markdown]
# ### Participation to conferences

# %%
category = 'Did you participate to conference'
results = count_diff(df, conf1, country, category, y_n=True)
results
# Out:
#                                                  Count  Percentage
# Did you participate to conference for Australia
# Yes                                                 45   55.555556
# No                                                  36   44.444444

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Conference name

# %%
plot_wordcloud(df, conf2, country, category)

# %% [markdown]
# ## Germany

# %%
country = 'Germany'

# %% [markdown]
# ### Acknowledgment in paper

# %%
category = 'Acknowledgment in paper'
results = count_diff(df, paper, country, category, order_index=order_paper)
results
# Out:
#                                           Count  Percentage
# Acknowledgment in paper for Germany
# Not mentioned at all                         63   21.355932
# Acknowledged in the main text                28    9.491525
# Acknowledged in acknowledgements section     56   18.983051
# Named as co-author                          124   42.033898
# Named as main author                         24    8.135593

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_paper)

# %% [markdown]
# ### Participation to conferences

# %%
category = 'Did you participate to conference'
results = count_diff(df, conf1, country, category, y_n=True)
results
# Out:
#                                                Count  Percentage  \
# Did you participate to conference for Germany
# Yes                                              150   54.347826
# No                                               126   45.652174
#
#                                                Percentage in 2017  \
# Did you participate to conference for Germany
# Yes                                                     55.666667
# No                                                      44.333333
#
#                                                Difference with previous year
# Did you participate to conference for Germany
# Yes                                                                -1.318841
# No                                                                  1.318841

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Conference name

# %%
plot_wordcloud(df, conf2, country, category)

# %% [markdown]
# ## Netherlands

# %%
country = 'Netherlands'

# %% [markdown]
# ### Acknowledgment in paper

# %%
category = 'Acknowledgment in paper'
results = count_diff(df, paper, country, category, order_index=order_paper)
results
# Out:
#                                           Count  Percentage
# Acknowledgment in paper for Netherlands
# Not mentioned at all                         12   23.529412
# Acknowledged in the main text                 7   13.725490
# Acknowledged in acknowledgements section      8   15.686275
# Named as co-author                           23   45.098039
# Named as main author                          1    1.960784

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_paper)

# %% [markdown]
# ### Participation to conferences

# %%
category = 'Did you participate to conference'
results = count_diff(df, conf1, country, category, y_n=True)
results
# Out:
#                                                    Count  Percentage  \
# Did you participate to conference for Netherlands
# Yes                                                   26        52.0
# No                                                    24        48.0
#
#                                                    Percentage in 2017  \
# Did you participate to conference for Netherlands
# Yes                                                         78.082192
# No                                                          21.917808
#
#                                                    Difference with previous year
# Did you participate to conference for Netherlands
# Yes                                                                   -26.082192
# No                                                                     26.082192

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Conference name

# %%
plot_wordcloud(df, conf2, country, category)

# %% [markdown]
# ## New Zealand

# %%
country = 'New Zealand'

# %% [markdown]
# ### Acknowledgment in paper

# %%
category = 'Acknowledgment in paper'
results = count_diff(df, paper, country, category, order_index=order_paper)
results
# Out:
#                                           Count  Percentage
# Acknowledgment in paper for New Zealand
# Not mentioned at all                          6   17.647059
# Acknowledged in the main text                 3    8.823529
# Acknowledged in acknowledgements section      7   20.588235
# Named as co-author                           15   44.117647
# Named as main author                          3    8.823529

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_paper)

# %% [markdown]
# ### Participation to conferences

# %%
category = 'Did you participate to conference'
results = count_diff(df, conf1, country, category, y_n=True)
results
# Out:
#                                                    Count  Percentage
# Did you participate to conference for New Zealand
# Yes                                                   18       56.25
# No                                                    14       43.75

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Conference name

# %%
plot_wordcloud(df, conf2, country, category)

# %% [markdown]
# ## South Africa

# %%
country = 'South Africa'

# %% [markdown]
# ### Acknowledgment in paper

# %%
category = 'Acknowledgment in paper'
results = count_diff(df, paper, country, category, order_index=order_paper)
results
# Out:
#                                           Count  Percentage
# Acknowledgment in paper for South Africa
# Not mentioned at all                          5   23.809524
# Acknowledged in the main text                 1    4.761905
# Acknowledged in acknowledgements section      4   19.047619
# Named as co-author                           10   47.619048
# Named as main author                          1    4.761905

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_paper)

# %% [markdown]
# ### Participation to conferences

# %%
category = 'Did you participate to conference'
results = count_diff(df, conf1, country, category, y_n=True)
results
# Out:
#                                                     Count  Percentage  \
# Did you participate to conference for South Africa
# Yes                                                    12        60.0
# No                                                      8        40.0
#
#                                                     Percentage in 2017  \
# Did you participate to conference for South Africa
# Yes                                                              31.25
# No                                                               68.75
#
#                                                     Difference with previous year
# Did you participate to conference for South Africa
# Yes                                                                         28.75
# No                                                                         -28.75

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Conference name

# %%
plot_wordcloud(df, conf2, country, category)

# %% [markdown]
# ## United Kingdom

# %% [markdown]
# When the software developed by the participants is used in a paper, the majority of them are named as co-author, and 5% are named as main author. There still exists a high percentage of RSE that are not mentioned at all (19%).
#
# On conference, the number of RSEs who present their work in conference is rather small, only 57%.

# %%
country = 'United Kingdom'

# %% [markdown]
# ### Acknowledgment in paper

# %%
category = 'Acknowledgment in paper'
results = count_diff(df, paper, country, category, order_index=order_paper)
results
# Out:
#                                             Count  Percentage
# Acknowledgment in paper for United Kingdom
# Not mentioned at all                           41   19.158879
# Acknowledged in the main text                  10    4.672897
# Acknowledged in acknowledgements section       42   19.626168
# Named as co-author                            110   51.401869
# Named as main author                           11    5.140187

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_paper)

# %% [markdown]
# ### Participation to conferences

# %%
category = 'Did you participate to conference'
results = count_diff(df, conf1, country, category, y_n=True)
results
# Out:
#                                                     Count  Percentage  \
# Did you participate to conference for United Ki...
# Yes                                                   121   58.173077
# No                                                     87   41.826923
#
#                                                     Percentage in 2017  \
# Did you participate to conference for United Ki...
# Yes                                                          57.826087
# No                                                           42.173913
#
#                                                     Difference with previous year
# Did you participate to conference for United Ki...
# Yes                                                                       0.34699
# No                                                                       -0.34699

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Conference name

# %%
plot_wordcloud(df, conf2, country, category)

# %% [markdown]
# ## United States

# %%
country = 'United States'

# %% [markdown]
# ### Acknowledgment in paper

# %%
category = 'Acknowledgment in paper'
results = count_diff(df, paper, country, category, order_index=order_paper)
results
# Out:
#                                            Count  Percentage
# Acknowledgment in paper for United States
# Not mentioned at all                          30   21.739130
# Acknowledged in the main text                 17   12.318841
# Acknowledged in acknowledgements section      23   16.666667
# Named as co-author                            65   47.101449
# Named as main author                           3    2.173913

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_paper)

# %% [markdown]
# ### Participation to conferences

# %%
category = 'Did you participate to conference'
results = count_diff(df, conf1, country, category, y_n=True)
results
# Out:
#                                                     Count  Percentage  \
# Did you participate to conference for United St...
# Yes                                                    79   59.848485
# No                                                     53   40.151515
#
#                                                     Percentage in 2017  \
# Did you participate to conference for United St...
# Yes                                                          65.957447
# No                                                           34.042553
#
#                                                     Difference with previous year
# Did you participate to conference for United St...
# Yes                                                                     -6.108962
# No                                                                       6.108962

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Conference name

# %%
plot_wordcloud(df, conf2, country, category)

# %% [markdown]
# ## Rest of the world

# %%
country = 'World'

# %% [markdown]
# ### Acknowledgment in paper

# %%
category = 'Acknowledgment in paper'
results = count_diff(df, paper, country, category, order_index=order_paper)
results
# Out:
#                                           Count  Percentage
# Acknowledgment in paper for World
# Not mentioned at all                         10   24.390244
# Acknowledged in the main text                 2    4.878049
# Acknowledged in acknowledgements section      5   12.195122
# Named as co-author                           22   53.658537
# Named as main author                          2    4.878049

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_paper)

# %% [markdown]
# ### Participation to conferences

# %%
category = 'Did you participate to conference'
results = count_diff(df, conf1, country, category, y_n=True)
results
# Out:
#                                              Count  Percentage
# Did you participate to conference for World
# Yes                                             21   53.846154
# No                                              18   46.153846

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Conference name

# %%
plot_wordcloud(df, conf2, country, category)
