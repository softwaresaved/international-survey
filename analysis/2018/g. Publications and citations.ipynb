# %% [markdown]
# # Introduction

# %% [markdown]
# ## Setting up

# %%
# %%capture  
# Import notebook containing the imports the functions and the dataset
# %run "./0. Imports and functions.ipynb"

# Import notebook containing sampled dataset
# %run "./1. Overview and sampling.ipynb"

# %% [markdown]
# # Publications and citations

# %%
paper = ['paper2mod. In general, when your software contributes to a paper, are you acknowledged in that paper?']
order_paper = ['Not mentioned at all', 'Acknowledged in the main text', 'Acknowledged in acknowledgements section', 'Named as co-author', 'Named as main author']

conf1 = ['conf1can. Have you presented your software work at a conference or workshop?']

conf2 = ['conf2can. At which conference(s)/workshop(s) have you presented your software work?']

# %% [markdown]
# ## Australia

# %%
country = 'Australia'

# %% [markdown]
# ### Acknowledgment in paper

# %%
category = 'Acknowledgment in paper'
results = count_diff(df, paper, country, category, order_index=order_paper)
results
# Out:
#                                           Count  Percentage
# Acknowledgment in paper for Australia
# Not mentioned at all                         18   20.454545
# Acknowledged in the main text                 3    3.409091
# Acknowledged in acknowledgements section     18   20.454545
# Named as co-author                           44   50.000000
# Named as main author                          5    5.681818

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_paper)

# %% [markdown]
# ### Participation to conferences

# %%
category = 'Did you participate to conference'
results = count_diff(df, conf1, country, category, y_n=True)
results
# Out:
#                                                  Count  Percentage
# Did you participate to conference for Australia
# Yes                                                 44        55.0
# No                                                  36        45.0

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Conference name

# %%
plot_wordcloud(df, conf2, country, category)

# %% [markdown]
# ## Germany

# %%
country = 'Germany'

# %% [markdown]
# ### Acknowledgment in paper

# %%
category = 'Acknowledgment in paper'
results = count_diff(df, paper, country, category, order_index=order_paper)
results
# Out:
#                                           Count  Percentage
# Acknowledgment in paper for Germany
# Not mentioned at all                         63   21.501706
# Acknowledged in the main text                28    9.556314
# Acknowledged in acknowledgements section     55   18.771331
# Named as co-author                          123   41.979522
# Named as main author                         24    8.191126

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_paper)

# %% [markdown]
# ### Participation to conferences

# %%
category = 'Did you participate to conference'
results = count_diff(df, conf1, country, category, y_n=True)
results
# Out:
#                                                Count  Percentage  \
# Did you participate to conference for Germany
# Yes                                              149   54.181818
# No                                               126   45.818182
#
#                                                Difference with previous year
# Did you participate to conference for Germany
# Yes                                                                -1.484848
# No                                                                  1.484848

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Conference name

# %%
plot_wordcloud(df, conf2, country, category)

# %% [markdown]
# ## Netherlands

# %%
country = 'Netherlands'

# %% [markdown]
# ### Acknowledgment in paper

# %%
category = 'Acknowledgment in paper'
results = count_diff(df, paper, country, category, order_index=order_paper)
results
# Out:
#                                           Count  Percentage
# Acknowledgment in paper for Netherlands
# Not mentioned at all                         10   21.276596
# Acknowledged in the main text                 6   12.765957
# Acknowledged in acknowledgements section      8   17.021277
# Named as co-author                           22   46.808511
# Named as main author                          1    2.127660

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_paper)

# %% [markdown]
# ### Participation to conferences

# %%
category = 'Did you participate to conference'
results = count_diff(df, conf1, country, category, y_n=True)
results
# Out:
#                                                    Count  Percentage  \
# Did you participate to conference for Netherlands
# Yes                                                   22   47.826087
# No                                                    24   52.173913
#
#                                                    Difference with previous year
# Did you participate to conference for Netherlands
# Yes                                                                   -30.256105
# No                                                                     30.256105

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Conference name

# %%
plot_wordcloud(df, conf2, country, category)

# %% [markdown]
# ## New Zealand

# %%
country = 'New Zealand'

# %% [markdown]
# ### Acknowledgment in paper

# %%
category = 'Acknowledgment in paper'
results = count_diff(df, paper, country, category, order_index=order_paper)
results
# Out:
#                                           Count  Percentage
# Acknowledgment in paper for New Zealand
# Not mentioned at all                          6   17.647059
# Acknowledged in the main text                 3    8.823529
# Acknowledged in acknowledgements section      7   20.588235
# Named as co-author                           15   44.117647
# Named as main author                          3    8.823529

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_paper)

# %% [markdown]
# ### Participation to conferences

# %%
category = 'Did you participate to conference'
results = count_diff(df, conf1, country, category, y_n=True)
results
# Out:
#                                                    Count  Percentage
# Did you participate to conference for New Zealand
# Yes                                                   18       56.25
# No                                                    14       43.75

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Conference name

# %%
plot_wordcloud(df, conf2, country, category)

# %% [markdown]
# ## South Africa

# %%
country = 'South Africa'

# %% [markdown]
# ### Acknowledgment in paper

# %%
category = 'Acknowledgment in paper'
results = count_diff(df, paper, country, category, order_index=order_paper)
results
# Out:
#                                           Count  Percentage
# Acknowledgment in paper for South Africa
# Not mentioned at all                          5   23.809524
# Acknowledged in the main text                 1    4.761905
# Acknowledged in acknowledgements section      4   19.047619
# Named as co-author                           10   47.619048
# Named as main author                          1    4.761905

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_paper)

# %% [markdown]
# ### Participation to conferences

# %%
category = 'Did you participate to conference'
results = count_diff(df, conf1, country, category, y_n=True)
results
# Out:
#                                                     Count  Percentage  \
# Did you participate to conference for South Africa
# Yes                                                    12        60.0
# No                                                      8        40.0
#
#                                                     Difference with previous year
# Did you participate to conference for South Africa
# Yes                                                                         28.75
# No                                                                         -28.75

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Conference name

# %%
plot_wordcloud(df, conf2, country, category)

# %% [markdown]
# ## United Kingdom

# %%
country = 'United Kingdom'

# %% [markdown]
# ### Acknowledgment in paper

# %%
category = 'Acknowledgment in paper'
results = count_diff(df, paper, country, category, order_index=order_paper)
results
# Out:
#                                             Count  Percentage
# Acknowledgment in paper for United Kingdom
# Not mentioned at all                           39   18.396226
# Acknowledged in the main text                  10    4.716981
# Acknowledged in acknowledgements section       42   19.811321
# Named as co-author                            110   51.886792
# Named as main author                           11    5.188679

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_paper)

# %% [markdown]
# ### Participation to conferences

# %%
category = 'Did you participate to conference'
results = count_diff(df, conf1, country, category, y_n=True)
results
# Out:
#                                                     Count  Percentage  \
# Did you participate to conference for United Ki...
# Yes                                                   121   58.737864
# No                                                     85   41.262136
#
#                                                     Difference with previous year
# Did you participate to conference for United Ki...
# Yes                                                                      0.911777
# No                                                                      -0.911777

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Conference name

# %%
plot_wordcloud(df, conf2, country, category)

# %% [markdown]
# ## United States

# %%
country = 'United States'

# %% [markdown]
# ### Acknowledgment in paper

# %%
category = 'Acknowledgment in paper'
results = count_diff(df, paper, country, category, order_index=order_paper)
results
# Out:
#                                            Count  Percentage
# Acknowledgment in paper for United States
# Not mentioned at all                          30   21.739130
# Acknowledged in the main text                 17   12.318841
# Acknowledged in acknowledgements section      23   16.666667
# Named as co-author                            65   47.101449
# Named as main author                           3    2.173913

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_paper)

# %% [markdown]
# ### Participation to conferences

# %%
category = 'Did you participate to conference'
results = count_diff(df, conf1, country, category, y_n=True)
results
# Out:
#                                                     Count  Percentage  \
# Did you participate to conference for United St...
# Yes                                                    79   59.848485
# No                                                     53   40.151515
#
#                                                     Difference with previous year
# Did you participate to conference for United St...
# Yes                                                                     -6.108962
# No                                                                       6.108962

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Conference name

# %%
plot_wordcloud(df, conf2, country, category)

# %% [markdown]
# ## Rest of the world

# %%
country = 'World'

# %% [markdown]
# ### Acknowledgment in paper

# %%
category = 'Acknowledgment in paper'
results = count_diff(df, paper, country, category, order_index=order_paper)
results
# Out:
#                                           Count  Percentage
# Acknowledgment in paper for World
# Not mentioned at all                         10   25.641026
# Acknowledged in the main text                 2    5.128205
# Acknowledged in acknowledgements section      5   12.820513
# Named as co-author                           20   51.282051
# Named as main author                          2    5.128205

# %%
plot_cat_comparison(results, country=country, category=category, order_index=order_paper)

# %% [markdown]
# ### Participation to conferences

# %%
category = 'Did you participate to conference'
results = count_diff(df, conf1, country, category, y_n=True)
results
# Out:
#                                              Count  Percentage
# Did you participate to conference for World
# Yes                                             20   52.631579
# No                                              18   47.368421

# %%
plot_cat_comparison(results, country=country, category=category)

# %% [markdown]
# ### Conference name

# %%
plot_wordcloud(df, conf2, country, category)
