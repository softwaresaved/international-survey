# %% [markdown]
# # Section: Importing modules

# %%
import operator
import sys
from pathlib import Path

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

from IPython.display import display
import IPython.core.display as di
from IPython.core.interactiveshell import InteractiveShell

sys.path.append(str(Path('.').absolute().parent))

from include.config import CleaningConfig, PlottingConfig, NotebookConfig
from include.counting import get_count, get_percentage
from include.plotting import get_plot, display_side_by_side
from include.likertScalePlot import likert_scale
from include.textCleaning import wordcloud

# %%
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000) 
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# This text is used to hide the code cell when exported in html

# %%
di.display_html('<script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>', raw=True)
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>

# %%
get_ipython().magic('matplotlib inline')  # Activate that line to use in Jupyter 
matplotlib.rcParams['figure.figsize'] = (15.0, 8.0)

# %% [markdown]
# # Loading dataset

# %%
df =  pd.read_csv('./can/data/public_data.csv')

# %% [markdown]
# The total of participant after cleaning the dataset. Remove all participants that have not completed the survey passed the first pages and all participants who are not from the country

# %%
len(df)
# Out:
# 110

# %% [markdown]
# # Section:

# %% [markdown]
# ## Group of question: socio

# %% [markdown]
# ### In which country do you work?

# %%
v_to_count, filename = get_count(df, ['socio1. In which country do you work?'], "one choice", "./../../survey_creation/2017/can/listAnswers/countries.csv", "False", "./can/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                Count Percentage
# In which country do you work?
# Canada                           110        100

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ## Group of question: rse

# %% [markdown]
# ### Do you write software for research as part of your job?

# %%
v_to_count, filename = get_count(df, ['rse1. Do you write software for research as part of your job?'], "y/n/na", "./../../survey_creation/2017/can/listAnswers/.csv", "False", "./can/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Yes [Count]  No [Count]  \
# Do you write software for research as part of y...
#  Do you write software for research as part of ...           97          13
#
#                                                    Yes [Percentage]  \
# Do you write software for research as part of y...
#  Do you write software for research as part of ...               88
#
#                                                    No [Percentage]
# Do you write software for research as part of y...
#  Do you write software for research as part of ...              12

# %%
_ = get_plot(perc_to_count, "y/n/na")

# %% [markdown]
# ## Group of question: edu

# %% [markdown]
# ### What is the highest level of education you have attained?

# %%
v_to_count, filename = get_count(df, ['edu1. What is the highest level of education you have attained?'], "one choice", "./../../survey_creation/2017/can/listAnswers/education.csv", "False", "./can/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Count Percentage
# What is the highest level of education you have...
# Doctorate                                              49         45
# Masters Degree                                         30         27
# Bachelors Degree                                       19         17
# College Diploma                                         6          5
# Some University                                         5          5
# Some College                                            1          1

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ### In which discipline is your highest academic qualification?

# %%
v_to_count, filename = get_count(df, ['edu2. In which discipline is your highest academic qualification?'], "one choice", "./../../survey_creation/2017/can/listAnswers/academic_field.csv", "False", "./can/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Count Percentage
# In which discipline is your highest academic qu...
# Information technology                                 28         25
# Other                                                  12         11
# Biomedical engineering                                  8          7
# Artificial intelligence                                 6          5
# Physics                                                 6          5
# Applied mathematics                                     5          5
# Electrical and electronic engineering                   4          4
# Chemical engineering                                    3          3
# Theoretical physics and chemistry                       3          3
# Genetics                                                3          3
# Evolution and ecology                                   2          2
# Fluid mechanics                                         2          2
# ...

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ### List any professional qualifications you hold (eg. P. Eng, PMP, …)

# %%
 wc = wordcloud(df, ['edu4. List any professional qualifications you hold (eg. P. Eng, PMP, …)'])

# %%
 plt.imshow(wc, interpolation='bilinear')
 plt.axis("off")
# Out:
# (-0.5, 1499.5, 799.5, -0.5)

# %% [markdown]
# ## Group of question: time

# %% [markdown]
# ### On average, how much of your time is spent developing software?; On average, how much of your time is spent on research?; On average, how much of the time you spend developing software is spent on new development/enhancement?; On average, how much of the time you spend developing software is devoted to maintenance and support activities?; On average, how much time do you spend on management?; On average, how much time do you spend on other activities?

# %%
v_to_count, filename = get_count(df, ['time1can. On average, how much of your time is spent developing software?', 'time2can. On average, how much of your time is spent on research?', 'time2acan. On average, how much of the time you spend developing software is spent on new development/enhancement?', 'time2bcan. On average, how much of the time you spend developing software is devoted to maintenance and support activities?', 'time3can. On average, how much time do you spend on management?', 'time5can. On average, how much time do you spend on other activities?'], "likert", "./../../survey_creation/2017/can/listAnswers/likert_time_10.csv", "False", "./can/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                    On average, how much of your time is spent developing software? [Count]  \
# Spending time
# 1 (None at all)                                                   5
# 2                                                                14
# 3                                                                23
# 4                                                                 9
# 5                                                                19
# 6                                                                 3
# 7                                                                15
# 8                                                                 6
# 9                                                                 5
# 10 (All my time)                                                  6
#
#                    On average, how much of your time is spent on research? [Count]  \
# Spending time
# 1 (None at all)                                                  16
# ...

# %%
_ = get_plot(v_to_count, "likert")

# %% [markdown]
# ## Group of question: soft

# %% [markdown]
# ### How many years of software development experience do you have?

# %%
v_to_count, filename = get_count(df, ['soft1can. How many years of software development experience do you have?'], "freenumeric", "./../../survey_creation/2017/can/listAnswers/.csv", "False", "./can/output/")

# %%
_ = get_plot(v_to_count, "freenumeric")
# Out:
#        soft1can. How many years of software development experience do you have?
# count                                          98.000000
# mean                                           14.510204
# std                                            10.892393
# min                                             0.000000
# 25%                                             5.250000
# 50%                                            15.000000
# 75%                                            20.000000
# max                                            56.000000
# /home/olivier/.data/git/ssi/international-survey/venv/lib/python3.7/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ### Do you consider yourself a professional software developer?

# %%
v_to_count, filename = get_count(df, ['soft2can. Do you consider yourself a professional software developer?'], "y/n/na", "./../../survey_creation/2017/can/listAnswers/.csv", "False", "./can/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Yes [Count]  No [Count]  \
# Do you consider yourself a professional softwar...
#  Do you consider yourself a professional softwa...           48          53
#
#                                                     NaN value  \
# Do you consider yourself a professional softwar...
#  Do you consider yourself a professional softwa...          9
#
#                                                    Yes [Percentage]  \
# Do you consider yourself a professional softwar...
#  Do you consider yourself a professional softwa...               48
#
#                                                    No [Percentage]
# Do you consider yourself a professional softwar...
#  Do you consider yourself a professional softwa...              52

# %%
_ = get_plot(perc_to_count, "y/n/na")

# %% [markdown]
# ## Group of question: proj

# %% [markdown]
# ### How many software projects are you currently involved in?

# %%
v_to_count, filename = get_count(df, ['proj1_can. How many software projects are you currently involved in?'], "freenumeric", "./../../survey_creation/2017/can/listAnswers/.csv", "False", "./can/output/")

# %%
_ = get_plot(v_to_count, "freenumeric")
# Out:
#        proj1_can. How many software projects are you currently involved in?
# count                                          99.000000
# mean                                            3.888889
# std                                             3.901567
# min                                             0.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             5.000000
# max                                            30.000000
# /home/olivier/.data/git/ssi/international-survey/venv/lib/python3.7/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ### How many software developers typically work on your projects?

# %%
v_to_count, filename = get_count(df, ['proj2_can. How many software developers typically work on your projects?'], "one choice", "./../../survey_creation/2017/can/listAnswers/project_team.csv", "False", "./can/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Count Percentage
# How many software developers typically work on ...
# 3-5                                                    39         38
# Just me                                                25         24
# 2                                                      22         21
# 6-9                                                    10         10
# 10+                                                     7          7
# NaN                                                     7        NaN

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ### Do your research software projects typically include a project manager?

# %%
v_to_count, filename = get_count(df, ['proj5_can. Do your research software projects typically include a project manager?'], "y/n/na", "./../../survey_creation/2017/can/listAnswers/.csv", "False", "./can/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Yes [Count]  No [Count]  \
# Do your research software projects typically in...
#  Do your research software projects typically i...           50          50
#
#                                                     NaN value  \
# Do your research software projects typically in...
#  Do your research software projects typically i...         10
#
#                                                    Yes [Percentage]  \
# Do your research software projects typically in...
#  Do your research software projects typically i...               50
#
#                                                    No [Percentage]
# Do your research software projects typically in...
#  Do your research software projects typically i...              50

# %%
_ = get_plot(perc_to_count, "y/n/na")

# %% [markdown]
# ### What development methodology does your current project use?

# %%
v_to_count, filename = get_count(df, ['proj6_can. What development methodology does your current project use?'], "one choice", "./../../survey_creation/2017/can/listAnswers/methodology.csv", "False", "./can/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Count Percentage
# What development methodology does your current ...
# No formal methodology                                  63         64
# Scrum                                                  11         11
# Kanban                                                 10         10
# Other                                                   8          8
# Waterfall                                               7          7
# NaN                                                    11        NaN

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ## Group of question: canarie

# %% [markdown]
# ### Have you ever visited the Research Software Registry at science.canarie.ca?

# %%
v_to_count, filename = get_count(df, ['canarie1_can. Have you ever visited the Research Software Registry at science.canarie.ca?'], "y/n/na", "./../../survey_creation/2017/can/listAnswers/.csv", "False", "./can/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Yes [Count]  No [Count]  \
# Have you ever visited the Research Software Reg...
#  Have you ever visited the Research Software Re...           39          65
#
#                                                     NaN value  \
# Have you ever visited the Research Software Reg...
#  Have you ever visited the Research Software Re...          6
#
#                                                    Yes [Percentage]  \
# Have you ever visited the Research Software Reg...
#  Have you ever visited the Research Software Re...               38
#
#                                                    No [Percentage]
# Have you ever visited the Research Software Reg...
#  Have you ever visited the Research Software Re...              62

# %%
_ = get_plot(perc_to_count, "y/n/na")

# %% [markdown]
# ### How many software components from science.canarie.ca have you integrated into your projects?

# %%
v_to_count, filename = get_count(df, ['canarie2_can. How many software components from science.canarie.ca have you integrated into your projects?'], "freenumeric", "./../../survey_creation/2017/can/listAnswers/.csv", "False", "./can/output/")

# %%
_ = get_plot(v_to_count, "freenumeric")
# Out:
#        canarie2_can. How many software components from science.canarie.ca have you integrated into your projects?
# count                                          83.000000
# mean                                            1.144578
# std                                             5.663603
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                            50.000000
# /home/olivier/.data/git/ssi/international-survey/venv/lib/python3.7/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ## Group of question: currentEmp

# %% [markdown]
# ### What type of organization do you work for?

# %%
v_to_count, filename = get_count(df, ['currentEmp1. What type of organization do you work for?'], "one choice", "./../../survey_creation/2017/can/listAnswers/type_organisation.csv", "False", "./can/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                             Count Percentage
# What type of organization do you work for?
# University                                     57         56
# Non-profit                                     23         23
# Private sector                                  7          7
# College                                         5          5
# Government department                           5          5
# Other                                           4          4
# Charity                                         1          1
# NaN                                             8        NaN

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ### What is your current job title?

# %%
 wc = wordcloud(df, ['currentEmp5. What is your current job title?'])

# %%
 plt.imshow(wc, interpolation='bilinear')
 plt.axis("off")
# Out:
# (-0.5, 1499.5, 799.5, -0.5)

# %% [markdown]
# ### In which application area do you primarily work?

# %%
v_to_count, filename = get_count(df, ['currentEmp7. In which application area do you primarily work?'], "one choice", "./../../survey_creation/2017/can/listAnswers/academic_field.csv", "False", "./can/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Count Percentage
# In which application area do you primarily work?
# Information technology                                 21         21
# Other                                                  11         11
# Artificial intelligence                                 8          8
# Biomedical engineering                                  7          7
# Genetics                                                6          6
# Applied mathematics                                     5          5
# Health Sciences                                         4          4
# Astronomy and astrophysics                              4          4
# Earth science                                           3          3
# Theoretical physics and chemistry                       3          3
# Fuel and energy technology                              3          3
# Physics                                                 3          3
# ...

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ### What is the nature of your current employment?

# %%
v_to_count, filename = get_count(df, ['currentEmp10. What is the nature of your current employment?'], "one choice", "./../../survey_creation/2017/can/listAnswers/type_contract.csv", "False", "./can/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                 Count Percentage
# What is the nature of your current employment?
# Full-time                                          81         78
# Contract                                            8          8
# Other                                               4          4
# Grad student                                        4          4
# Part-time                                           4          4
# Co-op/intern                                        2          2
# Self-employed                                       1          1
# NaN                                                 6        NaN

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ## Group of question: group

# %% [markdown]
# ### Do you work within a group that provides software development help or expertise to researchers from across your organization?; Is there such a group within your organization?; Do you think such a group would have value?; Would you be interested in participating in such a group?

# %%
v_to_count, filename = get_count(df, ['group1_can. Do you work within a group that provides software development help or expertise to researchers from across your organization?', 'group1a_can. Is there such a group within your organization?', 'group2_can. Do you think such a group would have value?', 'group3_can. Would you be interested in participating in such a group?'], "y/n/na", "./../../survey_creation/2017/can/listAnswers/.csv", "False", "./can/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Yes [Count]  No [Count]  \
# Do you work within a group that provides softwa...
#  Do you work within a group that provides softw...           55          45
#  Is there such a group within your organization?             10          25
#  Do you think such a group would have value?                 16           5
#  Would you be interested in participating in su...           12           3
#
#                                                     NaN value  \
# Do you work within a group that provides softwa...
#  Do you work within a group that provides softw...         10
#  Is there such a group within your organization?           75
#  Do you think such a group would have value?               89
#  Would you be interested in participating in su...         95
#
#                                                    Yes [Percentage]  \
# Do you work within a group that provides softwa...
# ...

# %%
_ = get_plot(perc_to_count, "y/n/na")

# %% [markdown]
# ## Group of question: paper

# %% [markdown]
# ### Have you contributed software to research that has been published in a journal or presented at a conference?; In general, when your software contributes to a paper, are you acknowledged in that paper?; Are you generally named as the main author of the paper?; Are you generally named as a co-author of the paper?

# %%
v_to_count, filename = get_count(df, ['paper1. Have you contributed software to research that has been published in a journal or presented at a conference?', 'paper2. In general, when your software contributes to a paper, are you acknowledged in that paper?', 'paper3. Are you generally named as the main author of the paper?', 'paper4. Are you generally named as a co-author of the paper?'], "y/n/na", "./../../survey_creation/2017/can/listAnswers/.csv", "False", "./can/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Yes [Count]  No [Count]  \
# Publications
#  Have you contributed software to research that...           77          24
#  In general, when your software contributes to ...           65          28
#  Are you generally named as the main author of ...           25          68
#  Are you generally named as a co-author of the ...           52          39
#
#                                                     NaN value  \
# Publications
#  Have you contributed software to research that...          9
#  In general, when your software contributes to ...         17
#  Are you generally named as the main author of ...         17
#  Are you generally named as a co-author of the ...         19
#
#                                                    Yes [Percentage]  \
# Publications
#  Have you contributed software to research that...               76
#  In general, when your software contributes to ...               70
# ...

# %%
_ = get_plot(perc_to_count, "y/n/na")

# %% [markdown]
# ## Group of question: conf

# %% [markdown]
# ### Which conference(s)/workshop(s)?

# %%
 wc = wordcloud(df, ['conf2_can. Which conference(s)/workshop(s)?'])

# %%
 plt.imshow(wc, interpolation='bilinear')
 plt.axis("off")
# Out:
# (-0.5, 1499.5, 799.5, -0.5)

# %% [markdown]
# ## Group of question: open

# %% [markdown]
# ### When you release code, how often do you use an open source license?

# %%
v_to_count, filename = get_count(df, ['open1_can. When you release code, how often do you use an open source license?'], "likert", "./../../survey_creation/2017/can/listAnswers/likert_time_5.csv", "False", "./can/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Count Percentage
# When you release code, how often do you use an ...
# Never                                                15.0        nan
# Sometimes                                            13.0        nan
# Often                                                 5.0        nan
# Very Often                                           16.0        nan
# Always                                               44.0        nan
# Prefer not to answer                                  NaN        nan

# %%
_ = get_plot(v_to_count, "likert")

# %% [markdown]
# ### List any open repositories (eg. GitHub) to which your software projects have been published.

# %%
 wc = wordcloud(df, ['open2_can. List any open repositories (eg. GitHub) to which your software projects have been published.'])

# %%
 plt.imshow(wc, interpolation='bilinear')
 plt.axis("off")
# Out:
# (-0.5, 1499.5, 799.5, -0.5)

# %% [markdown]
# ### When you release code or data, how often do you assign a Digital Object Identifier (DOI) to it?

# %%
v_to_count, filename = get_count(df, ['open3_can. When you release code or data, how often do you assign a Digital Object Identifier (DOI) to it?'], "likert", "./../../survey_creation/2017/can/listAnswers/likert_time_5.csv", "False", "./can/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Count Percentage
# When you release code or data, how often do you...
# Never                                                66.0        nan
# Sometimes                                             8.0        nan
# Often                                                 6.0        nan
# Very Often                                            5.0        nan
# Always                                                4.0        nan
# Prefer not to answer                                  NaN        nan

# %%
_ = get_plot(v_to_count, "likert")

# %% [markdown]
# ### Do any of your current projects accommodate the open/public sharing of data?; Is the creation of a Digital Object Identifier (DOI) and metadata for individual assets supported?

# %%
v_to_count, filename = get_count(df, ['open4_can. Do any of your current projects accommodate the open/public sharing of data?', 'open5_can. Is the creation of a Digital Object Identifier (DOI) and metadata for individual assets supported?'], "y/n/na", "./../../survey_creation/2017/can/listAnswers/.csv", "False", "./can/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Yes [Count]  No [Count]  \
# Is the creation of a Digital Object Identifier ...
#  Do any of your current projects accommodate th...           39          52
#  Is the creation of a Digital Object Identifier...           15          16
#
#                                                     NaN value  \
# Is the creation of a Digital Object Identifier ...
#  Do any of your current projects accommodate th...         19
#  Is the creation of a Digital Object Identifier...         79
#
#                                                    Yes [Percentage]  \
# Is the creation of a Digital Object Identifier ...
#  Do any of your current projects accommodate th...               43
#  Is the creation of a Digital Object Identifier...               48
#
#                                                    No [Percentage]
# Is the creation of a Digital Object Identifier ...
# ...

# %%
_ = get_plot(perc_to_count, "y/n/na")

# %% [markdown]
# ## Group of question: skill

# %% [markdown]
# ### In your opinion, what are the three most important skills that a Research Software Developer must possess? These skills can be technical and non-technical.

# %%
 wc = wordcloud(df, ['skill1. In your opinion, what are the three most important skills that a Research Software Developer must possess? These skills can be technical and non-technical.'])

# %%
 plt.imshow(wc, interpolation='bilinear')
 plt.axis("off")
# Out:
# (-0.5, 1499.5, 799.5, -0.5)

# %% [markdown]
# ### What three skills would you like to acquire or improve to help your work as a Research Software Developer? These skills can be technical and non-technical.

# %%
 wc = wordcloud(df, ['skill2. What three skills would you like to acquire or improve to help your work as a Research Software Developer? These skills can be technical and non-technical.'])

# %%
 plt.imshow(wc, interpolation='bilinear')
 plt.axis("off")
# Out:
# (-0.5, 1499.5, 799.5, -0.5)

# %% [markdown]
# ## Group of question: tool

# %% [markdown]
# ### What are the three tools or services you use most often in your software work?

# %%
 wc = wordcloud(df, ['tool1. What are the three tools or services you use most often in your software work?'])

# %%
 plt.imshow(wc, interpolation='bilinear')
 plt.axis("off")
# Out:
# (-0.5, 1499.5, 799.5, -0.5)

# %% [markdown]
# ### What is your Operating System of choice for development?

# %%
v_to_count, filename = get_count(df, ['tool2. What is your Operating System of choice for development?'], "one choice", "./../../survey_creation/2017/can/listAnswers/os.csv", "False", "./can/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Count Percentage
# What is your Operating System of choice for dev...
# GNU/Linux                                              48         51
# Windows                                                23         24
# Mac OS                                                 20         21
# Other                                                   3          3
# NaN                                                    16        NaN

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ### What is your Operating System of choice for deployment?

# %%
v_to_count, filename = get_count(df, ['tool3_can. What is your Operating System of choice for deployment?'], "one choice", "./../../survey_creation/2017/can/listAnswers/os.csv", "False", "./can/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Count Percentage
# What is your Operating System of choice for dep...
# GNU/Linux                                              58         60
# Windows                                                18         19
# Mac OS                                                  9          9
# Other                                                   6          6
# iOS                                                     4          4
# Android                                                 1          1
# NaN                                                    14        NaN

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ### What programming languages do you use in developing research software? Please list in order, beginning with most frequently used.

# %%
 wc = wordcloud(df, ['tool4_can. What programming languages do you use in developing research software? Please list in order, beginning with most frequently used.'])

# %%
 plt.imshow(wc, interpolation='bilinear')
 plt.axis("off")
# Out:
# (-0.5, 1499.5, 799.5, -0.5)

# %% [markdown]
# ### What platform(s) are your research software projects deployed on?

# %%
v_to_count, filename = get_count(df, ['tool5_can[multi]. What platform(s) are your research software projects deployed on? [Compute Canada HPC]', 'tool5_can[multi]. What platform(s) are your research software projects deployed on? [University computer centre]', 'tool5_can[multi]. What platform(s) are your research software projects deployed on? [Other HPC]', 'tool5_can[multi]. What platform(s) are your research software projects deployed on? [Cloud service]', 'tool5_can[multi]. What platform(s) are your research software projects deployed on? [Stand-alone server(s)]', 'tool5_can[multi]. What platform(s) are your research software projects deployed on? [Laptop/desktop]', 'tool5_can[multi]. What platform(s) are your research software projects deployed on? [Mobile]'], "multiple choices", "./../../survey_creation/2017/can/listAnswers/deployment_plateform.csv", "False", "./can/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Count Percentage
# What platform(s) are your research software pro...
# Laptop/desktop                                         55         26
# Stand-alone server(s)                                  46         22
# Compute Canada HPC                                     34         16
# Cloud service                                          24         11
# University computer centre                             23         11
# Other HPC                                              21         10
# Mobile                                                  8          4

# %%
_ = get_plot(perc_to_count, "multiple choices")

# %% [markdown]
# ## Group of question: data

# %% [markdown]
# ### Do any of your current projects make use of a data management or data archiving component?

# %%
v_to_count, filename = get_count(df, ['data1_can. Do any of your current projects make use of a data management or data archiving component?'], "y/n/na", "./../../survey_creation/2017/can/listAnswers/.csv", "False", "./can/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Yes [Count]  No [Count]  \
# Do any of your current projects make use of a d...
#  Do any of your current projects make use of a ...           55          39
#
#                                                     NaN value  \
# Do any of your current projects make use of a d...
#  Do any of your current projects make use of a ...         16
#
#                                                    Yes [Percentage]  \
# Do any of your current projects make use of a d...
#  Do any of your current projects make use of a ...               59
#
#                                                    No [Percentage]
# Do any of your current projects make use of a d...
#  Do any of your current projects make use of a ...              41

# %%
_ = get_plot(perc_to_count, "y/n/na")

# %% [markdown]
# ### Is it part of your software or an external system? (please specify)

# %%
v_to_count, filename = get_count(df, ['data2_can. Is it part of your software or an external system? (please specify)'], "one choice", "./../../survey_creation/2017/can/listAnswers/data_external.csv", "False", "./can/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Count Percentage
# Is it part of your software or an external syst...
# Software                                               28         52
# External System                                        26         48
# NaN                                                    56        NaN

# %%
_ = get_plot(perc_to_count, "one choice")

# %% [markdown]
# ## Group of question: org

# %% [markdown]
# ### Would you be interested in joining such an organization if one was formed in Canada?

# %%
v_to_count, filename = get_count(df, ['org1_can. Would you be interested in joining such an organization if one was formed in Canada?'], "y/n/na", "./../../survey_creation/2017/can/listAnswers/.csv", "False", "./can/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Yes [Count]  No [Count]  \
# Would you be interested in joining such an orga...
#  Would you be interested in joining such an org...           62          24
#
#                                                     NaN value  \
# Would you be interested in joining such an orga...
#  Would you be interested in joining such an org...         24
#
#                                                    Yes [Percentage]  \
# Would you be interested in joining such an orga...
#  Would you be interested in joining such an org...               72
#
#                                                    No [Percentage]
# Would you be interested in joining such an orga...
#  Would you be interested in joining such an org...              28

# %%
_ = get_plot(perc_to_count, "y/n/na")

# %% [markdown]
# ### What would you hope to get out of such an organization?

# %%
v_to_count, filename = get_count(df, ['org2_can[multi]. What would you hope to get out of such an organization? [Networking]', 'org2_can[multi]. What would you hope to get out of such an organization? [Software collaborations]', 'org2_can[multi]. What would you hope to get out of such an organization? [Research collaborations]', 'org2_can[multi]. What would you hope to get out of such an organization? [Training]', 'org2_can[multi]. What would you hope to get out of such an organization? [Research Software Standards and Interoperability]', 'org2_can[multi]. What would you hope to get out of such an organization? [Job opportunities]'], "multiple choices", "./../../survey_creation/2017/can/listAnswers/rse_benefits.csv", "False", "./can/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Count Percentage
# What would you hope to get out of such an organ...
# Networking                                             49         22
# Software collaborations                                43         19
# Training                                               40         18
# Research collaborations                                35         16
# Research Software Standards and Interoperability       35         16
# Job opportunities                                      19          9

# %%
_ = get_plot(perc_to_count, "multiple choices")

# %% [markdown]
# ## Group of question: instit

# %% [markdown]
# ### Have you developed software that is accessed from multiple institutions?

# %%
v_to_count, filename = get_count(df, ['instit1_can. Have you developed software that is accessed from multiple institutions?'], "y/n/na", "./../../survey_creation/2017/can/listAnswers/.csv", "False", "./can/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Yes [Count]  No [Count]  \
# Have you developed software that is accessed fr...
#  Have you developed software that is accessed f...           65          29
#
#                                                     NaN value  \
# Have you developed software that is accessed fr...
#  Have you developed software that is accessed f...         16
#
#                                                    Yes [Percentage]  \
# Have you developed software that is accessed fr...
#  Have you developed software that is accessed f...               69
#
#                                                    No [Percentage]
# Have you developed software that is accessed fr...
#  Have you developed software that is accessed f...              31

# %%
_ = get_plot(perc_to_count, "y/n/na")

# %% [markdown]
# ## Group of question: caf

# %% [markdown]
# ### Do any of your current or previous projects make use of the Canadian Access Federation (CAF) Federated Identity Management (FIM) service?

# %%
v_to_count, filename = get_count(df, ['caf1_can. Do any of your current or previous projects make use of the Canadian Access Federation (CAF) Federated Identity Management (FIM) service?'], "y/n/na", "./../../survey_creation/2017/can/listAnswers/.csv", "False", "./can/output/")

# %%
perc_to_count = get_percentage(v_to_count, filename)

# %%
display_side_by_side(v_to_count,perc_to_count)
# Out:
#                                                     Yes [Count]  No [Count]  \
# Do any of your current or previous projects mak...
#  Do any of your current or previous projects ma...            6          45
#
#                                                     NaN value  \
# Do any of your current or previous projects mak...
#  Do any of your current or previous projects ma...         13
#
#                                                    Yes [Percentage]  \
# Do any of your current or previous projects mak...
#  Do any of your current or previous projects ma...               12
#
#                                                    No [Percentage]
# Do any of your current or previous projects mak...
#  Do any of your current or previous projects ma...              88

# %%
_ = get_plot(perc_to_count, "y/n/na")
